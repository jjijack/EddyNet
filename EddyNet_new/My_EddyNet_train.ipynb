# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# to output everything in a cell instead of only the last output

# %matplotlib inline

# standard imports
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## import data

# %%
SSH_train = np.expand_dims(np.load('../Data/adt_train.npy'),3)[:,:-1,1:,:]
SSH_test = np.expand_dims(np.load('../Data/adt_test.npy'),3)[:,:-1,1:,:]

SSH_train[np.isnan(SSH_train)] = -1
SSH_test[np.isnan(SSH_test)] = -1

SSH_train=tf.pad(SSH_train, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=-1)
SSH_test=tf.pad(SSH_test, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=-1)
#######
Seg_train = np.expand_dims(np.load('../Data/grid_all.npy'),3)[:,:-1,1:,:]
Seg_test = np.expand_dims(np.load('../Data/grid_all_test.npy'),3)[:,:-1,1:,:]

Seg_train[Seg_train==-1] = 2
Seg_test[Seg_test==-1] = 2

Seg_train=tf.pad(Seg_train, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=0)
Seg_test=tf.pad(Seg_test, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=0)
######
SSH_train.shape
SSH_test.shape
#####
Seg_train.shape
Seg_test.shape
# Out:
# 2024-01-09 23:20:39.221553: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-01-09 23:20:39.221583: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-01-09 23:20:39.221592: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-01-09 23:20:39.221625: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-09 23:20:39.221641: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# TensorShape([3653, 80, 192, 1])
# TensorShape([365, 80, 192, 1])
# TensorShape([3653, 80, 192, 1])
# TensorShape([365, 80, 192, 1])

# %%
randindex=np.random.randint(0,len(SSH_train))

plt.figure(figsize=(20, 10))

plt.subplot(121)
plt.imshow(SSH_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(122)
plt.imshow(Seg_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

# %% [markdown]
# ## Eddynet

# %%
from keras.models import Model, load_model
from keras.layers import Activation, Reshape, Permute, Lambda
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, UpSampling2D, AlphaDropout, concatenate, Conv2DTranspose
from keras.layers import BatchNormalization, LeakyReLU, add
import keras.utils as utils     #更改代码
from keras.optimizers import legacy     #更改代码
from keras import backend as K
from keras import regularizers
import matplotlib.pyplot as plt
import numpy as np
import pickle
from IPython.display import SVG 
from keras.utils import model_to_dot    #更改代码
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import tensorflow as tf

# %%
Seg_train_categor = utils.to_categorical(np.reshape(Seg_train[:,:,:,0],(3653,80*192)),3)    #更改代码
Seg_train_categor.shape
# Out:
# (3653, 15360, 3)

# %%
def ConvBNActi(nf,ker,inputs):
    conv1 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    #conv1 = LeakyReLU(0.3)(conv1)
    return conv1
  
def ConvTranspBNActi(nf,ker,inputs):
    conv1 = Conv2DTranspose(nf, ker, strides=(2, 2), padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    #conv1 = LeakyReLU(0.3)(conv1)
    return conv1

# %%
width = 192
height = 80
nbClass = 3
nf = 16
ker = 3

###################################### INPUT LAYER

img_input = Input(shape=(height, width, 1))
######################################ENCODER

conv1 = ConvBNActi(nf,ker,img_input)
conv1 = ConvBNActi(nf,ker,conv1)
conv1 = Dropout(0.2)(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = ConvBNActi(nf,ker,pool1)
conv2 = ConvBNActi(nf,ker,conv2)
conv2 = Dropout(0.3)(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = ConvBNActi(nf,ker,pool2)
conv3 = ConvBNActi(nf,ker,conv3)
conv3 = Dropout(0.4)(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = ConvBNActi(nf,ker,pool3)
conv4 = ConvBNActi(nf,ker,conv4)
conv4 = Dropout(0.4)(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

#######################################center

convC = ConvBNActi(nf,ker,pool4)
convC = ConvBNActi(nf,ker,convC)
convC = Dropout(0.5)(convC)

#######################################DECODER

#up4 = concatenate([ConvTranspBNActi(nf,ker,convC), conv4])
up4 = concatenate([UpSampling2D((2,2))(convC), conv4])
decod4 = ConvBNActi(nf,ker,up4)
decod4 = ConvBNActi(nf,ker,decod4)
decod4 = Dropout(0.4)(decod4)

#up3 = concatenate([ConvTranspBNActi(nf,ker,convC), conv3])
up3 = concatenate([UpSampling2D((2,2))(decod4), conv3])
decod3 = ConvBNActi(nf,ker,up3)
decod3 = ConvBNActi(nf,ker,decod3)
decod3 = Dropout(0.3)(decod3)



#up2 = concatenate([ConvTranspBNActi(nf,ker,decod3), conv2])
up2 = concatenate([UpSampling2D((2,2))(decod3), conv2])
decod2 = ConvBNActi(nf,ker,up2)
decod2 = ConvBNActi(nf,ker,decod2)
decod2 = Dropout(0.2)(decod2)


#up1 = concatenate([ConvTranspBNActi(nf,ker,decod2), conv1])
up1 = concatenate([UpSampling2D((2,2))(decod2), conv1])
decod1 = ConvBNActi(nf,ker,up1)
decod1 = ConvBNActi(nf,ker,decod1)
decod1 = Dropout(0.1)(decod1)


####################################### Segmentation Layer

x = Conv2D(nbClass, (1, 1), padding="valid", use_bias=False)(decod1) 
x = Reshape((height * width, nbClass))(x) 
x = Activation("softmax")(x)
eddynet = Model(img_input, x)

eddynet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 80, 192, 1)]         0         []
#
#  conv2d (Conv2D)             (None, 80, 192, 16)          144       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 80, 192, 16)          64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 80, 192, 16)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 80, 192, 16)          2304      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 80, 192, 16)          64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 80, 192, 16)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 80, 192, 16)          0         ['activation_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 40, 96, 16)           0         ['dropout[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 40, 96, 16)           2304      ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 40, 96, 16)           64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 40, 96, 16)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 40, 96, 16)           2304      ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 40, 96, 16)           64        ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 40, 96, 16)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 40, 96, 16)           0         ['activation_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 20, 48, 16)           0         ['dropout_1[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 20, 48, 16)           2304      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 20, 48, 16)           64        ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 20, 48, 16)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 20, 48, 16)           2304      ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 20, 48, 16)           64        ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 20, 48, 16)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 20, 48, 16)           0         ['activation_5[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 24, 16)           0         ['dropout_2[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 10, 24, 16)           2304      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 10, 24, 16)           64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 10, 24, 16)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 10, 24, 16)           2304      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 10, 24, 16)           64        ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 10, 24, 16)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 10, 24, 16)           0         ['activation_7[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 12, 16)            0         ['dropout_3[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 5, 12, 16)            2304      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 5, 12, 16)            64        ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 5, 12, 16)            0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 5, 12, 16)            2304      ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 5, 12, 16)            64        ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 5, 12, 16)            0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 5, 12, 16)            0         ['activation_9[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 10, 24, 16)           0         ['dropout_4[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 10, 24, 32)           0         ['up_sampling2d[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 10, 24, 16)           4608      ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 10, 24, 16)           64        ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 10, 24, 16)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 10, 24, 16)           2304      ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 10, 24, 16)           64        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 10, 24, 16)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 10, 24, 16)           0         ['activation_11[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 20, 48, 16)           0         ['dropout_5[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 20, 48, 32)           0         ['up_sampling2d_1[0][0]',
#  )                                                                   'dropout_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 20, 48, 16)           4608      ['concatenate_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 20, 48, 16)           64        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 20, 48, 16)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 20, 48, 16)           2304      ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 20, 48, 16)           64        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 20, 48, 16)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 20, 48, 16)           0         ['activation_13[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 40, 96, 16)           0         ['dropout_6[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 40, 96, 32)           0         ['up_sampling2d_2[0][0]',
#  )                                                                   'dropout_1[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 40, 96, 16)           4608      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 40, 96, 16)           64        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 40, 96, 16)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 40, 96, 16)           2304      ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 40, 96, 16)           64        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 40, 96, 16)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 40, 96, 16)           0         ['activation_15[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 80, 192, 16)          0         ['dropout_7[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 80, 192, 32)          0         ['up_sampling2d_3[0][0]',
#  )                                                                   'dropout[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 80, 192, 16)          4608      ['concatenate_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 80, 192, 16)          64        ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 80, 192, 16)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 80, 192, 16)          2304      ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 80, 192, 16)          64        ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 80, 192, 16)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 80, 192, 16)          0         ['activation_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 80, 192, 3)           48        ['dropout_8[0][0]']
#
#  reshape (Reshape)           (None, 15360, 3)             0         ['conv2d_18[0][0]']
#
#  activation_18 (Activation)  (None, 15360, 3)             0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 49728 (194.25 KB)
# Trainable params: 49152 (192.00 KB)
# Non-trainable params: 576 (2.25 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### calculate weights (some heavy data imbalance out there...)

# %%
unique, counts = np.unique(Seg_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0.0: 40200956, 1.0: 8259619, 2.0: 7649505}

# %%
freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
weightsSeg
# Out:
# [0.0899075590389081, 0.4375952238221336, 0.4724972171389583]

# %% [markdown]
# ## loss functions

# %%
smooth = 1.  # to avoid zero division

def dice_coef_anti(y_true, y_pred):
    y_true_anti = y_true[:,:,1]
    y_pred_anti = y_pred[:,:,1]
    intersection_anti = K.sum(y_true_anti * y_pred_anti)
    return (2 * intersection_anti + smooth) / (K.sum(y_true_anti)+ K.sum(y_pred_anti) + smooth)

def dice_coef_cyc(y_true, y_pred):
    y_true_cyc = y_true[:,:,2]
    y_pred_cyc = y_pred[:,:,2]
    intersection_cyc = K.sum(y_true_cyc * y_pred_cyc)
    return (2 * intersection_cyc + smooth) / (K.sum(y_true_cyc) + K.sum(y_pred_cyc) + smooth)

def dice_coef_nn(y_true, y_pred):
    y_true_nn = y_true[:,:,0]
    y_pred_nn = y_pred[:,:,0]
    intersection_nn = K.sum(y_true_nn * y_pred_nn)
    return (2 * intersection_nn + smooth) / (K.sum(y_true_nn) + K.sum(y_pred_nn) + smooth)
    
def mean_dice_coef(y_true, y_pred):
    return (dice_coef_anti(y_true, y_pred) + dice_coef_cyc(y_true, y_pred) + dice_coef_nn(y_true, y_pred))/3.

def weighted_mean_dice_coef(y_true, y_pred):
    return (0.36*dice_coef_anti(y_true, y_pred) + 0.62*dice_coef_cyc(y_true, y_pred) + 0.02*dice_coef_nn(y_true, y_pred))
  
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_mean_dice_coef(y_true, y_pred)

# %%
eddynet.compile(optimizer=legacy.Adam(lr=1e-2), loss=dice_coef_loss,    #更改代码
                metrics=['categorical_accuracy', mean_dice_coef, weighted_mean_dice_coef])
# Out:
# /Users/jjijack/miniconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#SVG(model_to_dot(eddynet).create(prog='dot', format='svg'))

# %% [markdown]
# ## Training

# %%
modelcheck = ModelCheckpoint('./weights/eddynetfirst.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
reducecall = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, verbose=1, mode='auto', min_delta=1e-30, min_lr=1e-30)


histeddynet=eddynet.fit(SSH_train, Seg_train_categor,
                              epochs=50,
                              batch_size=16,
                              shuffle=True,
                              verbose=1,
                              callbacks=[modelcheck,reducecall],#,MyCallback(alpha,beta),reducecall
                              validation_split=0.2
                              )
# Out:
# Epoch 1/100
# 2024-01-09 23:20:44.037281: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 46/46 [==============================] - ETA: 0s - loss: 0.4937 - categorical_accuracy: 0.5257 - mean_dice_coef: 0.5157 - weighted_mean_dice_coef: 0.5073
# 2024-01-09 23:20:54.404099: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.63820, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 13s 220ms/step - loss: 0.4937 - categorical_accuracy: 0.5257 - mean_dice_coef: 0.5157 - weighted_mean_dice_coef: 0.5073 - val_loss: 0.6382 - val_categorical_accuracy: 0.2496 - val_mean_dice_coef: 0.2829 - val_weighted_mean_dice_coef: 0.3622 - lr: 0.0100
# Epoch 2/100
# 46/46 [==============================] - ETA: 0s - loss: 0.3306 - categorical_accuracy: 0.7986 - mean_dice_coef: 0.7261 - weighted_mean_dice_coef: 0.6696
# Epoch 2: val_loss did not improve from 0.63820
# 46/46 [==============================] - 8s 185ms/step - loss: 0.3306 - categorical_accuracy: 0.7986 - mean_dice_coef: 0.7261 - weighted_mean_dice_coef: 0.6696 - val_loss: 0.6422 - val_categorical_accuracy: 0.5732 - val_mean_dice_coef: 0.4719 - val_weighted_mean_dice_coef: 0.3585 - lr: 0.0100
# Epoch 3/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2996 - categorical_accuracy: 0.8203 - mean_dice_coef: 0.7535 - weighted_mean_dice_coef: 0.7004
# Epoch 3: val_loss improved from 0.63820 to 0.63485, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 190ms/step - loss: 0.2996 - categorical_accuracy: 0.8203 - mean_dice_coef: 0.7535 - weighted_mean_dice_coef: 0.7004 - val_loss: 0.6349 - val_categorical_accuracy: 0.7476 - val_mean_dice_coef: 0.5531 - val_weighted_mean_dice_coef: 0.3653 - lr: 0.0100
# Epoch 4/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2851 - categorical_accuracy: 0.8304 - mean_dice_coef: 0.7665 - weighted_mean_dice_coef: 0.7149
# Epoch 4: val_loss improved from 0.63485 to 0.58994, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2851 - categorical_accuracy: 0.8304 - mean_dice_coef: 0.7665 - weighted_mean_dice_coef: 0.7149 - val_loss: 0.5899 - val_categorical_accuracy: 0.7744 - val_mean_dice_coef: 0.5824 - val_weighted_mean_dice_coef: 0.4102 - lr: 0.0100
# Epoch 5/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2767 - categorical_accuracy: 0.8362 - mean_dice_coef: 0.7740 - weighted_mean_dice_coef: 0.7233
# Epoch 5: val_loss improved from 0.58994 to 0.46289, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 179ms/step - loss: 0.2767 - categorical_accuracy: 0.8362 - mean_dice_coef: 0.7740 - weighted_mean_dice_coef: 0.7233 - val_loss: 0.4629 - val_categorical_accuracy: 0.8022 - val_mean_dice_coef: 0.6570 - val_weighted_mean_dice_coef: 0.5359 - lr: 0.0100
# Epoch 6/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2707 - categorical_accuracy: 0.8400 - mean_dice_coef: 0.7791 - weighted_mean_dice_coef: 0.7293
# Epoch 6: val_loss improved from 0.46289 to 0.38555, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 177ms/step - loss: 0.2707 - categorical_accuracy: 0.8400 - mean_dice_coef: 0.7791 - weighted_mean_dice_coef: 0.7293 - val_loss: 0.3855 - val_categorical_accuracy: 0.8194 - val_mean_dice_coef: 0.7049 - val_weighted_mean_dice_coef: 0.6135 - lr: 0.0100
# Epoch 7/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2667 - categorical_accuracy: 0.8426 - mean_dice_coef: 0.7827 - weighted_mean_dice_coef: 0.7334
# Epoch 7: val_loss improved from 0.38555 to 0.32815, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 175ms/step - loss: 0.2667 - categorical_accuracy: 0.8426 - mean_dice_coef: 0.7827 - weighted_mean_dice_coef: 0.7334 - val_loss: 0.3281 - val_categorical_accuracy: 0.8325 - val_mean_dice_coef: 0.7420 - val_weighted_mean_dice_coef: 0.6707 - lr: 0.0100
# Epoch 8/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2640 - categorical_accuracy: 0.8445 - mean_dice_coef: 0.7850 - weighted_mean_dice_coef: 0.7360
# Epoch 8: val_loss improved from 0.32815 to 0.31052, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 190ms/step - loss: 0.2640 - categorical_accuracy: 0.8445 - mean_dice_coef: 0.7850 - weighted_mean_dice_coef: 0.7360 - val_loss: 0.3105 - val_categorical_accuracy: 0.8365 - val_mean_dice_coef: 0.7565 - val_weighted_mean_dice_coef: 0.6884 - lr: 0.0100
# Epoch 9/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2610 - categorical_accuracy: 0.8466 - mean_dice_coef: 0.7876 - weighted_mean_dice_coef: 0.7390
# Epoch 9: val_loss improved from 0.31052 to 0.31008, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2610 - categorical_accuracy: 0.8466 - mean_dice_coef: 0.7876 - weighted_mean_dice_coef: 0.7390 - val_loss: 0.3101 - val_categorical_accuracy: 0.8369 - val_mean_dice_coef: 0.7580 - val_weighted_mean_dice_coef: 0.6886 - lr: 0.0100
# Epoch 10/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2587 - categorical_accuracy: 0.8479 - mean_dice_coef: 0.7895 - weighted_mean_dice_coef: 0.7412
# Epoch 10: val_loss improved from 0.31008 to 0.28114, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 183ms/step - loss: 0.2587 - categorical_accuracy: 0.8479 - mean_dice_coef: 0.7895 - weighted_mean_dice_coef: 0.7412 - val_loss: 0.2811 - val_categorical_accuracy: 0.8448 - val_mean_dice_coef: 0.7733 - val_weighted_mean_dice_coef: 0.7178 - lr: 0.0100
# Epoch 11/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2576 - categorical_accuracy: 0.8488 - mean_dice_coef: 0.7906 - weighted_mean_dice_coef: 0.7424
# Epoch 11: val_loss improved from 0.28114 to 0.26498, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 176ms/step - loss: 0.2576 - categorical_accuracy: 0.8488 - mean_dice_coef: 0.7906 - weighted_mean_dice_coef: 0.7424 - val_loss: 0.2650 - val_categorical_accuracy: 0.8460 - val_mean_dice_coef: 0.7847 - val_weighted_mean_dice_coef: 0.7337 - lr: 0.0100
# Epoch 12/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2551 - categorical_accuracy: 0.8502 - mean_dice_coef: 0.7926 - weighted_mean_dice_coef: 0.7450
# Epoch 12: val_loss improved from 0.26498 to 0.26056, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 182ms/step - loss: 0.2551 - categorical_accuracy: 0.8502 - mean_dice_coef: 0.7926 - weighted_mean_dice_coef: 0.7450 - val_loss: 0.2606 - val_categorical_accuracy: 0.8515 - val_mean_dice_coef: 0.7872 - val_weighted_mean_dice_coef: 0.7385 - lr: 0.0100
# Epoch 13/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2549 - categorical_accuracy: 0.8505 - mean_dice_coef: 0.7929 - weighted_mean_dice_coef: 0.7452
# Epoch 13: val_loss improved from 0.26056 to 0.25645, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 183ms/step - loss: 0.2549 - categorical_accuracy: 0.8505 - mean_dice_coef: 0.7929 - weighted_mean_dice_coef: 0.7452 - val_loss: 0.2565 - val_categorical_accuracy: 0.8518 - val_mean_dice_coef: 0.7921 - val_weighted_mean_dice_coef: 0.7425 - lr: 0.0100
# Epoch 14/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2537 - categorical_accuracy: 0.8510 - mean_dice_coef: 0.7938 - weighted_mean_dice_coef: 0.7463
# Epoch 14: val_loss did not improve from 0.25645
# 46/46 [==============================] - 8s 179ms/step - loss: 0.2537 - categorical_accuracy: 0.8510 - mean_dice_coef: 0.7938 - weighted_mean_dice_coef: 0.7463 - val_loss: 0.2596 - val_categorical_accuracy: 0.8505 - val_mean_dice_coef: 0.7884 - val_weighted_mean_dice_coef: 0.7392 - lr: 0.0100
# Epoch 15/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2513 - categorical_accuracy: 0.8526 - mean_dice_coef: 0.7958 - weighted_mean_dice_coef: 0.7487
# Epoch 15: val_loss improved from 0.25645 to 0.25350, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 192ms/step - loss: 0.2513 - categorical_accuracy: 0.8526 - mean_dice_coef: 0.7958 - weighted_mean_dice_coef: 0.7487 - val_loss: 0.2535 - val_categorical_accuracy: 0.8519 - val_mean_dice_coef: 0.7922 - val_weighted_mean_dice_coef: 0.7455 - lr: 0.0100
# Epoch 16/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2516 - categorical_accuracy: 0.8525 - mean_dice_coef: 0.7956 - weighted_mean_dice_coef: 0.7483
# Epoch 16: val_loss did not improve from 0.25350
# 46/46 [==============================] - 9s 188ms/step - loss: 0.2516 - categorical_accuracy: 0.8525 - mean_dice_coef: 0.7956 - weighted_mean_dice_coef: 0.7483 - val_loss: 0.2562 - val_categorical_accuracy: 0.8450 - val_mean_dice_coef: 0.7889 - val_weighted_mean_dice_coef: 0.7426 - lr: 0.0100
# Epoch 17/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2501 - categorical_accuracy: 0.8533 - mean_dice_coef: 0.7969 - weighted_mean_dice_coef: 0.7499
# Epoch 17: val_loss improved from 0.25350 to 0.25302, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 202ms/step - loss: 0.2501 - categorical_accuracy: 0.8533 - mean_dice_coef: 0.7969 - weighted_mean_dice_coef: 0.7499 - val_loss: 0.2530 - val_categorical_accuracy: 0.8503 - val_mean_dice_coef: 0.7934 - val_weighted_mean_dice_coef: 0.7459 - lr: 0.0100
# Epoch 18/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2494 - categorical_accuracy: 0.8537 - mean_dice_coef: 0.7974 - weighted_mean_dice_coef: 0.7506
# Epoch 18: val_loss did not improve from 0.25302
# 46/46 [==============================] - 9s 196ms/step - loss: 0.2494 - categorical_accuracy: 0.8537 - mean_dice_coef: 0.7974 - weighted_mean_dice_coef: 0.7506 - val_loss: 0.2629 - val_categorical_accuracy: 0.8507 - val_mean_dice_coef: 0.7878 - val_weighted_mean_dice_coef: 0.7358 - lr: 0.0100
# Epoch 19/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2484 - categorical_accuracy: 0.8546 - mean_dice_coef: 0.7984 - weighted_mean_dice_coef: 0.7516
# Epoch 19: val_loss did not improve from 0.25302
# 46/46 [==============================] - 9s 197ms/step - loss: 0.2484 - categorical_accuracy: 0.8546 - mean_dice_coef: 0.7984 - weighted_mean_dice_coef: 0.7516 - val_loss: 0.2533 - val_categorical_accuracy: 0.8528 - val_mean_dice_coef: 0.7940 - val_weighted_mean_dice_coef: 0.7459 - lr: 0.0100
# Epoch 20/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2476 - categorical_accuracy: 0.8550 - mean_dice_coef: 0.7990 - weighted_mean_dice_coef: 0.7524
# Epoch 20: val_loss did not improve from 0.25302
# 46/46 [==============================] - 9s 191ms/step - loss: 0.2476 - categorical_accuracy: 0.8550 - mean_dice_coef: 0.7990 - weighted_mean_dice_coef: 0.7524 - val_loss: 0.2546 - val_categorical_accuracy: 0.8482 - val_mean_dice_coef: 0.7904 - val_weighted_mean_dice_coef: 0.7446 - lr: 0.0100
# Epoch 21/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2476 - categorical_accuracy: 0.8549 - mean_dice_coef: 0.7989 - weighted_mean_dice_coef: 0.7524
# Epoch 21: val_loss improved from 0.25302 to 0.25101, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2476 - categorical_accuracy: 0.8549 - mean_dice_coef: 0.7989 - weighted_mean_dice_coef: 0.7524 - val_loss: 0.2510 - val_categorical_accuracy: 0.8549 - val_mean_dice_coef: 0.7959 - val_weighted_mean_dice_coef: 0.7483 - lr: 0.0100
# Epoch 22/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2467 - categorical_accuracy: 0.8556 - mean_dice_coef: 0.7998 - weighted_mean_dice_coef: 0.7533
# Epoch 22: val_loss did not improve from 0.25101
# 46/46 [==============================] - 8s 182ms/step - loss: 0.2467 - categorical_accuracy: 0.8556 - mean_dice_coef: 0.7998 - weighted_mean_dice_coef: 0.7533 - val_loss: 0.2527 - val_categorical_accuracy: 0.8553 - val_mean_dice_coef: 0.7949 - val_weighted_mean_dice_coef: 0.7464 - lr: 0.0100
# Epoch 23/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2464 - categorical_accuracy: 0.8558 - mean_dice_coef: 0.8000 - weighted_mean_dice_coef: 0.7536
# Epoch 23: val_loss improved from 0.25101 to 0.24674, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 8s 175ms/step - loss: 0.2464 - categorical_accuracy: 0.8558 - mean_dice_coef: 0.8000 - weighted_mean_dice_coef: 0.7536 - val_loss: 0.2467 - val_categorical_accuracy: 0.8510 - val_mean_dice_coef: 0.7975 - val_weighted_mean_dice_coef: 0.7521 - lr: 0.0100
# Epoch 24/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2460 - categorical_accuracy: 0.8560 - mean_dice_coef: 0.8003 - weighted_mean_dice_coef: 0.7539
# Epoch 24: val_loss did not improve from 0.24674
# 46/46 [==============================] - 9s 187ms/step - loss: 0.2460 - categorical_accuracy: 0.8560 - mean_dice_coef: 0.8003 - weighted_mean_dice_coef: 0.7539 - val_loss: 0.2509 - val_categorical_accuracy: 0.8511 - val_mean_dice_coef: 0.7956 - val_weighted_mean_dice_coef: 0.7482 - lr: 0.0100
# Epoch 25/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2451 - categorical_accuracy: 0.8566 - mean_dice_coef: 0.8011 - weighted_mean_dice_coef: 0.7549
# Epoch 25: val_loss did not improve from 0.24674
# 46/46 [==============================] - 8s 182ms/step - loss: 0.2451 - categorical_accuracy: 0.8566 - mean_dice_coef: 0.8011 - weighted_mean_dice_coef: 0.7549 - val_loss: 0.2468 - val_categorical_accuracy: 0.8491 - val_mean_dice_coef: 0.7967 - val_weighted_mean_dice_coef: 0.7520 - lr: 0.0100
# Epoch 26/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2447 - categorical_accuracy: 0.8567 - mean_dice_coef: 0.8013 - weighted_mean_dice_coef: 0.7553
# Epoch 26: val_loss did not improve from 0.24674
# 46/46 [==============================] - 8s 178ms/step - loss: 0.2447 - categorical_accuracy: 0.8567 - mean_dice_coef: 0.8013 - weighted_mean_dice_coef: 0.7553 - val_loss: 0.2531 - val_categorical_accuracy: 0.8460 - val_mean_dice_coef: 0.7924 - val_weighted_mean_dice_coef: 0.7459 - lr: 0.0100
# Epoch 27/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2448 - categorical_accuracy: 0.8566 - mean_dice_coef: 0.8013 - weighted_mean_dice_coef: 0.7552
# Epoch 27: val_loss did not improve from 0.24674
# 46/46 [==============================] - 9s 188ms/step - loss: 0.2448 - categorical_accuracy: 0.8566 - mean_dice_coef: 0.8013 - weighted_mean_dice_coef: 0.7552 - val_loss: 0.2494 - val_categorical_accuracy: 0.8546 - val_mean_dice_coef: 0.7978 - val_weighted_mean_dice_coef: 0.7495 - lr: 0.0100
# Epoch 28/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2440 - categorical_accuracy: 0.8572 - mean_dice_coef: 0.8020 - weighted_mean_dice_coef: 0.7560
# Epoch 28: val_loss improved from 0.24674 to 0.24352, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 9s 197ms/step - loss: 0.2440 - categorical_accuracy: 0.8572 - mean_dice_coef: 0.8020 - weighted_mean_dice_coef: 0.7560 - val_loss: 0.2435 - val_categorical_accuracy: 0.8549 - val_mean_dice_coef: 0.8010 - val_weighted_mean_dice_coef: 0.7559 - lr: 0.0100
# Epoch 29/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2435 - categorical_accuracy: 0.8576 - mean_dice_coef: 0.8024 - weighted_mean_dice_coef: 0.7565
# Epoch 29: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 189ms/step - loss: 0.2435 - categorical_accuracy: 0.8576 - mean_dice_coef: 0.8024 - weighted_mean_dice_coef: 0.7565 - val_loss: 0.2514 - val_categorical_accuracy: 0.8424 - val_mean_dice_coef: 0.7924 - val_weighted_mean_dice_coef: 0.7478 - lr: 0.0100
# Epoch 30/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2441 - categorical_accuracy: 0.8572 - mean_dice_coef: 0.8020 - weighted_mean_dice_coef: 0.7559
# Epoch 30: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2441 - categorical_accuracy: 0.8572 - mean_dice_coef: 0.8020 - weighted_mean_dice_coef: 0.7559 - val_loss: 0.2524 - val_categorical_accuracy: 0.8575 - val_mean_dice_coef: 0.7967 - val_weighted_mean_dice_coef: 0.7464 - lr: 0.0100
# Epoch 31/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2428 - categorical_accuracy: 0.8580 - mean_dice_coef: 0.8030 - weighted_mean_dice_coef: 0.7572
# Epoch 31: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2428 - categorical_accuracy: 0.8580 - mean_dice_coef: 0.8030 - weighted_mean_dice_coef: 0.7572 - val_loss: 0.2506 - val_categorical_accuracy: 0.8495 - val_mean_dice_coef: 0.7944 - val_weighted_mean_dice_coef: 0.7480 - lr: 0.0100
# Epoch 32/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2424 - categorical_accuracy: 0.8582 - mean_dice_coef: 0.8033 - weighted_mean_dice_coef: 0.7576
# Epoch 32: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2424 - categorical_accuracy: 0.8582 - mean_dice_coef: 0.8033 - weighted_mean_dice_coef: 0.7576 - val_loss: 0.2546 - val_categorical_accuracy: 0.8468 - val_mean_dice_coef: 0.7905 - val_weighted_mean_dice_coef: 0.7442 - lr: 0.0100
# Epoch 33/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2423 - categorical_accuracy: 0.8581 - mean_dice_coef: 0.8033 - weighted_mean_dice_coef: 0.7577
# Epoch 33: val_loss did not improve from 0.24352
# 46/46 [==============================] - 8s 182ms/step - loss: 0.2423 - categorical_accuracy: 0.8581 - mean_dice_coef: 0.8033 - weighted_mean_dice_coef: 0.7577 - val_loss: 0.2478 - val_categorical_accuracy: 0.8556 - val_mean_dice_coef: 0.7985 - val_weighted_mean_dice_coef: 0.7511 - lr: 0.0100
# Epoch 34/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2418 - categorical_accuracy: 0.8586 - mean_dice_coef: 0.8038 - weighted_mean_dice_coef: 0.7583
# Epoch 34: val_loss did not improve from 0.24352
# 46/46 [==============================] - 8s 177ms/step - loss: 0.2418 - categorical_accuracy: 0.8586 - mean_dice_coef: 0.8038 - weighted_mean_dice_coef: 0.7583 - val_loss: 0.2514 - val_categorical_accuracy: 0.8544 - val_mean_dice_coef: 0.7965 - val_weighted_mean_dice_coef: 0.7474 - lr: 0.0100
# Epoch 35/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2411 - categorical_accuracy: 0.8589 - mean_dice_coef: 0.8043 - weighted_mean_dice_coef: 0.7589
# Epoch 35: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2411 - categorical_accuracy: 0.8589 - mean_dice_coef: 0.8043 - weighted_mean_dice_coef: 0.7589 - val_loss: 0.2490 - val_categorical_accuracy: 0.8516 - val_mean_dice_coef: 0.7965 - val_weighted_mean_dice_coef: 0.7498 - lr: 0.0100
# Epoch 36/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2410 - categorical_accuracy: 0.8591 - mean_dice_coef: 0.8045 - weighted_mean_dice_coef: 0.7591
# Epoch 36: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 195ms/step - loss: 0.2410 - categorical_accuracy: 0.8591 - mean_dice_coef: 0.8045 - weighted_mean_dice_coef: 0.7591 - val_loss: 0.2450 - val_categorical_accuracy: 0.8537 - val_mean_dice_coef: 0.7998 - val_weighted_mean_dice_coef: 0.7542 - lr: 0.0100
# Epoch 37/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2414 - categorical_accuracy: 0.8587 - mean_dice_coef: 0.8041 - weighted_mean_dice_coef: 0.7586
# Epoch 37: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 191ms/step - loss: 0.2414 - categorical_accuracy: 0.8587 - mean_dice_coef: 0.8041 - weighted_mean_dice_coef: 0.7586 - val_loss: 0.2469 - val_categorical_accuracy: 0.8503 - val_mean_dice_coef: 0.7975 - val_weighted_mean_dice_coef: 0.7522 - lr: 0.0100
# Epoch 38/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2409 - categorical_accuracy: 0.8591 - mean_dice_coef: 0.8045 - weighted_mean_dice_coef: 0.7591
# Epoch 38: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 191ms/step - loss: 0.2409 - categorical_accuracy: 0.8591 - mean_dice_coef: 0.8045 - weighted_mean_dice_coef: 0.7591 - val_loss: 0.2641 - val_categorical_accuracy: 0.8532 - val_mean_dice_coef: 0.7859 - val_weighted_mean_dice_coef: 0.7347 - lr: 0.0100
# Epoch 39/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2402 - categorical_accuracy: 0.8595 - mean_dice_coef: 0.8050 - weighted_mean_dice_coef: 0.7597
# Epoch 39: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 192ms/step - loss: 0.2402 - categorical_accuracy: 0.8595 - mean_dice_coef: 0.8050 - weighted_mean_dice_coef: 0.7597 - val_loss: 0.2523 - val_categorical_accuracy: 0.8472 - val_mean_dice_coef: 0.7932 - val_weighted_mean_dice_coef: 0.7467 - lr: 0.0100
# Epoch 40/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2402 - categorical_accuracy: 0.8597 - mean_dice_coef: 0.8052 - weighted_mean_dice_coef: 0.7598
# Epoch 40: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2402 - categorical_accuracy: 0.8597 - mean_dice_coef: 0.8052 - weighted_mean_dice_coef: 0.7598 - val_loss: 0.2581 - val_categorical_accuracy: 0.8482 - val_mean_dice_coef: 0.7899 - val_weighted_mean_dice_coef: 0.7404 - lr: 0.0100
# Epoch 41/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2400 - categorical_accuracy: 0.8597 - mean_dice_coef: 0.8053 - weighted_mean_dice_coef: 0.7600
# Epoch 41: val_loss did not improve from 0.24352
# 46/46 [==============================] - 8s 183ms/step - loss: 0.2400 - categorical_accuracy: 0.8597 - mean_dice_coef: 0.8053 - weighted_mean_dice_coef: 0.7600 - val_loss: 0.2480 - val_categorical_accuracy: 0.8579 - val_mean_dice_coef: 0.7994 - val_weighted_mean_dice_coef: 0.7510 - lr: 0.0100
# Epoch 42/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2394 - categorical_accuracy: 0.8599 - mean_dice_coef: 0.8057 - weighted_mean_dice_coef: 0.7606
# Epoch 42: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 195ms/step - loss: 0.2394 - categorical_accuracy: 0.8599 - mean_dice_coef: 0.8057 - weighted_mean_dice_coef: 0.7606 - val_loss: 0.2637 - val_categorical_accuracy: 0.8466 - val_mean_dice_coef: 0.7844 - val_weighted_mean_dice_coef: 0.7354 - lr: 0.0100
# Epoch 43/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2398 - categorical_accuracy: 0.8598 - mean_dice_coef: 0.8054 - weighted_mean_dice_coef: 0.7602
# Epoch 43: val_loss did not improve from 0.24352
# 46/46 [==============================] - 10s 208ms/step - loss: 0.2398 - categorical_accuracy: 0.8598 - mean_dice_coef: 0.8054 - weighted_mean_dice_coef: 0.7602 - val_loss: 0.2484 - val_categorical_accuracy: 0.8560 - val_mean_dice_coef: 0.7986 - val_weighted_mean_dice_coef: 0.7506 - lr: 0.0100
# Epoch 44/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2393 - categorical_accuracy: 0.8601 - mean_dice_coef: 0.8058 - weighted_mean_dice_coef: 0.7607
# Epoch 44: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 200ms/step - loss: 0.2393 - categorical_accuracy: 0.8601 - mean_dice_coef: 0.8058 - weighted_mean_dice_coef: 0.7607 - val_loss: 0.2561 - val_categorical_accuracy: 0.8519 - val_mean_dice_coef: 0.7936 - val_weighted_mean_dice_coef: 0.7426 - lr: 0.0100
# Epoch 45/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2389 - categorical_accuracy: 0.8602 - mean_dice_coef: 0.8061 - weighted_mean_dice_coef: 0.7611
# Epoch 45: val_loss did not improve from 0.24352
# 46/46 [==============================] - 8s 184ms/step - loss: 0.2389 - categorical_accuracy: 0.8602 - mean_dice_coef: 0.8061 - weighted_mean_dice_coef: 0.7611 - val_loss: 0.2436 - val_categorical_accuracy: 0.8508 - val_mean_dice_coef: 0.7994 - val_weighted_mean_dice_coef: 0.7552 - lr: 0.0100
# Epoch 46/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2388 - categorical_accuracy: 0.8606 - mean_dice_coef: 0.8063 - weighted_mean_dice_coef: 0.7612
# Epoch 46: val_loss did not improve from 0.24352
# 46/46 [==============================] - 8s 180ms/step - loss: 0.2388 - categorical_accuracy: 0.8606 - mean_dice_coef: 0.8063 - weighted_mean_dice_coef: 0.7612 - val_loss: 0.2540 - val_categorical_accuracy: 0.8488 - val_mean_dice_coef: 0.7932 - val_weighted_mean_dice_coef: 0.7451 - lr: 0.0100
# Epoch 47/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2386 - categorical_accuracy: 0.8605 - mean_dice_coef: 0.8064 - weighted_mean_dice_coef: 0.7614
# Epoch 47: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 190ms/step - loss: 0.2386 - categorical_accuracy: 0.8605 - mean_dice_coef: 0.8064 - weighted_mean_dice_coef: 0.7614 - val_loss: 0.2477 - val_categorical_accuracy: 0.8513 - val_mean_dice_coef: 0.7968 - val_weighted_mean_dice_coef: 0.7517 - lr: 0.0100
# Epoch 48/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2390 - categorical_accuracy: 0.8602 - mean_dice_coef: 0.8061 - weighted_mean_dice_coef: 0.7610
# Epoch 48: val_loss did not improve from 0.24352
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 46/46 [==============================] - 8s 180ms/step - loss: 0.2390 - categorical_accuracy: 0.8602 - mean_dice_coef: 0.8061 - weighted_mean_dice_coef: 0.7610 - val_loss: 0.2517 - val_categorical_accuracy: 0.8518 - val_mean_dice_coef: 0.7941 - val_weighted_mean_dice_coef: 0.7474 - lr: 0.0100
# Epoch 49/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2358 - categorical_accuracy: 0.8622 - mean_dice_coef: 0.8086 - weighted_mean_dice_coef: 0.7642
# Epoch 49: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 192ms/step - loss: 0.2358 - categorical_accuracy: 0.8622 - mean_dice_coef: 0.8086 - weighted_mean_dice_coef: 0.7642 - val_loss: 0.2442 - val_categorical_accuracy: 0.8543 - val_mean_dice_coef: 0.8003 - val_weighted_mean_dice_coef: 0.7547 - lr: 0.0050
# Epoch 50/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2347 - categorical_accuracy: 0.8630 - mean_dice_coef: 0.8095 - weighted_mean_dice_coef: 0.7653
# Epoch 50: val_loss did not improve from 0.24352
# 46/46 [==============================] - 9s 199ms/step - loss: 0.2347 - categorical_accuracy: 0.8630 - mean_dice_coef: 0.8095 - weighted_mean_dice_coef: 0.7653 - val_loss: 0.2442 - val_categorical_accuracy: 0.8565 - val_mean_dice_coef: 0.8014 - val_weighted_mean_dice_coef: 0.7547 - lr: 0.0050
# Epoch 51/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2345 - categorical_accuracy: 0.8631 - mean_dice_coef: 0.8098 - weighted_mean_dice_coef: 0.7656
# Epoch 51: val_loss improved from 0.24352 to 0.24117, saving model to ./weights/eddynetfirst.h5
# 46/46 [==============================] - 13s 281ms/step - loss: 0.2345 - categorical_accuracy: 0.8631 - mean_dice_coef: 0.8098 - weighted_mean_dice_coef: 0.7656 - val_loss: 0.2412 - val_categorical_accuracy: 0.8563 - val_mean_dice_coef: 0.8027 - val_weighted_mean_dice_coef: 0.7580 - lr: 0.0050
# Epoch 52/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2350 - categorical_accuracy: 0.8627 - mean_dice_coef: 0.8093 - weighted_mean_dice_coef: 0.7650
# Epoch 52: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 194ms/step - loss: 0.2350 - categorical_accuracy: 0.8627 - mean_dice_coef: 0.8093 - weighted_mean_dice_coef: 0.7650 - val_loss: 0.2436 - val_categorical_accuracy: 0.8580 - val_mean_dice_coef: 0.8026 - val_weighted_mean_dice_coef: 0.7554 - lr: 0.0050
# Epoch 53/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2346 - categorical_accuracy: 0.8629 - mean_dice_coef: 0.8096 - weighted_mean_dice_coef: 0.7654
# Epoch 53: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 190ms/step - loss: 0.2346 - categorical_accuracy: 0.8629 - mean_dice_coef: 0.8096 - weighted_mean_dice_coef: 0.7654 - val_loss: 0.2499 - val_categorical_accuracy: 0.8503 - val_mean_dice_coef: 0.7955 - val_weighted_mean_dice_coef: 0.7494 - lr: 0.0050
# Epoch 54/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2343 - categorical_accuracy: 0.8630 - mean_dice_coef: 0.8098 - weighted_mean_dice_coef: 0.7657
# Epoch 54: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 191ms/step - loss: 0.2343 - categorical_accuracy: 0.8630 - mean_dice_coef: 0.8098 - weighted_mean_dice_coef: 0.7657 - val_loss: 0.2488 - val_categorical_accuracy: 0.8544 - val_mean_dice_coef: 0.7984 - val_weighted_mean_dice_coef: 0.7501 - lr: 0.0050
# Epoch 55/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2341 - categorical_accuracy: 0.8632 - mean_dice_coef: 0.8100 - weighted_mean_dice_coef: 0.7658
# Epoch 55: val_loss did not improve from 0.24117
# 46/46 [==============================] - 10s 212ms/step - loss: 0.2341 - categorical_accuracy: 0.8632 - mean_dice_coef: 0.8100 - weighted_mean_dice_coef: 0.7658 - val_loss: 0.2513 - val_categorical_accuracy: 0.8538 - val_mean_dice_coef: 0.7961 - val_weighted_mean_dice_coef: 0.7478 - lr: 0.0050
# Epoch 56/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2340 - categorical_accuracy: 0.8635 - mean_dice_coef: 0.8101 - weighted_mean_dice_coef: 0.7660
# Epoch 56: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 188ms/step - loss: 0.2340 - categorical_accuracy: 0.8635 - mean_dice_coef: 0.8101 - weighted_mean_dice_coef: 0.7660 - val_loss: 0.2430 - val_categorical_accuracy: 0.8498 - val_mean_dice_coef: 0.7996 - val_weighted_mean_dice_coef: 0.7561 - lr: 0.0050
# Epoch 57/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2341 - categorical_accuracy: 0.8632 - mean_dice_coef: 0.8100 - weighted_mean_dice_coef: 0.7659
# Epoch 57: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2341 - categorical_accuracy: 0.8632 - mean_dice_coef: 0.8100 - weighted_mean_dice_coef: 0.7659 - val_loss: 0.2500 - val_categorical_accuracy: 0.8477 - val_mean_dice_coef: 0.7946 - val_weighted_mean_dice_coef: 0.7490 - lr: 0.0050
# Epoch 58/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2339 - categorical_accuracy: 0.8634 - mean_dice_coef: 0.8102 - weighted_mean_dice_coef: 0.7661
# Epoch 58: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 200ms/step - loss: 0.2339 - categorical_accuracy: 0.8634 - mean_dice_coef: 0.8102 - weighted_mean_dice_coef: 0.7661 - val_loss: 0.2472 - val_categorical_accuracy: 0.8563 - val_mean_dice_coef: 0.7998 - val_weighted_mean_dice_coef: 0.7517 - lr: 0.0050
# Epoch 59/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2337 - categorical_accuracy: 0.8635 - mean_dice_coef: 0.8103 - weighted_mean_dice_coef: 0.7663
# Epoch 59: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2337 - categorical_accuracy: 0.8635 - mean_dice_coef: 0.8103 - weighted_mean_dice_coef: 0.7663 - val_loss: 0.2454 - val_categorical_accuracy: 0.8560 - val_mean_dice_coef: 0.8000 - val_weighted_mean_dice_coef: 0.7536 - lr: 0.0050
# Epoch 60/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2339 - categorical_accuracy: 0.8633 - mean_dice_coef: 0.8101 - weighted_mean_dice_coef: 0.7661
# Epoch 60: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 187ms/step - loss: 0.2339 - categorical_accuracy: 0.8633 - mean_dice_coef: 0.8101 - weighted_mean_dice_coef: 0.7661 - val_loss: 0.2454 - val_categorical_accuracy: 0.8558 - val_mean_dice_coef: 0.7996 - val_weighted_mean_dice_coef: 0.7536 - lr: 0.0050
# Epoch 61/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2336 - categorical_accuracy: 0.8637 - mean_dice_coef: 0.8104 - weighted_mean_dice_coef: 0.7663
# Epoch 61: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2336 - categorical_accuracy: 0.8637 - mean_dice_coef: 0.8104 - weighted_mean_dice_coef: 0.7663 - val_loss: 0.2432 - val_categorical_accuracy: 0.8523 - val_mean_dice_coef: 0.8008 - val_weighted_mean_dice_coef: 0.7559 - lr: 0.0050
# Epoch 62/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2338 - categorical_accuracy: 0.8636 - mean_dice_coef: 0.8103 - weighted_mean_dice_coef: 0.7662
# Epoch 62: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 194ms/step - loss: 0.2338 - categorical_accuracy: 0.8636 - mean_dice_coef: 0.8103 - weighted_mean_dice_coef: 0.7662 - val_loss: 0.2522 - val_categorical_accuracy: 0.8507 - val_mean_dice_coef: 0.7948 - val_weighted_mean_dice_coef: 0.7466 - lr: 0.0050
# Epoch 63/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2341 - categorical_accuracy: 0.8633 - mean_dice_coef: 0.8100 - weighted_mean_dice_coef: 0.7659
# Epoch 63: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 192ms/step - loss: 0.2341 - categorical_accuracy: 0.8633 - mean_dice_coef: 0.8100 - weighted_mean_dice_coef: 0.7659 - val_loss: 0.2443 - val_categorical_accuracy: 0.8522 - val_mean_dice_coef: 0.7996 - val_weighted_mean_dice_coef: 0.7547 - lr: 0.0050
# Epoch 64/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2336 - categorical_accuracy: 0.8636 - mean_dice_coef: 0.8104 - weighted_mean_dice_coef: 0.7664
# Epoch 64: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 191ms/step - loss: 0.2336 - categorical_accuracy: 0.8636 - mean_dice_coef: 0.8104 - weighted_mean_dice_coef: 0.7664 - val_loss: 0.2459 - val_categorical_accuracy: 0.8519 - val_mean_dice_coef: 0.7990 - val_weighted_mean_dice_coef: 0.7530 - lr: 0.0050
# Epoch 65/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2332 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8108 - weighted_mean_dice_coef: 0.7668
# Epoch 65: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 200ms/step - loss: 0.2332 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8108 - weighted_mean_dice_coef: 0.7668 - val_loss: 0.2481 - val_categorical_accuracy: 0.8559 - val_mean_dice_coef: 0.7994 - val_weighted_mean_dice_coef: 0.7507 - lr: 0.0050
# Epoch 66/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2332 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8108 - weighted_mean_dice_coef: 0.7668
# Epoch 66: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 199ms/step - loss: 0.2332 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8108 - weighted_mean_dice_coef: 0.7668 - val_loss: 0.2461 - val_categorical_accuracy: 0.8558 - val_mean_dice_coef: 0.8002 - val_weighted_mean_dice_coef: 0.7528 - lr: 0.0050
# Epoch 67/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2332 - categorical_accuracy: 0.8637 - mean_dice_coef: 0.8107 - weighted_mean_dice_coef: 0.7667
# Epoch 67: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 190ms/step - loss: 0.2332 - categorical_accuracy: 0.8637 - mean_dice_coef: 0.8107 - weighted_mean_dice_coef: 0.7667 - val_loss: 0.2496 - val_categorical_accuracy: 0.8480 - val_mean_dice_coef: 0.7953 - val_weighted_mean_dice_coef: 0.7495 - lr: 0.0050
# Epoch 68/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2333 - categorical_accuracy: 0.8638 - mean_dice_coef: 0.8106 - weighted_mean_dice_coef: 0.7666
# Epoch 68: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 187ms/step - loss: 0.2333 - categorical_accuracy: 0.8638 - mean_dice_coef: 0.8106 - weighted_mean_dice_coef: 0.7666 - val_loss: 0.2437 - val_categorical_accuracy: 0.8543 - val_mean_dice_coef: 0.8011 - val_weighted_mean_dice_coef: 0.7553 - lr: 0.0050
# Epoch 69/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2330 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8109 - weighted_mean_dice_coef: 0.7670
# Epoch 69: val_loss did not improve from 0.24117
# 46/46 [==============================] - 8s 183ms/step - loss: 0.2330 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8109 - weighted_mean_dice_coef: 0.7670 - val_loss: 0.2449 - val_categorical_accuracy: 0.8561 - val_mean_dice_coef: 0.8008 - val_weighted_mean_dice_coef: 0.7541 - lr: 0.0050
# Epoch 70/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2331 - categorical_accuracy: 0.8638 - mean_dice_coef: 0.8109 - weighted_mean_dice_coef: 0.7670
# Epoch 70: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 199ms/step - loss: 0.2331 - categorical_accuracy: 0.8638 - mean_dice_coef: 0.8109 - weighted_mean_dice_coef: 0.7670 - val_loss: 0.2446 - val_categorical_accuracy: 0.8526 - val_mean_dice_coef: 0.7999 - val_weighted_mean_dice_coef: 0.7543 - lr: 0.0050
# Epoch 71/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2329 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8109 - weighted_mean_dice_coef: 0.7670
# Epoch 71: val_loss did not improve from 0.24117
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 46/46 [==============================] - 9s 192ms/step - loss: 0.2329 - categorical_accuracy: 0.8639 - mean_dice_coef: 0.8109 - weighted_mean_dice_coef: 0.7670 - val_loss: 0.2504 - val_categorical_accuracy: 0.8588 - val_mean_dice_coef: 0.7986 - val_weighted_mean_dice_coef: 0.7485 - lr: 0.0050
# Epoch 72/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2316 - categorical_accuracy: 0.8647 - mean_dice_coef: 0.8120 - weighted_mean_dice_coef: 0.7684
# Epoch 72: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 193ms/step - loss: 0.2316 - categorical_accuracy: 0.8647 - mean_dice_coef: 0.8120 - weighted_mean_dice_coef: 0.7684 - val_loss: 0.2439 - val_categorical_accuracy: 0.8573 - val_mean_dice_coef: 0.8020 - val_weighted_mean_dice_coef: 0.7550 - lr: 0.0025
# Epoch 73/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2310 - categorical_accuracy: 0.8653 - mean_dice_coef: 0.8125 - weighted_mean_dice_coef: 0.7689
# Epoch 73: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2310 - categorical_accuracy: 0.8653 - mean_dice_coef: 0.8125 - weighted_mean_dice_coef: 0.7689 - val_loss: 0.2484 - val_categorical_accuracy: 0.8569 - val_mean_dice_coef: 0.7986 - val_weighted_mean_dice_coef: 0.7505 - lr: 0.0025
# Epoch 74/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2308 - categorical_accuracy: 0.8655 - mean_dice_coef: 0.8127 - weighted_mean_dice_coef: 0.7693
# Epoch 74: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 190ms/step - loss: 0.2308 - categorical_accuracy: 0.8655 - mean_dice_coef: 0.8127 - weighted_mean_dice_coef: 0.7693 - val_loss: 0.2438 - val_categorical_accuracy: 0.8574 - val_mean_dice_coef: 0.8021 - val_weighted_mean_dice_coef: 0.7552 - lr: 0.0025
# Epoch 75/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2307 - categorical_accuracy: 0.8654 - mean_dice_coef: 0.8128 - weighted_mean_dice_coef: 0.7693
# Epoch 75: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 201ms/step - loss: 0.2307 - categorical_accuracy: 0.8654 - mean_dice_coef: 0.8128 - weighted_mean_dice_coef: 0.7693 - val_loss: 0.2427 - val_categorical_accuracy: 0.8546 - val_mean_dice_coef: 0.8016 - val_weighted_mean_dice_coef: 0.7563 - lr: 0.0025
# Epoch 76/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2307 - categorical_accuracy: 0.8653 - mean_dice_coef: 0.8127 - weighted_mean_dice_coef: 0.7692
# Epoch 76: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 195ms/step - loss: 0.2307 - categorical_accuracy: 0.8653 - mean_dice_coef: 0.8127 - weighted_mean_dice_coef: 0.7692 - val_loss: 0.2490 - val_categorical_accuracy: 0.8546 - val_mean_dice_coef: 0.7978 - val_weighted_mean_dice_coef: 0.7500 - lr: 0.0025
# Epoch 77/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2308 - categorical_accuracy: 0.8654 - mean_dice_coef: 0.8127 - weighted_mean_dice_coef: 0.7691
# Epoch 77: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 199ms/step - loss: 0.2308 - categorical_accuracy: 0.8654 - mean_dice_coef: 0.8127 - weighted_mean_dice_coef: 0.7691 - val_loss: 0.2443 - val_categorical_accuracy: 0.8524 - val_mean_dice_coef: 0.8001 - val_weighted_mean_dice_coef: 0.7547 - lr: 0.0025
# Epoch 78/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2305 - categorical_accuracy: 0.8655 - mean_dice_coef: 0.8130 - weighted_mean_dice_coef: 0.7695
# Epoch 78: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 191ms/step - loss: 0.2305 - categorical_accuracy: 0.8655 - mean_dice_coef: 0.8130 - weighted_mean_dice_coef: 0.7695 - val_loss: 0.2456 - val_categorical_accuracy: 0.8557 - val_mean_dice_coef: 0.8007 - val_weighted_mean_dice_coef: 0.7535 - lr: 0.0025
# Epoch 79/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2306 - categorical_accuracy: 0.8655 - mean_dice_coef: 0.8129 - weighted_mean_dice_coef: 0.7694
# Epoch 79: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 185ms/step - loss: 0.2306 - categorical_accuracy: 0.8655 - mean_dice_coef: 0.8129 - weighted_mean_dice_coef: 0.7694 - val_loss: 0.2452 - val_categorical_accuracy: 0.8535 - val_mean_dice_coef: 0.8000 - val_weighted_mean_dice_coef: 0.7537 - lr: 0.0025
# Epoch 80/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2304 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8130 - weighted_mean_dice_coef: 0.7696
# Epoch 80: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2304 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8130 - weighted_mean_dice_coef: 0.7696 - val_loss: 0.2444 - val_categorical_accuracy: 0.8563 - val_mean_dice_coef: 0.8014 - val_weighted_mean_dice_coef: 0.7545 - lr: 0.0025
# Epoch 81/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2301 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7699
# Epoch 81: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2301 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7699 - val_loss: 0.2427 - val_categorical_accuracy: 0.8570 - val_mean_dice_coef: 0.8025 - val_weighted_mean_dice_coef: 0.7563 - lr: 0.0025
# Epoch 82/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2300 - categorical_accuracy: 0.8658 - mean_dice_coef: 0.8133 - weighted_mean_dice_coef: 0.7700
# Epoch 82: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 197ms/step - loss: 0.2300 - categorical_accuracy: 0.8658 - mean_dice_coef: 0.8133 - weighted_mean_dice_coef: 0.7700 - val_loss: 0.2454 - val_categorical_accuracy: 0.8561 - val_mean_dice_coef: 0.8004 - val_weighted_mean_dice_coef: 0.7537 - lr: 0.0025
# Epoch 83/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2304 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8130 - weighted_mean_dice_coef: 0.7696
# Epoch 83: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2304 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8130 - weighted_mean_dice_coef: 0.7696 - val_loss: 0.2437 - val_categorical_accuracy: 0.8542 - val_mean_dice_coef: 0.8010 - val_weighted_mean_dice_coef: 0.7555 - lr: 0.0025
# Epoch 84/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2302 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7698
# Epoch 84: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 193ms/step - loss: 0.2302 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7698 - val_loss: 0.2463 - val_categorical_accuracy: 0.8521 - val_mean_dice_coef: 0.7989 - val_weighted_mean_dice_coef: 0.7527 - lr: 0.0025
# Epoch 85/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2301 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8131 - weighted_mean_dice_coef: 0.7698
# Epoch 85: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 198ms/step - loss: 0.2301 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8131 - weighted_mean_dice_coef: 0.7698 - val_loss: 0.2424 - val_categorical_accuracy: 0.8572 - val_mean_dice_coef: 0.8029 - val_weighted_mean_dice_coef: 0.7566 - lr: 0.0025
# Epoch 86/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2302 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7698
# Epoch 86: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 199ms/step - loss: 0.2302 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7698 - val_loss: 0.2472 - val_categorical_accuracy: 0.8540 - val_mean_dice_coef: 0.7986 - val_weighted_mean_dice_coef: 0.7518 - lr: 0.0025
# Epoch 87/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2302 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7699
# Epoch 87: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 193ms/step - loss: 0.2302 - categorical_accuracy: 0.8656 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7699 - val_loss: 0.2425 - val_categorical_accuracy: 0.8529 - val_mean_dice_coef: 0.8014 - val_weighted_mean_dice_coef: 0.7566 - lr: 0.0025
# Epoch 88/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2300 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8133 - weighted_mean_dice_coef: 0.7700
# Epoch 88: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 196ms/step - loss: 0.2300 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8133 - weighted_mean_dice_coef: 0.7700 - val_loss: 0.2418 - val_categorical_accuracy: 0.8515 - val_mean_dice_coef: 0.8016 - val_weighted_mean_dice_coef: 0.7573 - lr: 0.0025
# Epoch 89/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2301 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8133 - weighted_mean_dice_coef: 0.7699
# Epoch 89: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 195ms/step - loss: 0.2301 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8133 - weighted_mean_dice_coef: 0.7699 - val_loss: 0.2437 - val_categorical_accuracy: 0.8536 - val_mean_dice_coef: 0.8007 - val_weighted_mean_dice_coef: 0.7553 - lr: 0.0025
# Epoch 90/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2300 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7699
# Epoch 90: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 193ms/step - loss: 0.2300 - categorical_accuracy: 0.8657 - mean_dice_coef: 0.8132 - weighted_mean_dice_coef: 0.7699 - val_loss: 0.2462 - val_categorical_accuracy: 0.8563 - val_mean_dice_coef: 0.8005 - val_weighted_mean_dice_coef: 0.7526 - lr: 0.0025
# Epoch 91/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2299 - categorical_accuracy: 0.8659 - mean_dice_coef: 0.8134 - weighted_mean_dice_coef: 0.7701
# Epoch 91: val_loss did not improve from 0.24117
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 46/46 [==============================] - 9s 192ms/step - loss: 0.2299 - categorical_accuracy: 0.8659 - mean_dice_coef: 0.8134 - weighted_mean_dice_coef: 0.7701 - val_loss: 0.2424 - val_categorical_accuracy: 0.8550 - val_mean_dice_coef: 0.8022 - val_weighted_mean_dice_coef: 0.7567 - lr: 0.0025
# Epoch 92/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2291 - categorical_accuracy: 0.8663 - mean_dice_coef: 0.8140 - weighted_mean_dice_coef: 0.7709
# Epoch 92: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 196ms/step - loss: 0.2291 - categorical_accuracy: 0.8663 - mean_dice_coef: 0.8140 - weighted_mean_dice_coef: 0.7709 - val_loss: 0.2436 - val_categorical_accuracy: 0.8554 - val_mean_dice_coef: 0.8018 - val_weighted_mean_dice_coef: 0.7555 - lr: 0.0012
# Epoch 93/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2289 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8143 - weighted_mean_dice_coef: 0.7711
# Epoch 93: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 200ms/step - loss: 0.2289 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8143 - weighted_mean_dice_coef: 0.7711 - val_loss: 0.2443 - val_categorical_accuracy: 0.8551 - val_mean_dice_coef: 0.8010 - val_weighted_mean_dice_coef: 0.7548 - lr: 0.0012
# Epoch 94/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2287 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7714
# Epoch 94: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 199ms/step - loss: 0.2287 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7714 - val_loss: 0.2434 - val_categorical_accuracy: 0.8566 - val_mean_dice_coef: 0.8021 - val_weighted_mean_dice_coef: 0.7557 - lr: 0.0012
# Epoch 95/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2288 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8143 - weighted_mean_dice_coef: 0.7712
# Epoch 95: val_loss did not improve from 0.24117
# 46/46 [==============================] - 8s 184ms/step - loss: 0.2288 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8143 - weighted_mean_dice_coef: 0.7712 - val_loss: 0.2418 - val_categorical_accuracy: 0.8535 - val_mean_dice_coef: 0.8019 - val_weighted_mean_dice_coef: 0.7573 - lr: 0.0012
# Epoch 96/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2287 - categorical_accuracy: 0.8666 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7713
# Epoch 96: val_loss did not improve from 0.24117
# 46/46 [==============================] - 8s 185ms/step - loss: 0.2287 - categorical_accuracy: 0.8666 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7713 - val_loss: 0.2431 - val_categorical_accuracy: 0.8539 - val_mean_dice_coef: 0.8014 - val_weighted_mean_dice_coef: 0.7560 - lr: 0.0012
# Epoch 97/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2285 - categorical_accuracy: 0.8668 - mean_dice_coef: 0.8145 - weighted_mean_dice_coef: 0.7715
# Epoch 97: val_loss did not improve from 0.24117
# 46/46 [==============================] - 10s 221ms/step - loss: 0.2285 - categorical_accuracy: 0.8668 - mean_dice_coef: 0.8145 - weighted_mean_dice_coef: 0.7715 - val_loss: 0.2419 - val_categorical_accuracy: 0.8561 - val_mean_dice_coef: 0.8026 - val_weighted_mean_dice_coef: 0.7572 - lr: 0.0012
# Epoch 98/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2286 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7715
# Epoch 98: val_loss did not improve from 0.24117
# 46/46 [==============================] - 10s 210ms/step - loss: 0.2286 - categorical_accuracy: 0.8665 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7715 - val_loss: 0.2450 - val_categorical_accuracy: 0.8575 - val_mean_dice_coef: 0.8012 - val_weighted_mean_dice_coef: 0.7541 - lr: 0.0012
# Epoch 99/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2284 - categorical_accuracy: 0.8668 - mean_dice_coef: 0.8146 - weighted_mean_dice_coef: 0.7715
# Epoch 99: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 187ms/step - loss: 0.2284 - categorical_accuracy: 0.8668 - mean_dice_coef: 0.8146 - weighted_mean_dice_coef: 0.7715 - val_loss: 0.2462 - val_categorical_accuracy: 0.8589 - val_mean_dice_coef: 0.8008 - val_weighted_mean_dice_coef: 0.7528 - lr: 0.0012
# Epoch 100/100
# 46/46 [==============================] - ETA: 0s - loss: 0.2286 - categorical_accuracy: 0.8668 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7714
# Epoch 100: val_loss did not improve from 0.24117
# 46/46 [==============================] - 9s 186ms/step - loss: 0.2286 - categorical_accuracy: 0.8668 - mean_dice_coef: 0.8144 - weighted_mean_dice_coef: 0.7714 - val_loss: 0.2428 - val_categorical_accuracy: 0.8546 - val_mean_dice_coef: 0.8019 - val_weighted_mean_dice_coef: 0.7562 - lr: 0.0012

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(eddynet.history.history['loss'])
plt.semilogy(eddynet.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper right');

# %% [markdown]
# ## Performance on train dataset
# just to be sure...

# %%
randindex=np.random.randint(0,len(SSH_train))
predictedSEGM=eddynet.predict(np.reshape(SSH_train[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,6:-6]

plt.figure(figsize=(20, 10))
plt.subplot(131)
plt.imshow(SSH_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(132)
plt.imshow(predictedSEGMimage, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('Eddynet Segmentation');

plt.subplot(133)
plt.imshow(Seg_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');
# Out:
# 2024-01-09 23:35:27.848958: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 476ms/step

# %% [markdown]
# ## Performance on test dataset (2009 data)

# %%
randindex=np.random.randint(0,len(SSH_test))
predictedSEGM=eddynet.predict(np.reshape(SSH_test[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,6:-6]

plt.figure(figsize=(20, 10))

plt.subplot(221)
plt.imshow(predictedSEGMimage, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('EddyNet Segmentation');

plt.subplot(222)
plt.imshow(Seg_test[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

plt.subplot(223)
plt.imshow(SSH_test[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(224)
plt.imshow(np.where(predictedSEGMimage == Seg_test[randindex,::-1,6:-6,0], 0, 1))
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.axis('off')
plt.title('Errors');
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
np.sum(np.where(predictedSEGMimage == Seg_test[randindex,::-1,6:-6,0], 0, 1))
# Out:
# 2064

# %% [markdown]
# Seems working nicely, but there are some false eddy detections that need to be dealt with, working on it..

# %%
#### if you wanna use some animations ;) 


#imageList=[]
#for i in range(1200,1400):
#    imageList.append(SSH_train[i,:,:,0])
  

#print('drawing the animation...')
#from matplotlib import animation, rc
#from IPython.display import HTML

#def getImageFromList(x):
#    return imageList[x]

#fig = plt.figure(figsize=(10, 10))
#ims = []
#for i in range(len(imageList)):
#    im = plt.imshow(getImageFromList(i), animated=True, cmap='viridis')
#    ims.append([im])
#plt.axis('off')

#ani = animation.ArtistAnimation(fig, ims, interval=50, blit=False, repeat=False)
#plt.close()

#HTML(ani.to_jshtml())

# %% [markdown]
# ## metrics on test dataset

# %%
Seg_test_categor = utils.to_categorical(np.reshape(Seg_test[:,:,:,0],(365,80*192)),3)
Seg_test_categor.shape
# Out:
# (365, 15360, 3)

# %%
eddynet.evaluate(SSH_test,Seg_test_categor)
# Out:
# 12/12 [==============================] - 1s 59ms/step - loss: 0.2542 - categorical_accuracy: 0.8506 - mean_dice_coef: 0.7946 - weighted_mean_dice_coef: 0.7462
# [0.2542441189289093,
#  0.8505622148513794,
#  0.7945871353149414,
#  0.7462493777275085]
