# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# to output everything in a cell instead of only the last output

# %matplotlib inline

# standard imports
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## import data

# %%
SSH_train = np.expand_dims(np.load('../Data/adt_train.npy'),3)[:,:-1,1:,:]
SSH_test = np.expand_dims(np.load('../Data/adt_test.npy'),3)[:,:-1,1:,:]

SSH_train[np.isnan(SSH_train)] = -1
SSH_test[np.isnan(SSH_test)] = -1

SSH_train=tf.pad(SSH_train, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=-1)
SSH_test=tf.pad(SSH_test, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=-1)
#######
Seg_train = np.expand_dims(np.load('../Data/grid_all_train.npy'),3)[:,:-1,1:,:]
Seg_test = np.expand_dims(np.load('../Data/grid_all_test.npy'),3)[:,:-1,1:,:]

Seg_train[Seg_train==-1] = 5
Seg_test[Seg_test==-1] = 5

Seg_train[Seg_train==10] = 6
Seg_test[Seg_test==10] = 6
Seg_train[Seg_train==11] = 7
Seg_test[Seg_test==11] = 7
Seg_train[Seg_train==12] = 8
Seg_test[Seg_test==12] = 8
Seg_train[Seg_train==13] = 9
Seg_test[Seg_test==13] = 9
Seg_train[Seg_train==14] = 10
Seg_test[Seg_test==14] = 10

Seg_train=tf.pad(Seg_train, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=5)
Seg_test=tf.pad(Seg_test, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=5)
######
SSH_train.shape
SSH_test.shape
#####
Seg_train.shape
Seg_test.shape
# Out:
# 2024-03-20 02:55:49.683477: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-03-20 02:55:49.683506: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-03-20 02:55:49.683511: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-03-20 02:55:49.683550: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-03-20 02:55:49.683565: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# TensorShape([7305, 80, 192, 1])
# TensorShape([365, 80, 192, 1])
# TensorShape([7305, 80, 192, 1])
# TensorShape([365, 80, 192, 1])

# %%
randindex=np.random.randint(0,len(SSH_train))

plt.figure(figsize=(20, 10))

plt.subplot(121)
plt.imshow(SSH_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(122)
plt.imshow(Seg_train[randindex,::-1,6:-6,0], cmap='coolwarm')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

# %% [markdown]
# ## Eddynet

# %%
from keras.models import Model, load_model
from keras.layers import Activation, Reshape, Permute, Lambda
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, UpSampling2D, AlphaDropout, concatenate, Conv2DTranspose
from keras.layers import BatchNormalization, LeakyReLU, add
import keras.utils as utils     #更改代码
from keras.optimizers import legacy     #更改代码
from keras import backend as K
from keras import regularizers
import matplotlib.pyplot as plt
import numpy as np
import pickle
from IPython.display import SVG 
from keras.utils import model_to_dot    #更改代码
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import tensorflow as tf

# %%
Seg_train_categor = utils.to_categorical(np.reshape(Seg_train[:,:,:,0],(7305,80*192)),11)    #更改代码
Seg_train_categor.shape
# Out:
# (7305, 15360, 11)

# %%
def ConvBNActi(nf,ker,inputs):
    conv1 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    #conv1 = LeakyReLU(0.3)(conv1)
    return conv1
  
def ConvTranspBNActi(nf,ker,inputs):
    conv1 = Conv2DTranspose(nf, ker, strides=(2, 2), padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    #conv1 = LeakyReLU(0.3)(conv1)
    return conv1

# %%
width = 192
height = 80
nbClass = 11
nf = 16
ker = 3

###################################### INPUT LAYER

img_input = Input(shape=(height, width, 1))
######################################ENCODER

conv1 = ConvBNActi(nf,ker,img_input)
conv1 = ConvBNActi(nf,ker,conv1)
conv1 = Dropout(0.2)(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = ConvBNActi(nf,ker,pool1)
conv2 = ConvBNActi(nf,ker,conv2)
conv2 = Dropout(0.3)(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = ConvBNActi(nf,ker,pool2)
conv3 = ConvBNActi(nf,ker,conv3)
conv3 = Dropout(0.4)(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = ConvBNActi(nf,ker,pool3)
conv4 = ConvBNActi(nf,ker,conv4)
conv4 = Dropout(0.4)(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

#######################################center

convC = ConvBNActi(nf,ker,pool4)
convC = ConvBNActi(nf,ker,convC)
convC = Dropout(0.5)(convC)

#######################################DECODER

#up4 = concatenate([ConvTranspBNActi(nf,ker,convC), conv4])
up4 = concatenate([UpSampling2D((2,2))(convC), conv4])
decod4 = ConvBNActi(nf,ker,up4)
decod4 = ConvBNActi(nf,ker,decod4)
decod4 = Dropout(0.4)(decod4)

#up3 = concatenate([ConvTranspBNActi(nf,ker,convC), conv3])
up3 = concatenate([UpSampling2D((2,2))(decod4), conv3])
decod3 = ConvBNActi(nf,ker,up3)
decod3 = ConvBNActi(nf,ker,decod3)
decod3 = Dropout(0.3)(decod3)



#up2 = concatenate([ConvTranspBNActi(nf,ker,decod3), conv2])
up2 = concatenate([UpSampling2D((2,2))(decod3), conv2])
decod2 = ConvBNActi(nf,ker,up2)
decod2 = ConvBNActi(nf,ker,decod2)
decod2 = Dropout(0.2)(decod2)


#up1 = concatenate([ConvTranspBNActi(nf,ker,decod2), conv1])
up1 = concatenate([UpSampling2D((2,2))(decod2), conv1])
decod1 = ConvBNActi(nf,ker,up1)
decod1 = ConvBNActi(nf,ker,decod1)
decod1 = Dropout(0.1)(decod1)


####################################### Segmentation Layer

x = Conv2D(nbClass, (1, 1), padding="valid", use_bias=False)(decod1) 
x = Reshape((height * width, nbClass))(x) 
x = Activation("softmax")(x)
eddynet = Model(img_input, x)

eddynet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 80, 192, 1)]         0         []
#
#  conv2d (Conv2D)             (None, 80, 192, 16)          144       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 80, 192, 16)          64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 80, 192, 16)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 80, 192, 16)          2304      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 80, 192, 16)          64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 80, 192, 16)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 80, 192, 16)          0         ['activation_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 40, 96, 16)           0         ['dropout[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 40, 96, 16)           2304      ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 40, 96, 16)           64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 40, 96, 16)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 40, 96, 16)           2304      ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 40, 96, 16)           64        ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 40, 96, 16)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 40, 96, 16)           0         ['activation_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 20, 48, 16)           0         ['dropout_1[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 20, 48, 16)           2304      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 20, 48, 16)           64        ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 20, 48, 16)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 20, 48, 16)           2304      ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 20, 48, 16)           64        ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 20, 48, 16)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 20, 48, 16)           0         ['activation_5[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 24, 16)           0         ['dropout_2[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 10, 24, 16)           2304      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 10, 24, 16)           64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 10, 24, 16)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 10, 24, 16)           2304      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 10, 24, 16)           64        ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 10, 24, 16)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 10, 24, 16)           0         ['activation_7[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 12, 16)            0         ['dropout_3[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 5, 12, 16)            2304      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 5, 12, 16)            64        ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 5, 12, 16)            0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 5, 12, 16)            2304      ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 5, 12, 16)            64        ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 5, 12, 16)            0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 5, 12, 16)            0         ['activation_9[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 10, 24, 16)           0         ['dropout_4[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 10, 24, 32)           0         ['up_sampling2d[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 10, 24, 16)           4608      ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 10, 24, 16)           64        ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 10, 24, 16)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 10, 24, 16)           2304      ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 10, 24, 16)           64        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 10, 24, 16)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 10, 24, 16)           0         ['activation_11[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 20, 48, 16)           0         ['dropout_5[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 20, 48, 32)           0         ['up_sampling2d_1[0][0]',
#  )                                                                   'dropout_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 20, 48, 16)           4608      ['concatenate_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 20, 48, 16)           64        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 20, 48, 16)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 20, 48, 16)           2304      ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 20, 48, 16)           64        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 20, 48, 16)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 20, 48, 16)           0         ['activation_13[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 40, 96, 16)           0         ['dropout_6[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 40, 96, 32)           0         ['up_sampling2d_2[0][0]',
#  )                                                                   'dropout_1[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 40, 96, 16)           4608      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 40, 96, 16)           64        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 40, 96, 16)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 40, 96, 16)           2304      ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 40, 96, 16)           64        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 40, 96, 16)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 40, 96, 16)           0         ['activation_15[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 80, 192, 16)          0         ['dropout_7[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 80, 192, 32)          0         ['up_sampling2d_3[0][0]',
#  )                                                                   'dropout[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 80, 192, 16)          4608      ['concatenate_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 80, 192, 16)          64        ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 80, 192, 16)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 80, 192, 16)          2304      ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 80, 192, 16)          64        ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 80, 192, 16)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 80, 192, 16)          0         ['activation_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 80, 192, 11)          176       ['dropout_8[0][0]']
#
#  reshape (Reshape)           (None, 15360, 11)            0         ['conv2d_18[0][0]']
#
#  activation_18 (Activation)  (None, 15360, 11)            0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 49856 (194.75 KB)
# Trainable params: 49280 (192.50 KB)
# Non-trainable params: 576 (2.25 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### calculate weights (some heavy data imbalance out there...)

# %%
unique, counts = np.unique(Seg_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0.0: 103639,
#  1.0: 2657999,
#  2.0: 5320154,
#  3.0: 6174869,
#  4.0: 2255325,
#  5.0: 80449775,
#  6.0: 109126,
#  7.0: 1917972,
#  8.0: 4965973,
#  9.0: 5937482,
#  10.0: 2312486}

# %%
freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
weightsSeg
# Out:
# [0.45261290432243334,
#  0.017647993393177602,
#  0.008817103563369157,
#  0.007596654891151969,
#  0.020798930881834175,
#  0.0005830761961866601,
#  0.4298549272499007,
#  0.024457264647801256,
#  0.009445953248451546,
#  0.007900377431219609,
#  0.020284814174473993]

# %% [markdown]
# ## loss functions

# %%
smooth = 1.  # to avoid zero division

def dice_coef_anti(y_true, y_pred):
    y_true_anti = y_true[:,:,1]
    y_pred_anti = y_pred[:,:,1]
    intersection_anti = K.sum(y_true_anti * y_pred_anti)
    return (2 * intersection_anti + smooth) / (K.sum(y_true_anti)+ K.sum(y_pred_anti) + smooth)

def dice_coef_cyc(y_true, y_pred):
    y_true_cyc = y_true[:,:,2]
    y_pred_cyc = y_pred[:,:,2]
    intersection_cyc = K.sum(y_true_cyc * y_pred_cyc)
    return (2 * intersection_cyc + smooth) / (K.sum(y_true_cyc) + K.sum(y_pred_cyc) + smooth)

def dice_coef_nn(y_true, y_pred):
    y_true_nn = y_true[:,:,0]
    y_pred_nn = y_pred[:,:,0]
    intersection_nn = K.sum(y_true_nn * y_pred_nn)
    return (2 * intersection_nn + smooth) / (K.sum(y_true_nn) + K.sum(y_pred_nn) + smooth)
    
def mean_dice_coef(y_true, y_pred):
    return (dice_coef_anti(y_true, y_pred) + dice_coef_cyc(y_true, y_pred) + dice_coef_nn(y_true, y_pred))/3.

def weighted_mean_dice_coef(y_true, y_pred):
    return (0.36*dice_coef_anti(y_true, y_pred) + 0.62*dice_coef_cyc(y_true, y_pred) + 0.02*dice_coef_nn(y_true, y_pred))
  
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_mean_dice_coef(y_true, y_pred)

# %%
eddynet.compile(optimizer=legacy.SGD(lr=0.2), loss=dice_coef_loss,    #更改代码
                metrics=['categorical_accuracy', mean_dice_coef, weighted_mean_dice_coef])
# Out:
# /Users/jjijack/miniconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#SVG(model_to_dot(eddynet).create(prog='dot', format='svg'))

# %% [markdown]
# ## Training

# %%
modelcheck = ModelCheckpoint('./weights/eddynetfirst.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
reducecall = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, verbose=1, mode='auto', min_delta=1e-30, min_lr=1e-30)


histeddynet=eddynet.fit(SSH_train, Seg_train_categor,
                              epochs=50,
                              batch_size=16,
                              shuffle=True,
                              verbose=1,
                              callbacks=[modelcheck,reducecall],#,MyCallback(alpha,beta),reducecall
                              validation_split=0.2
                              )
# Out:
# Epoch 1/50
# 2024-03-20 03:08:17.404368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 366/366 [==============================] - ETA: 0s - loss: 0.5988 - categorical_accuracy: 0.0641 - mean_dice_coef: 0.2718 - weighted_mean_dice_coef: 0.4012
# 2024-03-20 03:08:49.126299: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.68960, saving model to ./weights/eddynetfirst.h5
# 366/366 [==============================] - 37s 93ms/step - loss: 0.5988 - categorical_accuracy: 0.0641 - mean_dice_coef: 0.2718 - weighted_mean_dice_coef: 0.4012 - val_loss: 0.6896 - val_categorical_accuracy: 0.0570 - val_mean_dice_coef: 0.2125 - val_weighted_mean_dice_coef: 0.3108 - lr: 0.2000
# Epoch 2/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5950 - categorical_accuracy: 0.0647 - mean_dice_coef: 0.2748 - weighted_mean_dice_coef: 0.4051
# Epoch 2: val_loss improved from 0.68960 to 0.64953, saving model to ./weights/eddynetfirst.h5
# 366/366 [==============================] - 32s 87ms/step - loss: 0.5950 - categorical_accuracy: 0.0647 - mean_dice_coef: 0.2748 - weighted_mean_dice_coef: 0.4051 - val_loss: 0.6495 - val_categorical_accuracy: 0.0641 - val_mean_dice_coef: 0.2365 - val_weighted_mean_dice_coef: 0.3508 - lr: 0.2000
# Epoch 3/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5931 - categorical_accuracy: 0.0648 - mean_dice_coef: 0.2761 - weighted_mean_dice_coef: 0.4070
# Epoch 3: val_loss improved from 0.64953 to 0.64127, saving model to ./weights/eddynetfirst.h5
# 366/366 [==============================] - 33s 90ms/step - loss: 0.5931 - categorical_accuracy: 0.0648 - mean_dice_coef: 0.2761 - weighted_mean_dice_coef: 0.4070 - val_loss: 0.6413 - val_categorical_accuracy: 0.0645 - val_mean_dice_coef: 0.2400 - val_weighted_mean_dice_coef: 0.3589 - lr: 0.2000
# Epoch 4/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5918 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2771 - weighted_mean_dice_coef: 0.4082
# Epoch 4: val_loss did not improve from 0.64127
# 366/366 [==============================] - 31s 85ms/step - loss: 0.5918 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2771 - weighted_mean_dice_coef: 0.4082 - val_loss: 0.8300 - val_categorical_accuracy: 0.0573 - val_mean_dice_coef: 0.1250 - val_weighted_mean_dice_coef: 0.1706 - lr: 0.2000
# Epoch 5/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5917 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2772 - weighted_mean_dice_coef: 0.4084
# Epoch 5: val_loss improved from 0.64127 to 0.64076, saving model to ./weights/eddynetfirst.h5
# 366/366 [==============================] - 33s 90ms/step - loss: 0.5917 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2772 - weighted_mean_dice_coef: 0.4084 - val_loss: 0.6408 - val_categorical_accuracy: 0.0632 - val_mean_dice_coef: 0.2381 - val_weighted_mean_dice_coef: 0.3594 - lr: 0.2000
# Epoch 6/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5909 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2775 - weighted_mean_dice_coef: 0.4091
# Epoch 6: val_loss did not improve from 0.64076
# 366/366 [==============================] - 33s 89ms/step - loss: 0.5909 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2775 - weighted_mean_dice_coef: 0.4091 - val_loss: 0.6687 - val_categorical_accuracy: 0.0647 - val_mean_dice_coef: 0.2246 - val_weighted_mean_dice_coef: 0.3315 - lr: 0.2000
# Epoch 7/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5900 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2782 - weighted_mean_dice_coef: 0.4101
# Epoch 7: val_loss did not improve from 0.64076
# 366/366 [==============================] - 32s 88ms/step - loss: 0.5900 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2782 - weighted_mean_dice_coef: 0.4101 - val_loss: 0.6670 - val_categorical_accuracy: 0.0614 - val_mean_dice_coef: 0.2218 - val_weighted_mean_dice_coef: 0.3332 - lr: 0.2000
# Epoch 8/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5900 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2783 - weighted_mean_dice_coef: 0.4099
# Epoch 8: val_loss improved from 0.64076 to 0.63445, saving model to ./weights/eddynetfirst.h5
# 366/366 [==============================] - 36s 98ms/step - loss: 0.5900 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2783 - weighted_mean_dice_coef: 0.4099 - val_loss: 0.6345 - val_categorical_accuracy: 0.0605 - val_mean_dice_coef: 0.2450 - val_weighted_mean_dice_coef: 0.3657 - lr: 0.2000
# Epoch 9/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5902 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2782 - weighted_mean_dice_coef: 0.4098
# Epoch 9: val_loss did not improve from 0.63445
# 366/366 [==============================] - 36s 97ms/step - loss: 0.5902 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2782 - weighted_mean_dice_coef: 0.4098 - val_loss: 0.6358 - val_categorical_accuracy: 0.0639 - val_mean_dice_coef: 0.2437 - val_weighted_mean_dice_coef: 0.3645 - lr: 0.2000
# Epoch 10/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5900 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2785 - weighted_mean_dice_coef: 0.4101
# Epoch 10: val_loss did not improve from 0.63445
# 366/366 [==============================] - 33s 91ms/step - loss: 0.5900 - categorical_accuracy: 0.0650 - mean_dice_coef: 0.2785 - weighted_mean_dice_coef: 0.4101 - val_loss: 0.6474 - val_categorical_accuracy: 0.0651 - val_mean_dice_coef: 0.2387 - val_weighted_mean_dice_coef: 0.3527 - lr: 0.2000
# Epoch 11/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5891 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2790 - weighted_mean_dice_coef: 0.4108
# Epoch 11: val_loss improved from 0.63445 to 0.63190, saving model to ./weights/eddynetfirst.h5
# 366/366 [==============================] - 34s 92ms/step - loss: 0.5891 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2790 - weighted_mean_dice_coef: 0.4108 - val_loss: 0.6319 - val_categorical_accuracy: 0.0619 - val_mean_dice_coef: 0.2466 - val_weighted_mean_dice_coef: 0.3682 - lr: 0.2000
# Epoch 12/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5891 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2790 - weighted_mean_dice_coef: 0.4108
# Epoch 12: val_loss did not improve from 0.63190
# 366/366 [==============================] - 33s 91ms/step - loss: 0.5891 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2790 - weighted_mean_dice_coef: 0.4108 - val_loss: 0.6561 - val_categorical_accuracy: 0.0638 - val_mean_dice_coef: 0.2319 - val_weighted_mean_dice_coef: 0.3441 - lr: 0.2000
# Epoch 13/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5886 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2795 - weighted_mean_dice_coef: 0.4114
# Epoch 13: val_loss did not improve from 0.63190
# 366/366 [==============================] - 32s 88ms/step - loss: 0.5886 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2795 - weighted_mean_dice_coef: 0.4114 - val_loss: 0.7331 - val_categorical_accuracy: 0.0587 - val_mean_dice_coef: 0.1852 - val_weighted_mean_dice_coef: 0.2674 - lr: 0.2000
# Epoch 14/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5884 - categorical_accuracy: 0.0653 - mean_dice_coef: 0.2793 - weighted_mean_dice_coef: 0.4115
# Epoch 14: val_loss did not improve from 0.63190
# 366/366 [==============================] - 32s 87ms/step - loss: 0.5884 - categorical_accuracy: 0.0653 - mean_dice_coef: 0.2793 - weighted_mean_dice_coef: 0.4115 - val_loss: 0.6657 - val_categorical_accuracy: 0.0580 - val_mean_dice_coef: 0.2236 - val_weighted_mean_dice_coef: 0.3346 - lr: 0.2000
# Epoch 15/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5886 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2791 - weighted_mean_dice_coef: 0.4114
# Epoch 15: val_loss did not improve from 0.63190
# 366/366 [==============================] - 34s 92ms/step - loss: 0.5886 - categorical_accuracy: 0.0651 - mean_dice_coef: 0.2791 - weighted_mean_dice_coef: 0.4114 - val_loss: 0.6379 - val_categorical_accuracy: 0.0647 - val_mean_dice_coef: 0.2430 - val_weighted_mean_dice_coef: 0.3623 - lr: 0.2000
# Epoch 16/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5885 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2792 - weighted_mean_dice_coef: 0.4113
# Epoch 16: val_loss did not improve from 0.63190
# 366/366 [==============================] - 34s 93ms/step - loss: 0.5885 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2792 - weighted_mean_dice_coef: 0.4113 - val_loss: 0.6939 - val_categorical_accuracy: 0.0621 - val_mean_dice_coef: 0.2107 - val_weighted_mean_dice_coef: 0.3064 - lr: 0.2000
# Epoch 17/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5874 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2800 - weighted_mean_dice_coef: 0.4126
# Epoch 17: val_loss did not improve from 0.63190
# 366/366 [==============================] - 35s 94ms/step - loss: 0.5874 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2800 - weighted_mean_dice_coef: 0.4126 - val_loss: 0.7070 - val_categorical_accuracy: 0.0636 - val_mean_dice_coef: 0.2008 - val_weighted_mean_dice_coef: 0.2934 - lr: 0.2000
# Epoch 18/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5876 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2801 - weighted_mean_dice_coef: 0.4123
# Epoch 18: val_loss improved from 0.63190 to 0.62102, saving model to ./weights/eddynetfirst.h5
# 366/366 [==============================] - 32s 88ms/step - loss: 0.5876 - categorical_accuracy: 0.0652 - mean_dice_coef: 0.2801 - weighted_mean_dice_coef: 0.4123 - val_loss: 0.6210 - val_categorical_accuracy: 0.0630 - val_mean_dice_coef: 0.2555 - val_weighted_mean_dice_coef: 0.3791 - lr: 0.2000
# Epoch 19/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5874 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2801 - weighted_mean_dice_coef: 0.4126
# Epoch 19: val_loss did not improve from 0.62102
# 366/366 [==============================] - 32s 87ms/step - loss: 0.5874 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2801 - weighted_mean_dice_coef: 0.4126 - val_loss: 0.7407 - val_categorical_accuracy: 0.0631 - val_mean_dice_coef: 0.1785 - val_weighted_mean_dice_coef: 0.2598 - lr: 0.2000
# Epoch 20/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5874 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2801 - weighted_mean_dice_coef: 0.4126
# Epoch 20: val_loss did not improve from 0.62102
# 366/366 [==============================] - 32s 87ms/step - loss: 0.5874 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2801 - weighted_mean_dice_coef: 0.4126 - val_loss: 0.6563 - val_categorical_accuracy: 0.0646 - val_mean_dice_coef: 0.2292 - val_weighted_mean_dice_coef: 0.3439 - lr: 0.2000
# Epoch 21/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5872 - categorical_accuracy: 0.0653 - mean_dice_coef: 0.2803 - weighted_mean_dice_coef: 0.4128
# Epoch 21: val_loss did not improve from 0.62102
# 366/366 [==============================] - 32s 87ms/step - loss: 0.5872 - categorical_accuracy: 0.0653 - mean_dice_coef: 0.2803 - weighted_mean_dice_coef: 0.4128 - val_loss: 0.6394 - val_categorical_accuracy: 0.0651 - val_mean_dice_coef: 0.2423 - val_weighted_mean_dice_coef: 0.3607 - lr: 0.2000
# Epoch 22/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5878 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2798 - weighted_mean_dice_coef: 0.4121
# Epoch 22: val_loss did not improve from 0.62102
# 366/366 [==============================] - 33s 90ms/step - loss: 0.5878 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2798 - weighted_mean_dice_coef: 0.4121 - val_loss: 0.6279 - val_categorical_accuracy: 0.0622 - val_mean_dice_coef: 0.2506 - val_weighted_mean_dice_coef: 0.3723 - lr: 0.2000
# Epoch 23/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5870 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2803 - weighted_mean_dice_coef: 0.4130
# Epoch 23: val_loss did not improve from 0.62102
# 366/366 [==============================] - 34s 93ms/step - loss: 0.5870 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2803 - weighted_mean_dice_coef: 0.4130 - val_loss: 0.6728 - val_categorical_accuracy: 0.0651 - val_mean_dice_coef: 0.2226 - val_weighted_mean_dice_coef: 0.3275 - lr: 0.2000
# Epoch 24/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5865 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2807 - weighted_mean_dice_coef: 0.4135
# Epoch 24: val_loss did not improve from 0.62102
# 366/366 [==============================] - 33s 89ms/step - loss: 0.5865 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2807 - weighted_mean_dice_coef: 0.4135 - val_loss: 0.6444 - val_categorical_accuracy: 0.0587 - val_mean_dice_coef: 0.2390 - val_weighted_mean_dice_coef: 0.3558 - lr: 0.2000
# Epoch 25/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5870 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2804 - weighted_mean_dice_coef: 0.4129
# Epoch 25: val_loss did not improve from 0.62102
# 366/366 [==============================] - 35s 95ms/step - loss: 0.5870 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2804 - weighted_mean_dice_coef: 0.4129 - val_loss: 0.6271 - val_categorical_accuracy: 0.0617 - val_mean_dice_coef: 0.2517 - val_weighted_mean_dice_coef: 0.3730 - lr: 0.2000
# Epoch 26/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5866 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2807 - weighted_mean_dice_coef: 0.4134
# Epoch 26: val_loss did not improve from 0.62102
# 366/366 [==============================] - 36s 98ms/step - loss: 0.5866 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2807 - weighted_mean_dice_coef: 0.4134 - val_loss: 0.6404 - val_categorical_accuracy: 0.0616 - val_mean_dice_coef: 0.2413 - val_weighted_mean_dice_coef: 0.3598 - lr: 0.2000
# Epoch 27/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5867 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2807 - weighted_mean_dice_coef: 0.4133
# Epoch 27: val_loss did not improve from 0.62102
# 366/366 [==============================] - 38s 103ms/step - loss: 0.5867 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2807 - weighted_mean_dice_coef: 0.4133 - val_loss: 0.6536 - val_categorical_accuracy: 0.0637 - val_mean_dice_coef: 0.2290 - val_weighted_mean_dice_coef: 0.3468 - lr: 0.2000
# Epoch 28/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5864 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2809 - weighted_mean_dice_coef: 0.4135
# Epoch 28: val_loss did not improve from 0.62102
# 366/366 [==============================] - 38s 104ms/step - loss: 0.5864 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2809 - weighted_mean_dice_coef: 0.4135 - val_loss: 0.6262 - val_categorical_accuracy: 0.0627 - val_mean_dice_coef: 0.2506 - val_weighted_mean_dice_coef: 0.3740 - lr: 0.2000
# Epoch 29/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5864 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2809 - weighted_mean_dice_coef: 0.4136
# Epoch 29: val_loss did not improve from 0.62102
# 366/366 [==============================] - 35s 96ms/step - loss: 0.5864 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2809 - weighted_mean_dice_coef: 0.4136 - val_loss: 0.6911 - val_categorical_accuracy: 0.0569 - val_mean_dice_coef: 0.2085 - val_weighted_mean_dice_coef: 0.3095 - lr: 0.2000
# Epoch 30/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5861 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2812 - weighted_mean_dice_coef: 0.4140
# Epoch 30: val_loss did not improve from 0.62102
# 366/366 [==============================] - 34s 93ms/step - loss: 0.5861 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2812 - weighted_mean_dice_coef: 0.4140 - val_loss: 0.6391 - val_categorical_accuracy: 0.0623 - val_mean_dice_coef: 0.2396 - val_weighted_mean_dice_coef: 0.3611 - lr: 0.2000
# Epoch 31/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5854 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2817 - weighted_mean_dice_coef: 0.4147
# Epoch 31: val_loss did not improve from 0.62102
# 366/366 [==============================] - 35s 96ms/step - loss: 0.5854 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2817 - weighted_mean_dice_coef: 0.4147 - val_loss: 0.6278 - val_categorical_accuracy: 0.0625 - val_mean_dice_coef: 0.2485 - val_weighted_mean_dice_coef: 0.3725 - lr: 0.2000
# Epoch 32/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5857 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2812 - weighted_mean_dice_coef: 0.4142
# Epoch 32: val_loss did not improve from 0.62102
# 366/366 [==============================] - 35s 95ms/step - loss: 0.5857 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2812 - weighted_mean_dice_coef: 0.4142 - val_loss: 0.6388 - val_categorical_accuracy: 0.0646 - val_mean_dice_coef: 0.2412 - val_weighted_mean_dice_coef: 0.3615 - lr: 0.2000
# Epoch 33/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5863 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2810 - weighted_mean_dice_coef: 0.4137
# Epoch 33: val_loss did not improve from 0.62102
# 366/366 [==============================] - 31s 84ms/step - loss: 0.5863 - categorical_accuracy: 0.0654 - mean_dice_coef: 0.2810 - weighted_mean_dice_coef: 0.4137 - val_loss: 0.7210 - val_categorical_accuracy: 0.0627 - val_mean_dice_coef: 0.1935 - val_weighted_mean_dice_coef: 0.2794 - lr: 0.2000
# Epoch 34/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5855 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2815 - weighted_mean_dice_coef: 0.4145
# Epoch 34: val_loss did not improve from 0.62102
# 366/366 [==============================] - 30s 82ms/step - loss: 0.5855 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2815 - weighted_mean_dice_coef: 0.4145 - val_loss: 0.6252 - val_categorical_accuracy: 0.0618 - val_mean_dice_coef: 0.2527 - val_weighted_mean_dice_coef: 0.3750 - lr: 0.2000
# Epoch 35/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5858 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2813 - weighted_mean_dice_coef: 0.4142
# Epoch 35: val_loss did not improve from 0.62102
# 366/366 [==============================] - 30s 83ms/step - loss: 0.5858 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2813 - weighted_mean_dice_coef: 0.4142 - val_loss: 0.6277 - val_categorical_accuracy: 0.0636 - val_mean_dice_coef: 0.2492 - val_weighted_mean_dice_coef: 0.3725 - lr: 0.2000
# Epoch 36/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5846 - categorical_accuracy: 0.0659 - mean_dice_coef: 0.2823 - weighted_mean_dice_coef: 0.4154
# Epoch 36: val_loss did not improve from 0.62102
# 366/366 [==============================] - 35s 94ms/step - loss: 0.5846 - categorical_accuracy: 0.0659 - mean_dice_coef: 0.2823 - weighted_mean_dice_coef: 0.4154 - val_loss: 0.6281 - val_categorical_accuracy: 0.0632 - val_mean_dice_coef: 0.2508 - val_weighted_mean_dice_coef: 0.3721 - lr: 0.2000
# Epoch 37/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5851 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2817 - weighted_mean_dice_coef: 0.4149
# Epoch 37: val_loss did not improve from 0.62102
# 366/366 [==============================] - 37s 101ms/step - loss: 0.5851 - categorical_accuracy: 0.0656 - mean_dice_coef: 0.2817 - weighted_mean_dice_coef: 0.4149 - val_loss: 0.6372 - val_categorical_accuracy: 0.0637 - val_mean_dice_coef: 0.2449 - val_weighted_mean_dice_coef: 0.3629 - lr: 0.2000
# Epoch 38/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5856 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2815 - weighted_mean_dice_coef: 0.4146
# Epoch 38: val_loss did not improve from 0.62102
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.10000000149011612.
# 366/366 [==============================] - 38s 104ms/step - loss: 0.5856 - categorical_accuracy: 0.0655 - mean_dice_coef: 0.2815 - weighted_mean_dice_coef: 0.4146 - val_loss: 0.6511 - val_categorical_accuracy: 0.0629 - val_mean_dice_coef: 0.2378 - val_weighted_mean_dice_coef: 0.3491 - lr: 0.2000
# Epoch 39/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5841 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4159
# Epoch 39: val_loss did not improve from 0.62102
# 366/366 [==============================] - 37s 99ms/step - loss: 0.5841 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4159 - val_loss: 0.6409 - val_categorical_accuracy: 0.0610 - val_mean_dice_coef: 0.2401 - val_weighted_mean_dice_coef: 0.3593 - lr: 0.1000
# Epoch 40/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5839 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4161
# Epoch 40: val_loss did not improve from 0.62102
# 366/366 [==============================] - 37s 100ms/step - loss: 0.5839 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4161 - val_loss: 0.6498 - val_categorical_accuracy: 0.0647 - val_mean_dice_coef: 0.2349 - val_weighted_mean_dice_coef: 0.3504 - lr: 0.1000
# Epoch 41/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5840 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4160
# Epoch 41: val_loss did not improve from 0.62102
# 366/366 [==============================] - 36s 99ms/step - loss: 0.5840 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4160 - val_loss: 0.6370 - val_categorical_accuracy: 0.0600 - val_mean_dice_coef: 0.2437 - val_weighted_mean_dice_coef: 0.3632 - lr: 0.1000
# Epoch 42/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5836 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2829 - weighted_mean_dice_coef: 0.4163
# Epoch 42: val_loss did not improve from 0.62102
# 366/366 [==============================] - 37s 100ms/step - loss: 0.5836 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2829 - weighted_mean_dice_coef: 0.4163 - val_loss: 0.6487 - val_categorical_accuracy: 0.0647 - val_mean_dice_coef: 0.2355 - val_weighted_mean_dice_coef: 0.3515 - lr: 0.1000
# Epoch 43/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5840 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2828 - weighted_mean_dice_coef: 0.4161
# Epoch 43: val_loss did not improve from 0.62102
# 366/366 [==============================] - 34s 94ms/step - loss: 0.5840 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2828 - weighted_mean_dice_coef: 0.4161 - val_loss: 0.6252 - val_categorical_accuracy: 0.0623 - val_mean_dice_coef: 0.2515 - val_weighted_mean_dice_coef: 0.3749 - lr: 0.1000
# Epoch 44/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5836 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2828 - weighted_mean_dice_coef: 0.4164
# Epoch 44: val_loss did not improve from 0.62102
# 366/366 [==============================] - 36s 99ms/step - loss: 0.5836 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2828 - weighted_mean_dice_coef: 0.4164 - val_loss: 0.6442 - val_categorical_accuracy: 0.0650 - val_mean_dice_coef: 0.2383 - val_weighted_mean_dice_coef: 0.3560 - lr: 0.1000
# Epoch 45/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5838 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2829 - weighted_mean_dice_coef: 0.4162
# Epoch 45: val_loss did not improve from 0.62102
# 366/366 [==============================] - 37s 101ms/step - loss: 0.5838 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2829 - weighted_mean_dice_coef: 0.4162 - val_loss: 0.6367 - val_categorical_accuracy: 0.0599 - val_mean_dice_coef: 0.2448 - val_weighted_mean_dice_coef: 0.3635 - lr: 0.1000
# Epoch 46/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5844 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2824 - weighted_mean_dice_coef: 0.4157
# Epoch 46: val_loss did not improve from 0.62102
# 366/366 [==============================] - 36s 99ms/step - loss: 0.5844 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2824 - weighted_mean_dice_coef: 0.4157 - val_loss: 0.6259 - val_categorical_accuracy: 0.0630 - val_mean_dice_coef: 0.2506 - val_weighted_mean_dice_coef: 0.3743 - lr: 0.1000
# Epoch 47/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5835 - categorical_accuracy: 0.0659 - mean_dice_coef: 0.2830 - weighted_mean_dice_coef: 0.4165
# Epoch 47: val_loss did not improve from 0.62102
# 366/366 [==============================] - 35s 95ms/step - loss: 0.5835 - categorical_accuracy: 0.0659 - mean_dice_coef: 0.2830 - weighted_mean_dice_coef: 0.4165 - val_loss: 0.6330 - val_categorical_accuracy: 0.0646 - val_mean_dice_coef: 0.2455 - val_weighted_mean_dice_coef: 0.3672 - lr: 0.1000
# Epoch 48/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5842 - categorical_accuracy: 0.0659 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4159
# Epoch 48: val_loss did not improve from 0.62102
# 366/366 [==============================] - 34s 93ms/step - loss: 0.5842 - categorical_accuracy: 0.0659 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4159 - val_loss: 0.6256 - val_categorical_accuracy: 0.0639 - val_mean_dice_coef: 0.2512 - val_weighted_mean_dice_coef: 0.3746 - lr: 0.1000
# Epoch 49/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5842 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4158
# Epoch 49: val_loss did not improve from 0.62102
# 366/366 [==============================] - 36s 98ms/step - loss: 0.5842 - categorical_accuracy: 0.0657 - mean_dice_coef: 0.2826 - weighted_mean_dice_coef: 0.4158 - val_loss: 0.6266 - val_categorical_accuracy: 0.0640 - val_mean_dice_coef: 0.2509 - val_weighted_mean_dice_coef: 0.3737 - lr: 0.1000
# Epoch 50/50
# 366/366 [==============================] - ETA: 0s - loss: 0.5835 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2829 - weighted_mean_dice_coef: 0.4165
# Epoch 50: val_loss did not improve from 0.62102
# 366/366 [==============================] - 38s 104ms/step - loss: 0.5835 - categorical_accuracy: 0.0658 - mean_dice_coef: 0.2829 - weighted_mean_dice_coef: 0.4165 - val_loss: 0.6290 - val_categorical_accuracy: 0.0634 - val_mean_dice_coef: 0.2497 - val_weighted_mean_dice_coef: 0.3712 - lr: 0.1000

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(eddynet.history.history['loss'])
plt.semilogy(eddynet.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper right');

# %% [markdown]
# ## Performance on train dataset
# just to be sure...

# %%
randindex=np.random.randint(0,len(SSH_train))
predictedSEGM=eddynet.predict(np.reshape(SSH_train[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,6:-6]

plt.figure(figsize=(20, 10))
plt.subplot(131)
plt.imshow(SSH_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(132)
plt.imshow(predictedSEGMimage, cmap='coolwarm')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('Eddynet Segmentation');

plt.subplot(133)
plt.imshow(Seg_train[randindex,::-1,6:-6,0], cmap='coolwarm')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');
# Out:
# 2024-03-20 03:38:57.049715: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 681ms/step

# %% [markdown]
# ## Performance on test dataset (2009 data)

# %%
randindex=np.random.randint(0,len(SSH_test))
predictedSEGM=eddynet.predict(np.reshape(SSH_test[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,6:-6]

plt.figure(figsize=(20, 10))

plt.subplot(221)
plt.imshow(predictedSEGMimage, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('EddyNet Segmentation');

plt.subplot(222)
plt.imshow(Seg_test[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

plt.subplot(223)
plt.imshow(SSH_test[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(224)
plt.imshow(np.where(predictedSEGMimage == Seg_test[randindex,::-1,6:-6,0], 0, 1))
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.axis('off')
plt.title('Errors');
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %% [markdown]
# Seems working nicely, but there are some false eddy detections that need to be dealt with, working on it..

# %%
#### if you wanna use some animations ;) 


#imageList=[]
#for i in range(1200,1400):
#    imageList.append(SSH_train[i,:,:,0])
  

#print('drawing the animation...')
#from matplotlib import animation, rc
#from IPython.display import HTML

#def getImageFromList(x):
#    return imageList[x]

#fig = plt.figure(figsize=(10, 10))
#ims = []
#for i in range(len(imageList)):
#    im = plt.imshow(getImageFromList(i), animated=True, cmap='viridis')
#    ims.append([im])
#plt.axis('off')

#ani = animation.ArtistAnimation(fig, ims, interval=50, blit=False, repeat=False)
#plt.close()

#HTML(ani.to_jshtml())

# %% [markdown]
# ## metrics on test dataset

# %%
Seg_test_categor = utils.to_categorical(np.reshape(Seg_test[:,:,:,0],(365,80*192)),3)
Seg_test_categor.shape
# Out:
# (365, 15360, 3)

# %%
eddynet.evaluate(SSH_test,Seg_test_categor)
# Out:
# 12/12 [==============================] - 1s 59ms/step - loss: 0.2542 - categorical_accuracy: 0.8506 - mean_dice_coef: 0.7946 - weighted_mean_dice_coef: 0.7462
# [0.2542441189289093,
#  0.8505622148513794,
#  0.7945871353149414,
#  0.7462493777275085]
