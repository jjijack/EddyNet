# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# to output everything in a cell instead of only the last output

# %matplotlib inline

# standard imports
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# ## import data

# %%
SSH_train = np.expand_dims(np.load('../Data/adt_train.npy'),3)[:,:-1,1:,:]
SSH_test = np.expand_dims(np.load('../Data/adt_test.npy'),3)[:,:-1,1:,:]

SSH_train[np.isnan(SSH_train)] = -1
SSH_test[np.isnan(SSH_test)] = -1
#######
Seg_train = np.expand_dims(np.load('../Data/grid_all.npy'),3)[:,:-1,1:,:]
Seg_test = np.expand_dims(np.load('../Data/grid_all_test.npy'),3)[:,:-1,1:,:]

Seg_train[Seg_train==-1] = 2
Seg_test[Seg_test==-1] = 2
######
SSH_train.shape
SSH_test.shape
#####
Seg_train.shape
Seg_test.shape
# Out:
# (3653, 80, 180, 1)
# (365, 80, 180, 1)
# (3653, 80, 180, 1)
# (365, 80, 180, 1)

# %%
randindex=np.random.randint(0,len(SSH_train))

plt.figure(figsize=(20, 10))

plt.subplot(121)
plt.imshow(SSH_train[randindex,::-1,:,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(122)
plt.imshow(Seg_train[randindex,::-1,:,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

# %% [markdown]
# ## EddyResNet

# %% [markdown]
# This architecture is based on combining Unet and Residual units, here we show a small EddyResNet

# %%
from keras.models import Model, load_model
from keras.layers import Activation, Reshape, Permute, Lambda
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, UpSampling2D, AlphaDropout, concatenate, Conv2DTranspose
from keras.layers import BatchNormalization, LeakyReLU, add
import keras.utils as utils   #更改代码
from keras.optimizers import legacy   #更改代码
from keras import backend as K
from keras import regularizers
import matplotlib.pyplot as plt
import numpy as np
import pickle
from IPython.display import SVG 
from keras.utils import model_to_dot    #更改代码
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
Seg_train_categor = utils.to_categorical(np.reshape(Seg_train[:,:,:,0],(3653,80*180)),3)   #更改代码
Seg_train_categor.shape
# Out:
# (3653, 14400, 3)

# %%
def FirstResUnit(nf,ker,inputs):
    conv1 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv1)
    return add([conv2,inputs])

def ResUnit(nf,ker,inputs, drop=0.5):
    conv1 = BatchNormalization()(inputs)
    conv1 = Activation('relu')(conv1)
    conv1 = Dropout(drop)(conv1)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Dropout(drop)(conv2)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv2)
    return add([conv2,inputs])

def ResUnitDecoder(nf,ker,inputs,drop=0.5):
    conv1 = BatchNormalization()(inputs)
    conv1 = Activation('relu')(conv1)
    conv1 = Dropout(drop)(conv1)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Dropout(drop)(conv2)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv2)
    ###
    shortcut = Conv2D(nf, 1, padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    return add([conv2,shortcut])

# %%
width = 180
height = 80
nbClass = 3
nf = 32
ker = 3

###################################### INPUT LAYER

img_input = Input(shape=(height, width, 1))
######################################ENCODER

conv1 = FirstResUnit(nf,ker,img_input)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = ResUnit(nf,ker,pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

#######################################center

convC = ResUnit(nf,ker,pool2)

#######################################DECODER

up2 = concatenate([UpSampling2D((2,2))(convC), conv2])
decod2 = ResUnitDecoder(nf,ker,up2)

up1 = concatenate([UpSampling2D((2,2))(decod2), conv1])
decod1 = ResUnitDecoder(nf,ker,up1)

####################################### Segmentation Layer

x = Conv2D(nbClass, (1, 1), padding="valid", use_bias=False)(decod1) 
x = Reshape((height * width, nbClass))(x) 
x = Activation("softmax")(x)
eddynet = Model(img_input, x)

eddynet.summary()
# Out:
# 2024-01-08 23:24:09.760339: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-01-08 23:24:09.760424: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-01-08 23:24:09.760437: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-01-08 23:24:09.760852: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-08 23:24:09.761042: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 80, 180, 1)]         0         []
#
#  conv2d (Conv2D)             (None, 80, 180, 32)          288       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 80, 180, 32)          128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 80, 180, 32)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 80, 180, 32)          9216      ['activation[0][0]']
#
#  add (Add)                   (None, 80, 180, 32)          0         ['conv2d_1[0][0]',
#                                                                      'input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 40, 90, 32)           0         ['add[0][0]']
#  D)
#
#  batch_normalization_1 (Bat  (None, 40, 90, 32)           128       ['max_pooling2d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 90, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 40, 90, 32)           0         ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 40, 90, 32)           9216      ['dropout[0][0]']
#
#  batch_normalization_2 (Bat  (None, 40, 90, 32)           128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 40, 90, 32)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 40, 90, 32)           0         ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 40, 90, 32)           9216      ['dropout_1[0][0]']
#
#  add_1 (Add)                 (None, 40, 90, 32)           0         ['conv2d_3[0][0]',
#                                                                      'max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 20, 45, 32)           0         ['add_1[0][0]']
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 20, 45, 32)           128       ['max_pooling2d_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 20, 45, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 20, 45, 32)           0         ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 20, 45, 32)           9216      ['dropout_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 20, 45, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 20, 45, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 20, 45, 32)           0         ['activation_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 20, 45, 32)           9216      ['dropout_3[0][0]']
#
#  add_2 (Add)                 (None, 20, 45, 32)           0         ['conv2d_5[0][0]',
#                                                                      'max_pooling2d_1[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 40, 90, 32)           0         ['add_2[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 40, 90, 64)           0         ['up_sampling2d[0][0]',
#                                                                      'add_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, 40, 90, 64)           256       ['concatenate[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 40, 90, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 40, 90, 64)           0         ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 40, 90, 32)           18432     ['dropout_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 40, 90, 32)           128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 40, 90, 32)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 40, 90, 32)           0         ['activation_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 40, 90, 32)           9216      ['dropout_5[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 40, 90, 32)           2048      ['concatenate[0][0]']
#
#  add_3 (Add)                 (None, 40, 90, 32)           0         ['conv2d_7[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 80, 180, 32)          0         ['add_3[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 80, 180, 64)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'add[0][0]']
#
#  batch_normalization_7 (Bat  (None, 80, 180, 64)          256       ['concatenate_1[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 80, 180, 64)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 80, 180, 64)          0         ['activation_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 80, 180, 32)          18432     ['dropout_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 80, 180, 32)          128       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 80, 180, 32)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 80, 180, 32)          0         ['activation_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 80, 180, 32)          9216      ['dropout_7[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 80, 180, 32)          2048      ['concatenate_1[0][0]']
#
#  add_4 (Add)                 (None, 80, 180, 32)          0         ['conv2d_10[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 80, 180, 3)           96        ['add_4[0][0]']
#
#  reshape (Reshape)           (None, 14400, 3)             0         ['conv2d_12[0][0]']
#
#  activation_9 (Activation)   (None, 14400, 3)             0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 107264 (419.00 KB)
# Trainable params: 106560 (416.25 KB)
# Non-trainable params: 704 (2.75 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### calculate weights (some heavy data imbalance out there...)

# %%
unique, counts = np.unique(Seg_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0.0: 36694076, 1.0: 8259619, 2.0: 7649505}

# %%
freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
weightsSeg
# Out:
# [0.0976609362794789, 0.43386720598981093, 0.46847185773071015]

# %% [markdown]
# ## loss functions

# %%
smooth = 1.  # to avoid zero division

def dice_coef_anti(y_true, y_pred):
    y_true_anti = y_true[:,:,1]
    y_pred_anti = y_pred[:,:,1]
    intersection_anti = K.sum(y_true_anti * y_pred_anti)
    return (2 * intersection_anti + smooth) / (K.sum(y_true_anti)+ K.sum(y_pred_anti) + smooth)

def dice_coef_cyc(y_true, y_pred):
    y_true_cyc = y_true[:,:,2]
    y_pred_cyc = y_pred[:,:,2]
    intersection_cyc = K.sum(y_true_cyc * y_pred_cyc)
    return (2 * intersection_cyc + smooth) / (K.sum(y_true_cyc) + K.sum(y_pred_cyc) + smooth)

def dice_coef_nn(y_true, y_pred):
    y_true_nn = y_true[:,:,0]
    y_pred_nn = y_pred[:,:,0]
    intersection_nn = K.sum(y_true_nn * y_pred_nn)
    return (2 * intersection_nn + smooth) / (K.sum(y_true_nn) + K.sum(y_pred_nn) + smooth)
    
def mean_dice_coef(y_true, y_pred):
    return (dice_coef_anti(y_true, y_pred) + dice_coef_cyc(y_true, y_pred) + dice_coef_nn(y_true, y_pred))/3.

def weighted_mean_dice_coef(y_true, y_pred):
    return (0.35*dice_coef_anti(y_true, y_pred) + 0.62*dice_coef_cyc(y_true, y_pred) + 0.03*dice_coef_nn(y_true, y_pred))
  
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_mean_dice_coef(y_true, y_pred)

# %%
eddynet.compile(optimizer=legacy.Adam(lr=1e-3), loss=dice_coef_loss,    #更改代码
                metrics=['categorical_accuracy', mean_dice_coef, weighted_mean_dice_coef])
# Out:
# /Users/jjijack/miniconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#SVG(model_to_dot(eddynet).create(prog='dot', format='svg'))

# %% [markdown]
# ## Training

# %%
earl = EarlyStopping(monitor='val_loss', min_delta=1e-8, patience=50, verbose=1, mode='auto')
modelcheck = ModelCheckpoint('./weights/eddyRESnet.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
reducecall = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, verbose=1, mode='auto', min_delta=1e-30, min_lr=1e-30)


histeddynet=eddynet.fit(SSH_train, Seg_train_categor,
                              epochs=50,
                              batch_size=16,
                              shuffle=True,
                              verbose=1,
                              callbacks=[modelcheck,reducecall, earl],
                              validation_split=0.2
                              )
# Out:
# Epoch 1/50
# 2024-01-08 23:24:13.297159: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 183/183 [==============================] - ETA: 0s - loss: 0.4414 - categorical_accuracy: 0.6270 - mean_dice_coef: 0.5839 - weighted_mean_dice_coef: 0.5588
# 2024-01-08 23:24:34.923015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.39359, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 25s 122ms/step - loss: 0.4414 - categorical_accuracy: 0.6270 - mean_dice_coef: 0.5839 - weighted_mean_dice_coef: 0.5588 - val_loss: 0.3936 - val_categorical_accuracy: 0.6761 - val_mean_dice_coef: 0.6404 - val_weighted_mean_dice_coef: 0.6063 - lr: 0.0010
# Epoch 2/50
# 183/183 [==============================] - ETA: 0s - loss: 0.3372 - categorical_accuracy: 0.7791 - mean_dice_coef: 0.7167 - weighted_mean_dice_coef: 0.6628
# Epoch 2: val_loss improved from 0.39359 to 0.33767, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 113ms/step - loss: 0.3372 - categorical_accuracy: 0.7791 - mean_dice_coef: 0.7167 - weighted_mean_dice_coef: 0.6628 - val_loss: 0.3377 - val_categorical_accuracy: 0.7571 - val_mean_dice_coef: 0.7065 - val_weighted_mean_dice_coef: 0.6622 - lr: 0.0010
# Epoch 3/50
# 183/183 [==============================] - ETA: 0s - loss: 0.3187 - categorical_accuracy: 0.7934 - mean_dice_coef: 0.7333 - weighted_mean_dice_coef: 0.6814
# Epoch 3: val_loss improved from 0.33767 to 0.30036, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 116ms/step - loss: 0.3187 - categorical_accuracy: 0.7934 - mean_dice_coef: 0.7333 - weighted_mean_dice_coef: 0.6814 - val_loss: 0.3004 - val_categorical_accuracy: 0.7966 - val_mean_dice_coef: 0.7444 - val_weighted_mean_dice_coef: 0.6997 - lr: 0.0010
# Epoch 4/50
# 183/183 [==============================] - ETA: 0s - loss: 0.3076 - categorical_accuracy: 0.8017 - mean_dice_coef: 0.7430 - weighted_mean_dice_coef: 0.6924
# Epoch 4: val_loss improved from 0.30036 to 0.28727, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 114ms/step - loss: 0.3076 - categorical_accuracy: 0.8017 - mean_dice_coef: 0.7430 - weighted_mean_dice_coef: 0.6924 - val_loss: 0.2873 - val_categorical_accuracy: 0.8082 - val_mean_dice_coef: 0.7572 - val_weighted_mean_dice_coef: 0.7128 - lr: 0.0010
# Epoch 5/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2997 - categorical_accuracy: 0.8077 - mean_dice_coef: 0.7499 - weighted_mean_dice_coef: 0.7003
# Epoch 5: val_loss improved from 0.28727 to 0.28098, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2997 - categorical_accuracy: 0.8077 - mean_dice_coef: 0.7499 - weighted_mean_dice_coef: 0.7003 - val_loss: 0.2810 - val_categorical_accuracy: 0.8148 - val_mean_dice_coef: 0.7635 - val_weighted_mean_dice_coef: 0.7190 - lr: 0.0010
# Epoch 6/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2938 - categorical_accuracy: 0.8120 - mean_dice_coef: 0.7551 - weighted_mean_dice_coef: 0.7062
# Epoch 6: val_loss improved from 0.28098 to 0.27815, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2938 - categorical_accuracy: 0.8120 - mean_dice_coef: 0.7551 - weighted_mean_dice_coef: 0.7062 - val_loss: 0.2781 - val_categorical_accuracy: 0.8089 - val_mean_dice_coef: 0.7625 - val_weighted_mean_dice_coef: 0.7218 - lr: 0.0010
# Epoch 7/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2889 - categorical_accuracy: 0.8156 - mean_dice_coef: 0.7594 - weighted_mean_dice_coef: 0.7111
# Epoch 7: val_loss improved from 0.27815 to 0.27595, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2889 - categorical_accuracy: 0.8156 - mean_dice_coef: 0.7594 - weighted_mean_dice_coef: 0.7111 - val_loss: 0.2759 - val_categorical_accuracy: 0.8124 - val_mean_dice_coef: 0.7662 - val_weighted_mean_dice_coef: 0.7241 - lr: 0.0010
# Epoch 8/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2851 - categorical_accuracy: 0.8183 - mean_dice_coef: 0.7627 - weighted_mean_dice_coef: 0.7149
# Epoch 8: val_loss improved from 0.27595 to 0.27064, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2851 - categorical_accuracy: 0.8183 - mean_dice_coef: 0.7627 - weighted_mean_dice_coef: 0.7149 - val_loss: 0.2706 - val_categorical_accuracy: 0.8192 - val_mean_dice_coef: 0.7712 - val_weighted_mean_dice_coef: 0.7294 - lr: 0.0010
# Epoch 9/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2824 - categorical_accuracy: 0.8201 - mean_dice_coef: 0.7648 - weighted_mean_dice_coef: 0.7175
# Epoch 9: val_loss improved from 0.27064 to 0.26738, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2824 - categorical_accuracy: 0.8201 - mean_dice_coef: 0.7648 - weighted_mean_dice_coef: 0.7175 - val_loss: 0.2674 - val_categorical_accuracy: 0.8299 - val_mean_dice_coef: 0.7769 - val_weighted_mean_dice_coef: 0.7326 - lr: 0.0010
# Epoch 10/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2788 - categorical_accuracy: 0.8229 - mean_dice_coef: 0.7681 - weighted_mean_dice_coef: 0.7212
# Epoch 10: val_loss improved from 0.26738 to 0.26388, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2788 - categorical_accuracy: 0.8229 - mean_dice_coef: 0.7681 - weighted_mean_dice_coef: 0.7212 - val_loss: 0.2639 - val_categorical_accuracy: 0.8251 - val_mean_dice_coef: 0.7775 - val_weighted_mean_dice_coef: 0.7361 - lr: 0.0010
# Epoch 11/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2764 - categorical_accuracy: 0.8245 - mean_dice_coef: 0.7701 - weighted_mean_dice_coef: 0.7236
# Epoch 11: val_loss improved from 0.26388 to 0.26240, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 116ms/step - loss: 0.2764 - categorical_accuracy: 0.8245 - mean_dice_coef: 0.7701 - weighted_mean_dice_coef: 0.7236 - val_loss: 0.2624 - val_categorical_accuracy: 0.8239 - val_mean_dice_coef: 0.7780 - val_weighted_mean_dice_coef: 0.7376 - lr: 0.0010
# Epoch 12/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2745 - categorical_accuracy: 0.8259 - mean_dice_coef: 0.7717 - weighted_mean_dice_coef: 0.7255
# Epoch 12: val_loss improved from 0.26240 to 0.25970, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2745 - categorical_accuracy: 0.8259 - mean_dice_coef: 0.7717 - weighted_mean_dice_coef: 0.7255 - val_loss: 0.2597 - val_categorical_accuracy: 0.8222 - val_mean_dice_coef: 0.7787 - val_weighted_mean_dice_coef: 0.7403 - lr: 0.0010
# Epoch 13/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2727 - categorical_accuracy: 0.8271 - mean_dice_coef: 0.7733 - weighted_mean_dice_coef: 0.7273
# Epoch 13: val_loss improved from 0.25970 to 0.25608, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 20s 111ms/step - loss: 0.2727 - categorical_accuracy: 0.8271 - mean_dice_coef: 0.7733 - weighted_mean_dice_coef: 0.7273 - val_loss: 0.2561 - val_categorical_accuracy: 0.8308 - val_mean_dice_coef: 0.7842 - val_weighted_mean_dice_coef: 0.7439 - lr: 0.0010
# Epoch 14/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2709 - categorical_accuracy: 0.8284 - mean_dice_coef: 0.7748 - weighted_mean_dice_coef: 0.7291
# Epoch 14: val_loss did not improve from 0.25608
# 183/183 [==============================] - 20s 112ms/step - loss: 0.2709 - categorical_accuracy: 0.8284 - mean_dice_coef: 0.7748 - weighted_mean_dice_coef: 0.7291 - val_loss: 0.2592 - val_categorical_accuracy: 0.8262 - val_mean_dice_coef: 0.7811 - val_weighted_mean_dice_coef: 0.7408 - lr: 0.0010
# Epoch 15/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2693 - categorical_accuracy: 0.8297 - mean_dice_coef: 0.7763 - weighted_mean_dice_coef: 0.7307
# Epoch 15: val_loss did not improve from 0.25608
# 183/183 [==============================] - 21s 115ms/step - loss: 0.2693 - categorical_accuracy: 0.8297 - mean_dice_coef: 0.7763 - weighted_mean_dice_coef: 0.7307 - val_loss: 0.2600 - val_categorical_accuracy: 0.8216 - val_mean_dice_coef: 0.7780 - val_weighted_mean_dice_coef: 0.7399 - lr: 0.0010
# Epoch 16/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2685 - categorical_accuracy: 0.8299 - mean_dice_coef: 0.7769 - weighted_mean_dice_coef: 0.7316
# Epoch 16: val_loss improved from 0.25608 to 0.25468, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 22s 121ms/step - loss: 0.2685 - categorical_accuracy: 0.8299 - mean_dice_coef: 0.7769 - weighted_mean_dice_coef: 0.7316 - val_loss: 0.2547 - val_categorical_accuracy: 0.8303 - val_mean_dice_coef: 0.7852 - val_weighted_mean_dice_coef: 0.7453 - lr: 0.0010
# Epoch 17/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2673 - categorical_accuracy: 0.8310 - mean_dice_coef: 0.7780 - weighted_mean_dice_coef: 0.7327
# Epoch 17: val_loss improved from 0.25468 to 0.25353, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 112ms/step - loss: 0.2673 - categorical_accuracy: 0.8310 - mean_dice_coef: 0.7780 - weighted_mean_dice_coef: 0.7327 - val_loss: 0.2535 - val_categorical_accuracy: 0.8257 - val_mean_dice_coef: 0.7833 - val_weighted_mean_dice_coef: 0.7464 - lr: 0.0010
# Epoch 18/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2659 - categorical_accuracy: 0.8319 - mean_dice_coef: 0.7792 - weighted_mean_dice_coef: 0.7341
# Epoch 18: val_loss did not improve from 0.25353
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2659 - categorical_accuracy: 0.8319 - mean_dice_coef: 0.7792 - weighted_mean_dice_coef: 0.7341 - val_loss: 0.2548 - val_categorical_accuracy: 0.8260 - val_mean_dice_coef: 0.7828 - val_weighted_mean_dice_coef: 0.7451 - lr: 0.0010
# Epoch 19/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2651 - categorical_accuracy: 0.8325 - mean_dice_coef: 0.7799 - weighted_mean_dice_coef: 0.7349
# Epoch 19: val_loss improved from 0.25353 to 0.24997, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 112ms/step - loss: 0.2651 - categorical_accuracy: 0.8325 - mean_dice_coef: 0.7799 - weighted_mean_dice_coef: 0.7349 - val_loss: 0.2500 - val_categorical_accuracy: 0.8342 - val_mean_dice_coef: 0.7892 - val_weighted_mean_dice_coef: 0.7500 - lr: 0.0010
# Epoch 20/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2641 - categorical_accuracy: 0.8332 - mean_dice_coef: 0.7807 - weighted_mean_dice_coef: 0.7359
# Epoch 20: val_loss did not improve from 0.24997
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2641 - categorical_accuracy: 0.8332 - mean_dice_coef: 0.7807 - weighted_mean_dice_coef: 0.7359 - val_loss: 0.2550 - val_categorical_accuracy: 0.8318 - val_mean_dice_coef: 0.7853 - val_weighted_mean_dice_coef: 0.7450 - lr: 0.0010
# Epoch 21/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2631 - categorical_accuracy: 0.8339 - mean_dice_coef: 0.7816 - weighted_mean_dice_coef: 0.7369
# Epoch 21: val_loss improved from 0.24997 to 0.24880, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2631 - categorical_accuracy: 0.8339 - mean_dice_coef: 0.7816 - weighted_mean_dice_coef: 0.7369 - val_loss: 0.2488 - val_categorical_accuracy: 0.8380 - val_mean_dice_coef: 0.7911 - val_weighted_mean_dice_coef: 0.7511 - lr: 0.0010
# Epoch 22/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2622 - categorical_accuracy: 0.8345 - mean_dice_coef: 0.7823 - weighted_mean_dice_coef: 0.7378
# Epoch 22: val_loss improved from 0.24880 to 0.24875, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 115ms/step - loss: 0.2622 - categorical_accuracy: 0.8345 - mean_dice_coef: 0.7823 - weighted_mean_dice_coef: 0.7378 - val_loss: 0.2487 - val_categorical_accuracy: 0.8324 - val_mean_dice_coef: 0.7894 - val_weighted_mean_dice_coef: 0.7512 - lr: 0.0010
# Epoch 23/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2620 - categorical_accuracy: 0.8345 - mean_dice_coef: 0.7825 - weighted_mean_dice_coef: 0.7380
# Epoch 23: val_loss did not improve from 0.24875
# 183/183 [==============================] - 21s 112ms/step - loss: 0.2620 - categorical_accuracy: 0.8345 - mean_dice_coef: 0.7825 - weighted_mean_dice_coef: 0.7380 - val_loss: 0.2510 - val_categorical_accuracy: 0.8299 - val_mean_dice_coef: 0.7865 - val_weighted_mean_dice_coef: 0.7489 - lr: 0.0010
# Epoch 24/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2612 - categorical_accuracy: 0.8352 - mean_dice_coef: 0.7832 - weighted_mean_dice_coef: 0.7388
# Epoch 24: val_loss did not improve from 0.24875
# 183/183 [==============================] - 21s 115ms/step - loss: 0.2612 - categorical_accuracy: 0.8352 - mean_dice_coef: 0.7832 - weighted_mean_dice_coef: 0.7388 - val_loss: 0.2490 - val_categorical_accuracy: 0.8369 - val_mean_dice_coef: 0.7909 - val_weighted_mean_dice_coef: 0.7510 - lr: 0.0010
# Epoch 25/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2607 - categorical_accuracy: 0.8354 - mean_dice_coef: 0.7836 - weighted_mean_dice_coef: 0.7393
# Epoch 25: val_loss did not improve from 0.24875
# 183/183 [==============================] - 22s 117ms/step - loss: 0.2607 - categorical_accuracy: 0.8354 - mean_dice_coef: 0.7836 - weighted_mean_dice_coef: 0.7393 - val_loss: 0.2555 - val_categorical_accuracy: 0.8365 - val_mean_dice_coef: 0.7863 - val_weighted_mean_dice_coef: 0.7445 - lr: 0.0010
# Epoch 26/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2597 - categorical_accuracy: 0.8362 - mean_dice_coef: 0.7844 - weighted_mean_dice_coef: 0.7403
# Epoch 26: val_loss did not improve from 0.24875
# 183/183 [==============================] - 22s 118ms/step - loss: 0.2597 - categorical_accuracy: 0.8362 - mean_dice_coef: 0.7844 - weighted_mean_dice_coef: 0.7403 - val_loss: 0.2488 - val_categorical_accuracy: 0.8348 - val_mean_dice_coef: 0.7903 - val_weighted_mean_dice_coef: 0.7511 - lr: 0.0010
# Epoch 27/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2594 - categorical_accuracy: 0.8362 - mean_dice_coef: 0.7847 - weighted_mean_dice_coef: 0.7406
# Epoch 27: val_loss improved from 0.24875 to 0.24671, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 22s 120ms/step - loss: 0.2594 - categorical_accuracy: 0.8362 - mean_dice_coef: 0.7847 - weighted_mean_dice_coef: 0.7406 - val_loss: 0.2467 - val_categorical_accuracy: 0.8390 - val_mean_dice_coef: 0.7933 - val_weighted_mean_dice_coef: 0.7532 - lr: 0.0010
# Epoch 28/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2584 - categorical_accuracy: 0.8372 - mean_dice_coef: 0.7857 - weighted_mean_dice_coef: 0.7417
# Epoch 28: val_loss did not improve from 0.24671
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2584 - categorical_accuracy: 0.8372 - mean_dice_coef: 0.7857 - weighted_mean_dice_coef: 0.7417 - val_loss: 0.2491 - val_categorical_accuracy: 0.8379 - val_mean_dice_coef: 0.7913 - val_weighted_mean_dice_coef: 0.7508 - lr: 0.0010
# Epoch 29/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2580 - categorical_accuracy: 0.8372 - mean_dice_coef: 0.7857 - weighted_mean_dice_coef: 0.7419
# Epoch 29: val_loss did not improve from 0.24671
# 183/183 [==============================] - 21s 115ms/step - loss: 0.2580 - categorical_accuracy: 0.8372 - mean_dice_coef: 0.7857 - weighted_mean_dice_coef: 0.7419 - val_loss: 0.2507 - val_categorical_accuracy: 0.8271 - val_mean_dice_coef: 0.7863 - val_weighted_mean_dice_coef: 0.7492 - lr: 0.0010
# Epoch 30/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2578 - categorical_accuracy: 0.8377 - mean_dice_coef: 0.7862 - weighted_mean_dice_coef: 0.7422
# Epoch 30: val_loss did not improve from 0.24671
# 183/183 [==============================] - 21s 115ms/step - loss: 0.2578 - categorical_accuracy: 0.8377 - mean_dice_coef: 0.7862 - weighted_mean_dice_coef: 0.7422 - val_loss: 0.2473 - val_categorical_accuracy: 0.8297 - val_mean_dice_coef: 0.7888 - val_weighted_mean_dice_coef: 0.7526 - lr: 0.0010
# Epoch 31/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2568 - categorical_accuracy: 0.8381 - mean_dice_coef: 0.7868 - weighted_mean_dice_coef: 0.7431
# Epoch 31: val_loss did not improve from 0.24671
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2568 - categorical_accuracy: 0.8381 - mean_dice_coef: 0.7868 - weighted_mean_dice_coef: 0.7431 - val_loss: 0.2472 - val_categorical_accuracy: 0.8371 - val_mean_dice_coef: 0.7922 - val_weighted_mean_dice_coef: 0.7527 - lr: 0.0010
# Epoch 32/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2563 - categorical_accuracy: 0.8385 - mean_dice_coef: 0.7873 - weighted_mean_dice_coef: 0.7437
# Epoch 32: val_loss improved from 0.24671 to 0.24595, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 22s 119ms/step - loss: 0.2563 - categorical_accuracy: 0.8385 - mean_dice_coef: 0.7873 - weighted_mean_dice_coef: 0.7437 - val_loss: 0.2460 - val_categorical_accuracy: 0.8338 - val_mean_dice_coef: 0.7916 - val_weighted_mean_dice_coef: 0.7540 - lr: 0.0010
# Epoch 33/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2559 - categorical_accuracy: 0.8388 - mean_dice_coef: 0.7876 - weighted_mean_dice_coef: 0.7441
# Epoch 33: val_loss did not improve from 0.24595
# 183/183 [==============================] - 22s 117ms/step - loss: 0.2559 - categorical_accuracy: 0.8388 - mean_dice_coef: 0.7876 - weighted_mean_dice_coef: 0.7441 - val_loss: 0.2474 - val_categorical_accuracy: 0.8385 - val_mean_dice_coef: 0.7926 - val_weighted_mean_dice_coef: 0.7525 - lr: 0.0010
# Epoch 34/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2554 - categorical_accuracy: 0.8392 - mean_dice_coef: 0.7881 - weighted_mean_dice_coef: 0.7446
# Epoch 34: val_loss improved from 0.24595 to 0.24382, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 116ms/step - loss: 0.2554 - categorical_accuracy: 0.8392 - mean_dice_coef: 0.7881 - weighted_mean_dice_coef: 0.7446 - val_loss: 0.2438 - val_categorical_accuracy: 0.8370 - val_mean_dice_coef: 0.7941 - val_weighted_mean_dice_coef: 0.7561 - lr: 0.0010
# Epoch 35/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2559 - categorical_accuracy: 0.8387 - mean_dice_coef: 0.7876 - weighted_mean_dice_coef: 0.7441
# Epoch 35: val_loss did not improve from 0.24382
# 183/183 [==============================] - 22s 119ms/step - loss: 0.2559 - categorical_accuracy: 0.8387 - mean_dice_coef: 0.7876 - weighted_mean_dice_coef: 0.7441 - val_loss: 0.2474 - val_categorical_accuracy: 0.8327 - val_mean_dice_coef: 0.7903 - val_weighted_mean_dice_coef: 0.7525 - lr: 0.0010
# Epoch 36/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2547 - categorical_accuracy: 0.8396 - mean_dice_coef: 0.7887 - weighted_mean_dice_coef: 0.7453
# Epoch 36: val_loss did not improve from 0.24382
# 183/183 [==============================] - 22s 120ms/step - loss: 0.2547 - categorical_accuracy: 0.8396 - mean_dice_coef: 0.7887 - weighted_mean_dice_coef: 0.7453 - val_loss: 0.2448 - val_categorical_accuracy: 0.8366 - val_mean_dice_coef: 0.7935 - val_weighted_mean_dice_coef: 0.7551 - lr: 0.0010
# Epoch 37/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2545 - categorical_accuracy: 0.8398 - mean_dice_coef: 0.7889 - weighted_mean_dice_coef: 0.7455
# Epoch 37: val_loss did not improve from 0.24382
# 183/183 [==============================] - 22s 119ms/step - loss: 0.2545 - categorical_accuracy: 0.8398 - mean_dice_coef: 0.7889 - weighted_mean_dice_coef: 0.7455 - val_loss: 0.2454 - val_categorical_accuracy: 0.8367 - val_mean_dice_coef: 0.7935 - val_weighted_mean_dice_coef: 0.7546 - lr: 0.0010
# Epoch 38/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2544 - categorical_accuracy: 0.8398 - mean_dice_coef: 0.7890 - weighted_mean_dice_coef: 0.7456
# Epoch 38: val_loss did not improve from 0.24382
# 183/183 [==============================] - 21s 115ms/step - loss: 0.2544 - categorical_accuracy: 0.8398 - mean_dice_coef: 0.7890 - weighted_mean_dice_coef: 0.7456 - val_loss: 0.2467 - val_categorical_accuracy: 0.8404 - val_mean_dice_coef: 0.7938 - val_weighted_mean_dice_coef: 0.7532 - lr: 0.0010
# Epoch 39/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2541 - categorical_accuracy: 0.8399 - mean_dice_coef: 0.7892 - weighted_mean_dice_coef: 0.7459
# Epoch 39: val_loss did not improve from 0.24382
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2541 - categorical_accuracy: 0.8399 - mean_dice_coef: 0.7892 - weighted_mean_dice_coef: 0.7459 - val_loss: 0.2501 - val_categorical_accuracy: 0.8305 - val_mean_dice_coef: 0.7877 - val_weighted_mean_dice_coef: 0.7499 - lr: 0.0010
# Epoch 40/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2538 - categorical_accuracy: 0.8401 - mean_dice_coef: 0.7894 - weighted_mean_dice_coef: 0.7462
# Epoch 40: val_loss did not improve from 0.24382
# 183/183 [==============================] - 22s 118ms/step - loss: 0.2538 - categorical_accuracy: 0.8401 - mean_dice_coef: 0.7894 - weighted_mean_dice_coef: 0.7462 - val_loss: 0.2469 - val_categorical_accuracy: 0.8321 - val_mean_dice_coef: 0.7908 - val_weighted_mean_dice_coef: 0.7530 - lr: 0.0010
# Epoch 41/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2533 - categorical_accuracy: 0.8406 - mean_dice_coef: 0.7899 - weighted_mean_dice_coef: 0.7467
# Epoch 41: val_loss improved from 0.24382 to 0.24135, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2533 - categorical_accuracy: 0.8406 - mean_dice_coef: 0.7899 - weighted_mean_dice_coef: 0.7467 - val_loss: 0.2414 - val_categorical_accuracy: 0.8439 - val_mean_dice_coef: 0.7982 - val_weighted_mean_dice_coef: 0.7586 - lr: 0.0010
# Epoch 42/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2529 - categorical_accuracy: 0.8408 - mean_dice_coef: 0.7902 - weighted_mean_dice_coef: 0.7471
# Epoch 42: val_loss did not improve from 0.24135
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2529 - categorical_accuracy: 0.8408 - mean_dice_coef: 0.7902 - weighted_mean_dice_coef: 0.7471 - val_loss: 0.2425 - val_categorical_accuracy: 0.8399 - val_mean_dice_coef: 0.7961 - val_weighted_mean_dice_coef: 0.7574 - lr: 0.0010
# Epoch 43/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2527 - categorical_accuracy: 0.8410 - mean_dice_coef: 0.7904 - weighted_mean_dice_coef: 0.7473
# Epoch 43: val_loss did not improve from 0.24135
# 183/183 [==============================] - 20s 111ms/step - loss: 0.2527 - categorical_accuracy: 0.8410 - mean_dice_coef: 0.7904 - weighted_mean_dice_coef: 0.7473 - val_loss: 0.2438 - val_categorical_accuracy: 0.8416 - val_mean_dice_coef: 0.7959 - val_weighted_mean_dice_coef: 0.7562 - lr: 0.0010
# Epoch 44/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2527 - categorical_accuracy: 0.8410 - mean_dice_coef: 0.7904 - weighted_mean_dice_coef: 0.7473
# Epoch 44: val_loss did not improve from 0.24135
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2527 - categorical_accuracy: 0.8410 - mean_dice_coef: 0.7904 - weighted_mean_dice_coef: 0.7473 - val_loss: 0.2428 - val_categorical_accuracy: 0.8412 - val_mean_dice_coef: 0.7965 - val_weighted_mean_dice_coef: 0.7571 - lr: 0.0010
# Epoch 45/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2523 - categorical_accuracy: 0.8413 - mean_dice_coef: 0.7907 - weighted_mean_dice_coef: 0.7477
# Epoch 45: val_loss did not improve from 0.24135
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2523 - categorical_accuracy: 0.8413 - mean_dice_coef: 0.7907 - weighted_mean_dice_coef: 0.7477 - val_loss: 0.2450 - val_categorical_accuracy: 0.8427 - val_mean_dice_coef: 0.7955 - val_weighted_mean_dice_coef: 0.7550 - lr: 0.0010
# Epoch 46/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2518 - categorical_accuracy: 0.8416 - mean_dice_coef: 0.7912 - weighted_mean_dice_coef: 0.7483
# Epoch 46: val_loss did not improve from 0.24135
# 183/183 [==============================] - 21s 113ms/step - loss: 0.2518 - categorical_accuracy: 0.8416 - mean_dice_coef: 0.7912 - weighted_mean_dice_coef: 0.7483 - val_loss: 0.2447 - val_categorical_accuracy: 0.8396 - val_mean_dice_coef: 0.7946 - val_weighted_mean_dice_coef: 0.7552 - lr: 0.0010
# Epoch 47/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2516 - categorical_accuracy: 0.8418 - mean_dice_coef: 0.7914 - weighted_mean_dice_coef: 0.7485
# Epoch 47: val_loss did not improve from 0.24135
# 183/183 [==============================] - 20s 112ms/step - loss: 0.2516 - categorical_accuracy: 0.8418 - mean_dice_coef: 0.7914 - weighted_mean_dice_coef: 0.7485 - val_loss: 0.2426 - val_categorical_accuracy: 0.8413 - val_mean_dice_coef: 0.7967 - val_weighted_mean_dice_coef: 0.7573 - lr: 0.0010
# Epoch 48/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2515 - categorical_accuracy: 0.8417 - mean_dice_coef: 0.7914 - weighted_mean_dice_coef: 0.7485
# Epoch 48: val_loss did not improve from 0.24135
# 183/183 [==============================] - 21s 114ms/step - loss: 0.2515 - categorical_accuracy: 0.8417 - mean_dice_coef: 0.7914 - weighted_mean_dice_coef: 0.7485 - val_loss: 0.2416 - val_categorical_accuracy: 0.8389 - val_mean_dice_coef: 0.7963 - val_weighted_mean_dice_coef: 0.7583 - lr: 0.0010
# Epoch 49/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2511 - categorical_accuracy: 0.8420 - mean_dice_coef: 0.7917 - weighted_mean_dice_coef: 0.7489
# Epoch 49: val_loss did not improve from 0.24135
# 183/183 [==============================] - 21s 112ms/step - loss: 0.2511 - categorical_accuracy: 0.8420 - mean_dice_coef: 0.7917 - weighted_mean_dice_coef: 0.7489 - val_loss: 0.2421 - val_categorical_accuracy: 0.8370 - val_mean_dice_coef: 0.7950 - val_weighted_mean_dice_coef: 0.7578 - lr: 0.0010
# Epoch 50/50
# 183/183 [==============================] - ETA: 0s - loss: 0.2511 - categorical_accuracy: 0.8421 - mean_dice_coef: 0.7918 - weighted_mean_dice_coef: 0.7489
# Epoch 50: val_loss did not improve from 0.24135
# 183/183 [==============================] - 21s 115ms/step - loss: 0.2511 - categorical_accuracy: 0.8421 - mean_dice_coef: 0.7918 - weighted_mean_dice_coef: 0.7489 - val_loss: 0.2436 - val_categorical_accuracy: 0.8442 - val_mean_dice_coef: 0.7971 - val_weighted_mean_dice_coef: 0.7563 - lr: 0.0010

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(eddynet.history.history['loss'])
plt.semilogy(eddynet.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper right');

# %% [markdown]
# ## Performance on train dataset
# just to be sure...

# %%
randindex=np.random.randint(0,len(SSH_train))
predictedSEGM=eddynet.predict(np.reshape(SSH_train[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,:]

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(SSH_train[randindex,::-1,:,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(132)
plt.imshow(predictedSEGMimage, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('Eddynet Segmentation');

plt.subplot(133)
plt.imshow(Seg_train[randindex,::-1,:,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');
# Out:
# 2024-01-08 23:41:47.147805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 317ms/step

# %% [markdown]
# ## Performance on test dataset (2009 data)

# %%
randindex=np.random.randint(0,len(SSH_test))
predictedSEGM=eddynet.predict(np.reshape(SSH_test[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,:]

plt.figure(figsize=(20, 10))

plt.subplot(221)
plt.imshow(predictedSEGMimage, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('EddyResNet Segmentation');

plt.subplot(222)
plt.imshow(Seg_test[randindex,::-1,:,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

plt.subplot(223)
plt.imshow(SSH_test[randindex,::-1,:,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('SSH');

plt.subplot(224)
plt.imshow(np.where(predictedSEGMimage == Seg_test[randindex,::-1,:,0], 0, 1))
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.axis('off')
plt.title('Errors');
# Out:
# 1/1 [==============================] - 0s 117ms/step

# %%
np.sum(np.where(predictedSEGMimage == Seg_test[randindex,::-1,:,0], 0, 1))
# Out:
# 2265

# %% [markdown]
# Seems working nicely, but there are some false eddy detections that need to be dealt with.
#
# On my new paper I show that combining EddyResNet with ideas from level set segmentation leads to better results, I'll post the code upon acceptance of the paper

# %% [markdown]
# ## metrics on test dataset

# %%
Seg_test_categor = utils.to_categorical(np.reshape(Seg_test[:,:,:,0],(365,80*180)),3)
Seg_test_categor.shape
# Out:
# (365, 14400, 3)

# %%
eddynet.evaluate(SSH_test,Seg_test_categor)
# Out:
# 12/12 [==============================] - 1s 66ms/step - loss: 0.2567 - categorical_accuracy: 0.8384 - mean_dice_coef: 0.7874 - weighted_mean_dice_coef: 0.7438
# [0.2566577196121216,
#  0.8383830189704895,
#  0.7873563766479492,
#  0.7437596321105957]

# %%
#### if you wanna use some animations ;) 


#imageList=[]
#for i in range(1200,1400):
#    imageList.append(SSH_train[i,:,:,0])
  

#print('drawing the animation...')
#from matplotlib import animation, rc
#from IPython.display import HTML

#def getImageFromList(x):
#    return imageList[x]

#fig = plt.figure(figsize=(10, 10))
#ims = []
#for i in range(len(imageList)):
#    im = plt.imshow(getImageFromList(i), animated=True, cmap='viridis')
#    ims.append([im])
#plt.axis('off')

#ani = animation.ArtistAnimation(fig, ims, interval=50, blit=False, repeat=False)
#plt.close()

#HTML(ani.to_jshtml())
