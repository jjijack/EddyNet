# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# to output everything in a cell instead of only the last output

# %matplotlib inline

# standard imports
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## import data

# %%
SSH_train = np.expand_dims(np.load('../Data/adt_train.npy'),3)[:,:-1,1:,:]
SSH_test = np.expand_dims(np.load('../Data/adt_test.npy'),3)[:,:-1,1:,:]

SSH_train[np.isnan(SSH_train)] = -1
SSH_test[np.isnan(SSH_test)] = -1

SSH_train=tf.pad(SSH_train, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=-1)
SSH_test=tf.pad(SSH_test, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=-1)
#######
Seg_train = np.expand_dims(np.load('../Data/grid_all_train_simple.npy'),3)[:,:-1,1:,:]
Seg_test = np.expand_dims(np.load('../Data/grid_all_test_simple.npy'),3)[:,:-1,1:,:]

Seg_train=tf.pad(Seg_train, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=0)
Seg_test=tf.pad(Seg_test, [[0,0],[0,0],[6,6],[0,0]], 'CONSTANT', constant_values=0)
######
SSH_train=tf.cast(SSH_train,dtype=tf.float32)
SSH_test=tf.cast(SSH_test,dtype=tf.float32)
######
Seg_train=tf.cast(Seg_train,dtype=tf.int8)
Seg_test=tf.cast(Seg_test,dtype=tf.int8)
######
SSH_train.shape
SSH_test.shape
#####
Seg_train.shape
Seg_test.shape
# Out:
# 2024-05-14 14:09:55.455912: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-05-14 14:09:55.455933: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-05-14 14:09:55.455938: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-05-14 14:09:55.455966: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-05-14 14:09:55.455979: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# TensorShape([7305, 80, 192, 1])
# TensorShape([365, 80, 192, 1])
# TensorShape([7305, 80, 192, 1])
# TensorShape([365, 80, 192, 1])

# %%
randindex=np.random.randint(0,len(SSH_train))

plt.figure(figsize=(20, 10))

plt.subplot(121)
plt.imshow(SSH_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ADT');

plt.subplot(122)
plt.imshow(Seg_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

# %% [markdown]
# ## EddyResNet

# %% [markdown]
# This architecture is based on combining Unet and Residual units, here we show a small EddyResNet

# %%
from keras.models import Model, load_model
from keras.layers import Activation, Reshape, Permute, Lambda
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, UpSampling2D, AlphaDropout, concatenate, Conv2DTranspose
from keras.layers import BatchNormalization, LeakyReLU, add
import keras.utils as utils   #更改代码
from keras.optimizers import legacy   #更改代码
from keras import backend as K
from keras import regularizers
import matplotlib.pyplot as plt
import numpy as np
import pickle
from IPython.display import SVG 
from keras.utils import model_to_dot    #更改代码
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
Seg_train_categor = utils.to_categorical(np.reshape(Seg_train[:,:,:,0],(7305,80*192)),5)   #更改代码
Seg_train_categor.shape
# Out:
# (7305, 15360, 5)

# %%
def FirstResUnit(nf,ker,inputs):
    conv1 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv1)
    return add([conv2,inputs])

def ResUnit(nf,ker,inputs, drop=0.5):
    conv1 = BatchNormalization()(inputs)
    conv1 = Activation('relu')(conv1)
    conv1 = Dropout(drop)(conv1)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Dropout(drop)(conv2)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv2)
    return add([conv2,inputs])

def ResUnitDecoder(nf,ker,inputs,drop=0.5):
    conv1 = BatchNormalization()(inputs)
    conv1 = Activation('relu')(conv1)
    conv1 = Dropout(drop)(conv1)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Dropout(drop)(conv2)
    conv2 = Conv2D(nf, ker, padding="same", kernel_initializer='he_normal', use_bias=False)(conv2)
    ###
    shortcut = Conv2D(nf, 1, padding="same", kernel_initializer='he_normal', use_bias=False)(inputs)
    return add([conv2,shortcut])

# %%
width = 192
height = 80
nbClass = 5
nf = 32
ker = 3

###################################### INPUT LAYER

img_input = Input(shape=(height, width, 1))
######################################ENCODER

conv1 = FirstResUnit(nf,ker,img_input)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = ResUnit(nf,ker,pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = ResUnit(nf,ker,pool2)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

#######################################center

convC = ResUnit(nf,ker,pool3)

#######################################DECODER

up3 = concatenate([UpSampling2D((2,2))(convC), conv3])
decod3 = ResUnitDecoder(nf,ker,up3)

up2 = concatenate([UpSampling2D((2,2))(decod3), conv2])
decod2 = ResUnitDecoder(nf,ker,up2)

up1 = concatenate([UpSampling2D((2,2))(decod2), conv1])
decod1 = ResUnitDecoder(nf,ker,up1)

####################################### Segmentation Layer

x = Conv2D(nbClass, (1, 1), padding="valid", use_bias=False)(decod1) 
x = Reshape((height * width, nbClass))(x) 
x = Activation("softmax")(x)
eddynet = Model(img_input, x)

eddynet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 80, 192, 1)]         0         []
#
#  conv2d (Conv2D)             (None, 80, 192, 32)          288       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 80, 192, 32)          128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 80, 192, 32)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 80, 192, 32)          9216      ['activation[0][0]']
#
#  add (Add)                   (None, 80, 192, 32)          0         ['conv2d_1[0][0]',
#                                                                      'input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 40, 96, 32)           0         ['add[0][0]']
#  D)
#
#  batch_normalization_1 (Bat  (None, 40, 96, 32)           128       ['max_pooling2d[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 96, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 40, 96, 32)           0         ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 40, 96, 32)           9216      ['dropout[0][0]']
#
#  batch_normalization_2 (Bat  (None, 40, 96, 32)           128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 40, 96, 32)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 40, 96, 32)           0         ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 40, 96, 32)           9216      ['dropout_1[0][0]']
#
#  add_1 (Add)                 (None, 40, 96, 32)           0         ['conv2d_3[0][0]',
#                                                                      'max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 20, 48, 32)           0         ['add_1[0][0]']
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 20, 48, 32)           128       ['max_pooling2d_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 20, 48, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 20, 48, 32)           0         ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 20, 48, 32)           9216      ['dropout_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 20, 48, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 20, 48, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 20, 48, 32)           0         ['activation_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 20, 48, 32)           9216      ['dropout_3[0][0]']
#
#  add_2 (Add)                 (None, 20, 48, 32)           0         ['conv2d_5[0][0]',
#                                                                      'max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 24, 32)           0         ['add_2[0][0]']
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 10, 24, 32)           128       ['max_pooling2d_2[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 10, 24, 32)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 10, 24, 32)           0         ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 10, 24, 32)           9216      ['dropout_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 10, 24, 32)           128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 10, 24, 32)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 10, 24, 32)           0         ['activation_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 10, 24, 32)           9216      ['dropout_5[0][0]']
#
#  add_3 (Add)                 (None, 10, 24, 32)           0         ['conv2d_7[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 20, 48, 32)           0         ['add_3[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 20, 48, 64)           0         ['up_sampling2d[0][0]',
#                                                                      'add_2[0][0]']
#
#  batch_normalization_7 (Bat  (None, 20, 48, 64)           256       ['concatenate[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 20, 48, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 20, 48, 64)           0         ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 20, 48, 32)           18432     ['dropout_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 20, 48, 32)           128       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 20, 48, 32)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 20, 48, 32)           0         ['activation_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 20, 48, 32)           9216      ['dropout_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 20, 48, 32)           2048      ['concatenate[0][0]']
#
#  add_4 (Add)                 (None, 20, 48, 32)           0         ['conv2d_9[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 40, 96, 32)           0         ['add_4[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 40, 96, 64)           0         ['up_sampling2d_1[0][0]',
#  )                                                                   'add_1[0][0]']
#
#  batch_normalization_9 (Bat  (None, 40, 96, 64)           256       ['concatenate_1[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 40, 96, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 40, 96, 64)           0         ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 40, 96, 32)           18432     ['dropout_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 40, 96, 32)           128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 40, 96, 32)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 40, 96, 32)           0         ['activation_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 40, 96, 32)           9216      ['dropout_9[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 40, 96, 32)           2048      ['concatenate_1[0][0]']
#
#  add_5 (Add)                 (None, 40, 96, 32)           0         ['conv2d_12[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 80, 192, 32)          0         ['add_5[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 80, 192, 64)          0         ['up_sampling2d_2[0][0]',
#  )                                                                   'add[0][0]']
#
#  batch_normalization_11 (Ba  (None, 80, 192, 64)          256       ['concatenate_2[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 80, 192, 64)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 80, 192, 64)          0         ['activation_11[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 80, 192, 32)          18432     ['dropout_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 80, 192, 32)          128       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 80, 192, 32)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dropout_11 (Dropout)        (None, 80, 192, 32)          0         ['activation_12[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 80, 192, 32)          9216      ['dropout_11[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 80, 192, 32)          2048      ['concatenate_2[0][0]']
#
#  add_6 (Add)                 (None, 80, 192, 32)          0         ['conv2d_15[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 80, 192, 5)           160       ['add_6[0][0]']
#
#  reshape (Reshape)           (None, 15360, 5)             0         ['conv2d_17[0][0]']
#
#  activation_13 (Activation)  (None, 15360, 5)             0         ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 156096 (609.75 KB)
# Trainable params: 155072 (605.75 KB)
# Non-trainable params: 1024 (4.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### calculate weights (some heavy data imbalance out there...)

# %%
unique, counts = np.unique(Seg_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 80333001, 1: 15949436, 2: 617968, 3: 14659826, 4: 644569}

# %%
freq = [np.sum(counts)/j for j in counts]
weightsSeg = [f/np.sum(freq) for f in freq]
weightsSeg
# Out:
# [0.0037573854650822026,
#  0.01892493567320086,
#  0.48844284869739857,
#  0.020589743038139336,
#  0.4682850871261789]

# %% [markdown]
# ## loss functions

# %%
smooth = 1.  # to avoid zero division

def dice_coef_anti(y_true, y_pred):
    y_true_anti = y_true[:,:,1]
    y_pred_anti = y_pred[:,:,1]
    intersection_anti = K.sum(y_true_anti * y_pred_anti)
    return (2 * intersection_anti + smooth) / (K.sum(y_true_anti)+ K.sum(y_pred_anti) + smooth)

def dice_coef_anti_core(y_true, y_pred):
    y_true_anti = y_true[:,:,2]
    y_pred_anti = y_pred[:,:,2]
    intersection_anti = K.sum(y_true_anti * y_pred_anti)
    return (2 * intersection_anti + smooth) / (K.sum(y_true_anti)+ K.sum(y_pred_anti) + smooth)

def dice_coef_cyc(y_true, y_pred):
    y_true_cyc = y_true[:,:,3]
    y_pred_cyc = y_pred[:,:,3]
    intersection_cyc = K.sum(y_true_cyc * y_pred_cyc)
    return (2 * intersection_cyc + smooth) / (K.sum(y_true_cyc) + K.sum(y_pred_cyc) + smooth)

def dice_coef_cyc_core(y_true, y_pred):
    y_true_cyc = y_true[:,:,4]
    y_pred_cyc = y_pred[:,:,4]
    intersection_cyc = K.sum(y_true_cyc * y_pred_cyc)
    return (2 * intersection_cyc + smooth) / (K.sum(y_true_cyc) + K.sum(y_pred_cyc) + smooth)

def dice_coef_nn(y_true, y_pred):
    y_true_nn = y_true[:,:,0]
    y_pred_nn = y_pred[:,:,0]
    intersection_nn = K.sum(y_true_nn * y_pred_nn)
    return (2 * intersection_nn + smooth) / (K.sum(y_true_nn) + K.sum(y_pred_nn) + smooth)
    
def mean_dice_coef(y_true, y_pred):
    return (dice_coef_anti(y_true, y_pred) + dice_coef_anti_core(y_true, y_pred) + dice_coef_cyc(y_true, y_pred) + dice_coef_cyc_core(y_true, y_pred) + dice_coef_nn(y_true, y_pred))/5.

def weighted_mean_dice_coef(y_true, y_pred):
    return (0.2*dice_coef_anti(y_true, y_pred) + 0.19*dice_coef_cyc(y_true, y_pred) + 0.01*dice_coef_nn(y_true, y_pred) + 0.3*dice_coef_anti_core(y_true, y_pred) + 0.3*dice_coef_cyc_core(y_true, y_pred))
  
def dice_coef_loss(y_true, y_pred):
    return 1 - weighted_mean_dice_coef(y_true, y_pred)

# %%
eddynet.compile(optimizer=legacy.Adam(lr=1e-3), loss=dice_coef_loss,    #更改代码
                metrics=['categorical_accuracy', mean_dice_coef, weighted_mean_dice_coef])
# Out:
# /Users/jjijack/miniconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#SVG(model_to_dot(eddynet).create(prog='dot', format='svg'))

# %% [markdown]
# ## Training

# %%
earl = EarlyStopping(monitor='val_loss', min_delta=1e-8, patience=50, verbose=1, mode='auto')
modelcheck = ModelCheckpoint('./weights/eddyRESnet.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
reducecall = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, verbose=1, mode='auto', min_delta=1e-30, min_lr=1e-30)


histeddynet=eddynet.fit(SSH_train, Seg_train_categor,
                              epochs=200,
                              batch_size=32,
                              shuffle=True,
                              verbose=1,
                              callbacks=[modelcheck,reducecall, earl],
                              validation_split=0.2
                              )
# Out:
# Epoch 1/200
# 2024-05-14 14:10:03.505413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 183/183 [==============================] - ETA: 0s - loss: 0.7719 - categorical_accuracy: 0.5594 - mean_dice_coef: 0.3449 - weighted_mean_dice_coef: 0.2282
# Epoch 1: val_loss improved from inf to 0.73792, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 49s 253ms/step - loss: 0.7719 - categorical_accuracy: 0.5594 - mean_dice_coef: 0.3449 - weighted_mean_dice_coef: 0.2282 - val_loss: 0.7379 - val_categorical_accuracy: 0.7290 - val_mean_dice_coef: 0.4085 - val_weighted_mean_dice_coef: 0.2620 - lr: 0.0010
# Epoch 2/200
# 183/183 [==============================] - ETA: 0s - loss: 0.6170 - categorical_accuracy: 0.7600 - mean_dice_coef: 0.5003 - weighted_mean_dice_coef: 0.3831
# Epoch 2: val_loss improved from 0.73792 to 0.59331, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 47s 256ms/step - loss: 0.6170 - categorical_accuracy: 0.7600 - mean_dice_coef: 0.5003 - weighted_mean_dice_coef: 0.3831 - val_loss: 0.5933 - val_categorical_accuracy: 0.7487 - val_mean_dice_coef: 0.5147 - val_weighted_mean_dice_coef: 0.4064 - lr: 0.0010
# Epoch 3/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5705 - categorical_accuracy: 0.7763 - mean_dice_coef: 0.5371 - weighted_mean_dice_coef: 0.4295
# Epoch 3: val_loss improved from 0.59331 to 0.54236, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 53s 289ms/step - loss: 0.5705 - categorical_accuracy: 0.7763 - mean_dice_coef: 0.5371 - weighted_mean_dice_coef: 0.4295 - val_loss: 0.5424 - val_categorical_accuracy: 0.7769 - val_mean_dice_coef: 0.5577 - val_weighted_mean_dice_coef: 0.4575 - lr: 0.0010
# Epoch 4/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5519 - categorical_accuracy: 0.7852 - mean_dice_coef: 0.5526 - weighted_mean_dice_coef: 0.4481
# Epoch 4: val_loss improved from 0.54236 to 0.53190, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 46s 249ms/step - loss: 0.5519 - categorical_accuracy: 0.7852 - mean_dice_coef: 0.5526 - weighted_mean_dice_coef: 0.4481 - val_loss: 0.5319 - val_categorical_accuracy: 0.7952 - val_mean_dice_coef: 0.5701 - val_weighted_mean_dice_coef: 0.4679 - lr: 0.0010
# Epoch 5/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5404 - categorical_accuracy: 0.7913 - mean_dice_coef: 0.5624 - weighted_mean_dice_coef: 0.4596
# Epoch 5: val_loss improved from 0.53190 to 0.52100, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 42s 231ms/step - loss: 0.5404 - categorical_accuracy: 0.7913 - mean_dice_coef: 0.5624 - weighted_mean_dice_coef: 0.4596 - val_loss: 0.5210 - val_categorical_accuracy: 0.8050 - val_mean_dice_coef: 0.5802 - val_weighted_mean_dice_coef: 0.4788 - lr: 0.0010
# Epoch 6/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5321 - categorical_accuracy: 0.7960 - mean_dice_coef: 0.5696 - weighted_mean_dice_coef: 0.4679
# Epoch 6: val_loss improved from 0.52100 to 0.50647, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 41s 223ms/step - loss: 0.5321 - categorical_accuracy: 0.7960 - mean_dice_coef: 0.5696 - weighted_mean_dice_coef: 0.4679 - val_loss: 0.5065 - val_categorical_accuracy: 0.8096 - val_mean_dice_coef: 0.5919 - val_weighted_mean_dice_coef: 0.4934 - lr: 0.0010
# Epoch 7/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5257 - categorical_accuracy: 0.7994 - mean_dice_coef: 0.5751 - weighted_mean_dice_coef: 0.4743
# Epoch 7: val_loss improved from 0.50647 to 0.50224, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 41s 223ms/step - loss: 0.5257 - categorical_accuracy: 0.7994 - mean_dice_coef: 0.5751 - weighted_mean_dice_coef: 0.4743 - val_loss: 0.5022 - val_categorical_accuracy: 0.8082 - val_mean_dice_coef: 0.5948 - val_weighted_mean_dice_coef: 0.4976 - lr: 0.0010
# Epoch 8/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5212 - categorical_accuracy: 0.8023 - mean_dice_coef: 0.5791 - weighted_mean_dice_coef: 0.4788
# Epoch 8: val_loss improved from 0.50224 to 0.49644, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 39s 209ms/step - loss: 0.5212 - categorical_accuracy: 0.8023 - mean_dice_coef: 0.5791 - weighted_mean_dice_coef: 0.4788 - val_loss: 0.4964 - val_categorical_accuracy: 0.8149 - val_mean_dice_coef: 0.6007 - val_weighted_mean_dice_coef: 0.5035 - lr: 0.0010
# Epoch 9/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5162 - categorical_accuracy: 0.8048 - mean_dice_coef: 0.5833 - weighted_mean_dice_coef: 0.4838
# Epoch 9: val_loss improved from 0.49644 to 0.49387, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 208ms/step - loss: 0.5162 - categorical_accuracy: 0.8048 - mean_dice_coef: 0.5833 - weighted_mean_dice_coef: 0.4838 - val_loss: 0.4939 - val_categorical_accuracy: 0.8142 - val_mean_dice_coef: 0.6025 - val_weighted_mean_dice_coef: 0.5059 - lr: 0.0010
# Epoch 10/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5131 - categorical_accuracy: 0.8070 - mean_dice_coef: 0.5861 - weighted_mean_dice_coef: 0.4869
# Epoch 10: val_loss improved from 0.49387 to 0.49328, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 207ms/step - loss: 0.5131 - categorical_accuracy: 0.8070 - mean_dice_coef: 0.5861 - weighted_mean_dice_coef: 0.4869 - val_loss: 0.4933 - val_categorical_accuracy: 0.8159 - val_mean_dice_coef: 0.6035 - val_weighted_mean_dice_coef: 0.5066 - lr: 0.0010
# Epoch 11/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5101 - categorical_accuracy: 0.8086 - mean_dice_coef: 0.5888 - weighted_mean_dice_coef: 0.4899
# Epoch 11: val_loss improved from 0.49328 to 0.48970, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 206ms/step - loss: 0.5101 - categorical_accuracy: 0.8086 - mean_dice_coef: 0.5888 - weighted_mean_dice_coef: 0.4899 - val_loss: 0.4897 - val_categorical_accuracy: 0.8199 - val_mean_dice_coef: 0.6069 - val_weighted_mean_dice_coef: 0.5102 - lr: 0.0010
# Epoch 12/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5078 - categorical_accuracy: 0.8103 - mean_dice_coef: 0.5909 - weighted_mean_dice_coef: 0.4922
# Epoch 12: val_loss improved from 0.48970 to 0.48571, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 205ms/step - loss: 0.5078 - categorical_accuracy: 0.8103 - mean_dice_coef: 0.5909 - weighted_mean_dice_coef: 0.4922 - val_loss: 0.4857 - val_categorical_accuracy: 0.8193 - val_mean_dice_coef: 0.6097 - val_weighted_mean_dice_coef: 0.5141 - lr: 0.0010
# Epoch 13/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5054 - categorical_accuracy: 0.8117 - mean_dice_coef: 0.5930 - weighted_mean_dice_coef: 0.4946
# Epoch 13: val_loss improved from 0.48571 to 0.48255, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 201ms/step - loss: 0.5054 - categorical_accuracy: 0.8117 - mean_dice_coef: 0.5930 - weighted_mean_dice_coef: 0.4946 - val_loss: 0.4825 - val_categorical_accuracy: 0.8256 - val_mean_dice_coef: 0.6135 - val_weighted_mean_dice_coef: 0.5173 - lr: 0.0010
# Epoch 14/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5030 - categorical_accuracy: 0.8131 - mean_dice_coef: 0.5951 - weighted_mean_dice_coef: 0.4970
# Epoch 14: val_loss improved from 0.48255 to 0.47902, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 201ms/step - loss: 0.5030 - categorical_accuracy: 0.8131 - mean_dice_coef: 0.5951 - weighted_mean_dice_coef: 0.4970 - val_loss: 0.4790 - val_categorical_accuracy: 0.8241 - val_mean_dice_coef: 0.6158 - val_weighted_mean_dice_coef: 0.5209 - lr: 0.0010
# Epoch 15/200
# 183/183 [==============================] - ETA: 0s - loss: 0.5015 - categorical_accuracy: 0.8141 - mean_dice_coef: 0.5964 - weighted_mean_dice_coef: 0.4985
# Epoch 15: val_loss did not improve from 0.47902
# 183/183 [==============================] - 37s 202ms/step - loss: 0.5015 - categorical_accuracy: 0.8141 - mean_dice_coef: 0.5964 - weighted_mean_dice_coef: 0.4985 - val_loss: 0.4793 - val_categorical_accuracy: 0.8250 - val_mean_dice_coef: 0.6159 - val_weighted_mean_dice_coef: 0.5207 - lr: 0.0010
# Epoch 16/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4999 - categorical_accuracy: 0.8151 - mean_dice_coef: 0.5979 - weighted_mean_dice_coef: 0.5001
# Epoch 16: val_loss improved from 0.47902 to 0.47818, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 201ms/step - loss: 0.4999 - categorical_accuracy: 0.8151 - mean_dice_coef: 0.5979 - weighted_mean_dice_coef: 0.5001 - val_loss: 0.4782 - val_categorical_accuracy: 0.8280 - val_mean_dice_coef: 0.6174 - val_weighted_mean_dice_coef: 0.5217 - lr: 0.0010
# Epoch 17/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4986 - categorical_accuracy: 0.8158 - mean_dice_coef: 0.5990 - weighted_mean_dice_coef: 0.5014
# Epoch 17: val_loss did not improve from 0.47818
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4986 - categorical_accuracy: 0.8158 - mean_dice_coef: 0.5990 - weighted_mean_dice_coef: 0.5014 - val_loss: 0.4788 - val_categorical_accuracy: 0.8282 - val_mean_dice_coef: 0.6172 - val_weighted_mean_dice_coef: 0.5210 - lr: 0.0010
# Epoch 18/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4970 - categorical_accuracy: 0.8167 - mean_dice_coef: 0.6003 - weighted_mean_dice_coef: 0.5030
# Epoch 18: val_loss improved from 0.47818 to 0.47390, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 200ms/step - loss: 0.4970 - categorical_accuracy: 0.8167 - mean_dice_coef: 0.6003 - weighted_mean_dice_coef: 0.5030 - val_loss: 0.4739 - val_categorical_accuracy: 0.8315 - val_mean_dice_coef: 0.6212 - val_weighted_mean_dice_coef: 0.5259 - lr: 0.0010
# Epoch 19/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4962 - categorical_accuracy: 0.8174 - mean_dice_coef: 0.6011 - weighted_mean_dice_coef: 0.5038
# Epoch 19: val_loss improved from 0.47390 to 0.47381, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4962 - categorical_accuracy: 0.8174 - mean_dice_coef: 0.6011 - weighted_mean_dice_coef: 0.5038 - val_loss: 0.4738 - val_categorical_accuracy: 0.8272 - val_mean_dice_coef: 0.6204 - val_weighted_mean_dice_coef: 0.5260 - lr: 0.0010
# Epoch 20/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4949 - categorical_accuracy: 0.8182 - mean_dice_coef: 0.6023 - weighted_mean_dice_coef: 0.5051
# Epoch 20: val_loss improved from 0.47381 to 0.47040, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 204ms/step - loss: 0.4949 - categorical_accuracy: 0.8182 - mean_dice_coef: 0.6023 - weighted_mean_dice_coef: 0.5051 - val_loss: 0.4704 - val_categorical_accuracy: 0.8311 - val_mean_dice_coef: 0.6236 - val_weighted_mean_dice_coef: 0.5295 - lr: 0.0010
# Epoch 21/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4937 - categorical_accuracy: 0.8188 - mean_dice_coef: 0.6033 - weighted_mean_dice_coef: 0.5063
# Epoch 21: val_loss improved from 0.47040 to 0.47014, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 201ms/step - loss: 0.4937 - categorical_accuracy: 0.8188 - mean_dice_coef: 0.6033 - weighted_mean_dice_coef: 0.5063 - val_loss: 0.4701 - val_categorical_accuracy: 0.8279 - val_mean_dice_coef: 0.6233 - val_weighted_mean_dice_coef: 0.5298 - lr: 0.0010
# Epoch 22/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4926 - categorical_accuracy: 0.8193 - mean_dice_coef: 0.6042 - weighted_mean_dice_coef: 0.5074
# Epoch 22: val_loss did not improve from 0.47014
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4926 - categorical_accuracy: 0.8193 - mean_dice_coef: 0.6042 - weighted_mean_dice_coef: 0.5074 - val_loss: 0.4747 - val_categorical_accuracy: 0.8153 - val_mean_dice_coef: 0.6170 - val_weighted_mean_dice_coef: 0.5252 - lr: 0.0010
# Epoch 23/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4919 - categorical_accuracy: 0.8198 - mean_dice_coef: 0.6049 - weighted_mean_dice_coef: 0.5081
# Epoch 23: val_loss did not improve from 0.47014
# 183/183 [==============================] - 40s 217ms/step - loss: 0.4919 - categorical_accuracy: 0.8198 - mean_dice_coef: 0.6049 - weighted_mean_dice_coef: 0.5081 - val_loss: 0.4737 - val_categorical_accuracy: 0.8266 - val_mean_dice_coef: 0.6205 - val_weighted_mean_dice_coef: 0.5262 - lr: 0.0010
# Epoch 24/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4913 - categorical_accuracy: 0.8202 - mean_dice_coef: 0.6054 - weighted_mean_dice_coef: 0.5087
# Epoch 24: val_loss did not improve from 0.47014
# 183/183 [==============================] - 44s 238ms/step - loss: 0.4913 - categorical_accuracy: 0.8202 - mean_dice_coef: 0.6054 - weighted_mean_dice_coef: 0.5087 - val_loss: 0.4780 - val_categorical_accuracy: 0.8209 - val_mean_dice_coef: 0.6161 - val_weighted_mean_dice_coef: 0.5218 - lr: 0.0010
# Epoch 25/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4905 - categorical_accuracy: 0.8208 - mean_dice_coef: 0.6062 - weighted_mean_dice_coef: 0.5095
# Epoch 25: val_loss improved from 0.47014 to 0.46794, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4905 - categorical_accuracy: 0.8208 - mean_dice_coef: 0.6062 - weighted_mean_dice_coef: 0.5095 - val_loss: 0.4679 - val_categorical_accuracy: 0.8264 - val_mean_dice_coef: 0.6245 - val_weighted_mean_dice_coef: 0.5319 - lr: 0.0010
# Epoch 26/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4898 - categorical_accuracy: 0.8210 - mean_dice_coef: 0.6067 - weighted_mean_dice_coef: 0.5102
# Epoch 26: val_loss did not improve from 0.46794
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4898 - categorical_accuracy: 0.8210 - mean_dice_coef: 0.6067 - weighted_mean_dice_coef: 0.5102 - val_loss: 0.4744 - val_categorical_accuracy: 0.8249 - val_mean_dice_coef: 0.6198 - val_weighted_mean_dice_coef: 0.5254 - lr: 0.0010
# Epoch 27/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4887 - categorical_accuracy: 0.8216 - mean_dice_coef: 0.6077 - weighted_mean_dice_coef: 0.5113
# Epoch 27: val_loss did not improve from 0.46794
# 183/183 [==============================] - 38s 205ms/step - loss: 0.4887 - categorical_accuracy: 0.8216 - mean_dice_coef: 0.6077 - weighted_mean_dice_coef: 0.5113 - val_loss: 0.4707 - val_categorical_accuracy: 0.8286 - val_mean_dice_coef: 0.6232 - val_weighted_mean_dice_coef: 0.5291 - lr: 0.0010
# Epoch 28/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4883 - categorical_accuracy: 0.8217 - mean_dice_coef: 0.6080 - weighted_mean_dice_coef: 0.5117
# Epoch 28: val_loss did not improve from 0.46794
# 183/183 [==============================] - 38s 205ms/step - loss: 0.4883 - categorical_accuracy: 0.8217 - mean_dice_coef: 0.6080 - weighted_mean_dice_coef: 0.5117 - val_loss: 0.4704 - val_categorical_accuracy: 0.8179 - val_mean_dice_coef: 0.6208 - val_weighted_mean_dice_coef: 0.5294 - lr: 0.0010
# Epoch 29/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4879 - categorical_accuracy: 0.8223 - mean_dice_coef: 0.6084 - weighted_mean_dice_coef: 0.5121
# Epoch 29: val_loss did not improve from 0.46794
# 183/183 [==============================] - 37s 203ms/step - loss: 0.4879 - categorical_accuracy: 0.8223 - mean_dice_coef: 0.6084 - weighted_mean_dice_coef: 0.5121 - val_loss: 0.4743 - val_categorical_accuracy: 0.8321 - val_mean_dice_coef: 0.6216 - val_weighted_mean_dice_coef: 0.5255 - lr: 0.0010
# Epoch 30/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4871 - categorical_accuracy: 0.8226 - mean_dice_coef: 0.6091 - weighted_mean_dice_coef: 0.5129
# Epoch 30: val_loss improved from 0.46794 to 0.46580, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4871 - categorical_accuracy: 0.8226 - mean_dice_coef: 0.6091 - weighted_mean_dice_coef: 0.5129 - val_loss: 0.4658 - val_categorical_accuracy: 0.8358 - val_mean_dice_coef: 0.6283 - val_weighted_mean_dice_coef: 0.5341 - lr: 0.0010
# Epoch 31/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4865 - categorical_accuracy: 0.8230 - mean_dice_coef: 0.6096 - weighted_mean_dice_coef: 0.5135
# Epoch 31: val_loss did not improve from 0.46580
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4865 - categorical_accuracy: 0.8230 - mean_dice_coef: 0.6096 - weighted_mean_dice_coef: 0.5135 - val_loss: 0.4716 - val_categorical_accuracy: 0.8279 - val_mean_dice_coef: 0.6224 - val_weighted_mean_dice_coef: 0.5282 - lr: 0.0010
# Epoch 32/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4858 - categorical_accuracy: 0.8229 - mean_dice_coef: 0.6101 - weighted_mean_dice_coef: 0.5142
# Epoch 32: val_loss did not improve from 0.46580
# 183/183 [==============================] - 37s 203ms/step - loss: 0.4858 - categorical_accuracy: 0.8229 - mean_dice_coef: 0.6101 - weighted_mean_dice_coef: 0.5142 - val_loss: 0.4740 - val_categorical_accuracy: 0.8308 - val_mean_dice_coef: 0.6215 - val_weighted_mean_dice_coef: 0.5258 - lr: 0.0010
# Epoch 33/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4858 - categorical_accuracy: 0.8233 - mean_dice_coef: 0.6103 - weighted_mean_dice_coef: 0.5142
# Epoch 33: val_loss did not improve from 0.46580
# 183/183 [==============================] - 38s 205ms/step - loss: 0.4858 - categorical_accuracy: 0.8233 - mean_dice_coef: 0.6103 - weighted_mean_dice_coef: 0.5142 - val_loss: 0.4680 - val_categorical_accuracy: 0.8254 - val_mean_dice_coef: 0.6246 - val_weighted_mean_dice_coef: 0.5319 - lr: 0.0010
# Epoch 34/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4851 - categorical_accuracy: 0.8234 - mean_dice_coef: 0.6107 - weighted_mean_dice_coef: 0.5149
# Epoch 34: val_loss did not improve from 0.46580
# 183/183 [==============================] - 38s 204ms/step - loss: 0.4851 - categorical_accuracy: 0.8234 - mean_dice_coef: 0.6107 - weighted_mean_dice_coef: 0.5149 - val_loss: 0.4735 - val_categorical_accuracy: 0.8253 - val_mean_dice_coef: 0.6205 - val_weighted_mean_dice_coef: 0.5263 - lr: 0.0010
# Epoch 35/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4851 - categorical_accuracy: 0.8237 - mean_dice_coef: 0.6109 - weighted_mean_dice_coef: 0.5149
# Epoch 35: val_loss did not improve from 0.46580
# 183/183 [==============================] - 37s 204ms/step - loss: 0.4851 - categorical_accuracy: 0.8237 - mean_dice_coef: 0.6109 - weighted_mean_dice_coef: 0.5149 - val_loss: 0.4714 - val_categorical_accuracy: 0.8323 - val_mean_dice_coef: 0.6234 - val_weighted_mean_dice_coef: 0.5285 - lr: 0.0010
# Epoch 36/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4840 - categorical_accuracy: 0.8239 - mean_dice_coef: 0.6117 - weighted_mean_dice_coef: 0.5160
# Epoch 36: val_loss did not improve from 0.46580
# 183/183 [==============================] - 37s 203ms/step - loss: 0.4840 - categorical_accuracy: 0.8239 - mean_dice_coef: 0.6117 - weighted_mean_dice_coef: 0.5160 - val_loss: 0.4673 - val_categorical_accuracy: 0.8298 - val_mean_dice_coef: 0.6259 - val_weighted_mean_dice_coef: 0.5326 - lr: 0.0010
# Epoch 37/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4838 - categorical_accuracy: 0.8240 - mean_dice_coef: 0.6118 - weighted_mean_dice_coef: 0.5162
# Epoch 37: val_loss did not improve from 0.46580
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4838 - categorical_accuracy: 0.8240 - mean_dice_coef: 0.6118 - weighted_mean_dice_coef: 0.5162 - val_loss: 0.4660 - val_categorical_accuracy: 0.8318 - val_mean_dice_coef: 0.6272 - val_weighted_mean_dice_coef: 0.5338 - lr: 0.0010
# Epoch 38/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4831 - categorical_accuracy: 0.8244 - mean_dice_coef: 0.6124 - weighted_mean_dice_coef: 0.5169
# Epoch 38: val_loss did not improve from 0.46580
# 183/183 [==============================] - 41s 223ms/step - loss: 0.4831 - categorical_accuracy: 0.8244 - mean_dice_coef: 0.6124 - weighted_mean_dice_coef: 0.5169 - val_loss: 0.4690 - val_categorical_accuracy: 0.8284 - val_mean_dice_coef: 0.6245 - val_weighted_mean_dice_coef: 0.5309 - lr: 0.0010
# Epoch 39/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4825 - categorical_accuracy: 0.8246 - mean_dice_coef: 0.6129 - weighted_mean_dice_coef: 0.5175
# Epoch 39: val_loss did not improve from 0.46580
# 183/183 [==============================] - 38s 209ms/step - loss: 0.4825 - categorical_accuracy: 0.8246 - mean_dice_coef: 0.6129 - weighted_mean_dice_coef: 0.5175 - val_loss: 0.4688 - val_categorical_accuracy: 0.8343 - val_mean_dice_coef: 0.6262 - val_weighted_mean_dice_coef: 0.5311 - lr: 0.0010
# Epoch 40/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4822 - categorical_accuracy: 0.8248 - mean_dice_coef: 0.6132 - weighted_mean_dice_coef: 0.5178
# Epoch 40: val_loss improved from 0.46580 to 0.46183, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 200ms/step - loss: 0.4822 - categorical_accuracy: 0.8248 - mean_dice_coef: 0.6132 - weighted_mean_dice_coef: 0.5178 - val_loss: 0.4618 - val_categorical_accuracy: 0.8332 - val_mean_dice_coef: 0.6306 - val_weighted_mean_dice_coef: 0.5380 - lr: 0.0010
# Epoch 41/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4821 - categorical_accuracy: 0.8249 - mean_dice_coef: 0.6133 - weighted_mean_dice_coef: 0.5179
# Epoch 41: val_loss did not improve from 0.46183
# 183/183 [==============================] - 37s 201ms/step - loss: 0.4821 - categorical_accuracy: 0.8249 - mean_dice_coef: 0.6133 - weighted_mean_dice_coef: 0.5179 - val_loss: 0.4661 - val_categorical_accuracy: 0.8332 - val_mean_dice_coef: 0.6278 - val_weighted_mean_dice_coef: 0.5338 - lr: 0.0010
# Epoch 42/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4814 - categorical_accuracy: 0.8252 - mean_dice_coef: 0.6139 - weighted_mean_dice_coef: 0.5186
# Epoch 42: val_loss did not improve from 0.46183
# 183/183 [==============================] - 37s 200ms/step - loss: 0.4814 - categorical_accuracy: 0.8252 - mean_dice_coef: 0.6139 - weighted_mean_dice_coef: 0.5186 - val_loss: 0.4627 - val_categorical_accuracy: 0.8302 - val_mean_dice_coef: 0.6293 - val_weighted_mean_dice_coef: 0.5371 - lr: 0.0010
# Epoch 43/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4817 - categorical_accuracy: 0.8253 - mean_dice_coef: 0.6137 - weighted_mean_dice_coef: 0.5183
# Epoch 43: val_loss did not improve from 0.46183
# 183/183 [==============================] - 37s 201ms/step - loss: 0.4817 - categorical_accuracy: 0.8253 - mean_dice_coef: 0.6137 - weighted_mean_dice_coef: 0.5183 - val_loss: 0.4630 - val_categorical_accuracy: 0.8302 - val_mean_dice_coef: 0.6291 - val_weighted_mean_dice_coef: 0.5368 - lr: 0.0010
# Epoch 44/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4811 - categorical_accuracy: 0.8255 - mean_dice_coef: 0.6142 - weighted_mean_dice_coef: 0.5189
# Epoch 44: val_loss did not improve from 0.46183
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4811 - categorical_accuracy: 0.8255 - mean_dice_coef: 0.6142 - weighted_mean_dice_coef: 0.5189 - val_loss: 0.4650 - val_categorical_accuracy: 0.8346 - val_mean_dice_coef: 0.6289 - val_weighted_mean_dice_coef: 0.5349 - lr: 0.0010
# Epoch 45/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4810 - categorical_accuracy: 0.8255 - mean_dice_coef: 0.6143 - weighted_mean_dice_coef: 0.5190
# Epoch 45: val_loss did not improve from 0.46183
# 183/183 [==============================] - 37s 201ms/step - loss: 0.4810 - categorical_accuracy: 0.8255 - mean_dice_coef: 0.6143 - weighted_mean_dice_coef: 0.5190 - val_loss: 0.4642 - val_categorical_accuracy: 0.8299 - val_mean_dice_coef: 0.6284 - val_weighted_mean_dice_coef: 0.5357 - lr: 0.0010
# Epoch 46/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4807 - categorical_accuracy: 0.8257 - mean_dice_coef: 0.6145 - weighted_mean_dice_coef: 0.5193
# Epoch 46: val_loss improved from 0.46183 to 0.46143, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 200ms/step - loss: 0.4807 - categorical_accuracy: 0.8257 - mean_dice_coef: 0.6145 - weighted_mean_dice_coef: 0.5193 - val_loss: 0.4614 - val_categorical_accuracy: 0.8375 - val_mean_dice_coef: 0.6319 - val_weighted_mean_dice_coef: 0.5384 - lr: 0.0010
# Epoch 47/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4803 - categorical_accuracy: 0.8259 - mean_dice_coef: 0.6148 - weighted_mean_dice_coef: 0.5197
# Epoch 47: val_loss did not improve from 0.46143
# 183/183 [==============================] - 37s 203ms/step - loss: 0.4803 - categorical_accuracy: 0.8259 - mean_dice_coef: 0.6148 - weighted_mean_dice_coef: 0.5197 - val_loss: 0.4641 - val_categorical_accuracy: 0.8351 - val_mean_dice_coef: 0.6296 - val_weighted_mean_dice_coef: 0.5357 - lr: 0.0010
# Epoch 48/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4799 - categorical_accuracy: 0.8261 - mean_dice_coef: 0.6152 - weighted_mean_dice_coef: 0.5201
# Epoch 48: val_loss did not improve from 0.46143
# 183/183 [==============================] - 39s 211ms/step - loss: 0.4799 - categorical_accuracy: 0.8261 - mean_dice_coef: 0.6152 - weighted_mean_dice_coef: 0.5201 - val_loss: 0.4661 - val_categorical_accuracy: 0.8261 - val_mean_dice_coef: 0.6261 - val_weighted_mean_dice_coef: 0.5337 - lr: 0.0010
# Epoch 49/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4798 - categorical_accuracy: 0.8261 - mean_dice_coef: 0.6153 - weighted_mean_dice_coef: 0.5202
# Epoch 49: val_loss did not improve from 0.46143
# 183/183 [==============================] - 38s 206ms/step - loss: 0.4798 - categorical_accuracy: 0.8261 - mean_dice_coef: 0.6153 - weighted_mean_dice_coef: 0.5202 - val_loss: 0.4645 - val_categorical_accuracy: 0.8270 - val_mean_dice_coef: 0.6276 - val_weighted_mean_dice_coef: 0.5354 - lr: 0.0010
# Epoch 50/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4792 - categorical_accuracy: 0.8265 - mean_dice_coef: 0.6158 - weighted_mean_dice_coef: 0.5208
# Epoch 50: val_loss improved from 0.46143 to 0.46105, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 39s 214ms/step - loss: 0.4792 - categorical_accuracy: 0.8265 - mean_dice_coef: 0.6158 - weighted_mean_dice_coef: 0.5208 - val_loss: 0.4611 - val_categorical_accuracy: 0.8331 - val_mean_dice_coef: 0.6314 - val_weighted_mean_dice_coef: 0.5388 - lr: 0.0010
# Epoch 51/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4788 - categorical_accuracy: 0.8265 - mean_dice_coef: 0.6161 - weighted_mean_dice_coef: 0.5212
# Epoch 51: val_loss did not improve from 0.46105
# 183/183 [==============================] - 41s 222ms/step - loss: 0.4788 - categorical_accuracy: 0.8265 - mean_dice_coef: 0.6161 - weighted_mean_dice_coef: 0.5212 - val_loss: 0.4647 - val_categorical_accuracy: 0.8315 - val_mean_dice_coef: 0.6286 - val_weighted_mean_dice_coef: 0.5351 - lr: 0.0010
# Epoch 52/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4785 - categorical_accuracy: 0.8267 - mean_dice_coef: 0.6163 - weighted_mean_dice_coef: 0.5215
# Epoch 52: val_loss did not improve from 0.46105
# 183/183 [==============================] - 40s 217ms/step - loss: 0.4785 - categorical_accuracy: 0.8267 - mean_dice_coef: 0.6163 - weighted_mean_dice_coef: 0.5215 - val_loss: 0.4672 - val_categorical_accuracy: 0.8222 - val_mean_dice_coef: 0.6243 - val_weighted_mean_dice_coef: 0.5326 - lr: 0.0010
# Epoch 53/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4782 - categorical_accuracy: 0.8268 - mean_dice_coef: 0.6165 - weighted_mean_dice_coef: 0.5217
# Epoch 53: val_loss did not improve from 0.46105
# 183/183 [==============================] - 40s 215ms/step - loss: 0.4782 - categorical_accuracy: 0.8268 - mean_dice_coef: 0.6165 - weighted_mean_dice_coef: 0.5217 - val_loss: 0.4649 - val_categorical_accuracy: 0.8339 - val_mean_dice_coef: 0.6289 - val_weighted_mean_dice_coef: 0.5350 - lr: 0.0010
# Epoch 54/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4784 - categorical_accuracy: 0.8268 - mean_dice_coef: 0.6165 - weighted_mean_dice_coef: 0.5216
# Epoch 54: val_loss did not improve from 0.46105
# 183/183 [==============================] - 38s 206ms/step - loss: 0.4784 - categorical_accuracy: 0.8268 - mean_dice_coef: 0.6165 - weighted_mean_dice_coef: 0.5216 - val_loss: 0.4666 - val_categorical_accuracy: 0.8347 - val_mean_dice_coef: 0.6277 - val_weighted_mean_dice_coef: 0.5333 - lr: 0.0010
# Epoch 55/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4784 - categorical_accuracy: 0.8268 - mean_dice_coef: 0.6164 - weighted_mean_dice_coef: 0.5216
# Epoch 55: val_loss did not improve from 0.46105
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4784 - categorical_accuracy: 0.8268 - mean_dice_coef: 0.6164 - weighted_mean_dice_coef: 0.5216 - val_loss: 0.4649 - val_categorical_accuracy: 0.8301 - val_mean_dice_coef: 0.6277 - val_weighted_mean_dice_coef: 0.5349 - lr: 0.0010
# Epoch 56/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4785 - categorical_accuracy: 0.8271 - mean_dice_coef: 0.6165 - weighted_mean_dice_coef: 0.5216
# Epoch 56: val_loss did not improve from 0.46105
# 183/183 [==============================] - 36s 199ms/step - loss: 0.4785 - categorical_accuracy: 0.8271 - mean_dice_coef: 0.6165 - weighted_mean_dice_coef: 0.5216 - val_loss: 0.4618 - val_categorical_accuracy: 0.8330 - val_mean_dice_coef: 0.6309 - val_weighted_mean_dice_coef: 0.5381 - lr: 0.0010
# Epoch 57/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4779 - categorical_accuracy: 0.8269 - mean_dice_coef: 0.6169 - weighted_mean_dice_coef: 0.5221
# Epoch 57: val_loss did not improve from 0.46105
# 183/183 [==============================] - 37s 199ms/step - loss: 0.4779 - categorical_accuracy: 0.8269 - mean_dice_coef: 0.6169 - weighted_mean_dice_coef: 0.5221 - val_loss: 0.4652 - val_categorical_accuracy: 0.8402 - val_mean_dice_coef: 0.6297 - val_weighted_mean_dice_coef: 0.5347 - lr: 0.0010
# Epoch 58/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4773 - categorical_accuracy: 0.8274 - mean_dice_coef: 0.6174 - weighted_mean_dice_coef: 0.5227
# Epoch 58: val_loss improved from 0.46105 to 0.45794, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 37s 204ms/step - loss: 0.4773 - categorical_accuracy: 0.8274 - mean_dice_coef: 0.6174 - weighted_mean_dice_coef: 0.5227 - val_loss: 0.4579 - val_categorical_accuracy: 0.8337 - val_mean_dice_coef: 0.6337 - val_weighted_mean_dice_coef: 0.5420 - lr: 0.0010
# Epoch 59/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4773 - categorical_accuracy: 0.8272 - mean_dice_coef: 0.6174 - weighted_mean_dice_coef: 0.5227
# Epoch 59: val_loss did not improve from 0.45794
# 183/183 [==============================] - 37s 203ms/step - loss: 0.4773 - categorical_accuracy: 0.8272 - mean_dice_coef: 0.6174 - weighted_mean_dice_coef: 0.5227 - val_loss: 0.4612 - val_categorical_accuracy: 0.8382 - val_mean_dice_coef: 0.6324 - val_weighted_mean_dice_coef: 0.5388 - lr: 0.0010
# Epoch 60/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4771 - categorical_accuracy: 0.8274 - mean_dice_coef: 0.6175 - weighted_mean_dice_coef: 0.5229
# Epoch 60: val_loss did not improve from 0.45794
# 183/183 [==============================] - 38s 205ms/step - loss: 0.4771 - categorical_accuracy: 0.8274 - mean_dice_coef: 0.6175 - weighted_mean_dice_coef: 0.5229 - val_loss: 0.4637 - val_categorical_accuracy: 0.8341 - val_mean_dice_coef: 0.6297 - val_weighted_mean_dice_coef: 0.5361 - lr: 0.0010
# Epoch 61/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4767 - categorical_accuracy: 0.8276 - mean_dice_coef: 0.6179 - weighted_mean_dice_coef: 0.5233
# Epoch 61: val_loss did not improve from 0.45794
# 183/183 [==============================] - 38s 209ms/step - loss: 0.4767 - categorical_accuracy: 0.8276 - mean_dice_coef: 0.6179 - weighted_mean_dice_coef: 0.5233 - val_loss: 0.4591 - val_categorical_accuracy: 0.8314 - val_mean_dice_coef: 0.6324 - val_weighted_mean_dice_coef: 0.5408 - lr: 0.0010
# Epoch 62/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4771 - categorical_accuracy: 0.8275 - mean_dice_coef: 0.6176 - weighted_mean_dice_coef: 0.5229
# Epoch 62: val_loss did not improve from 0.45794
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4771 - categorical_accuracy: 0.8275 - mean_dice_coef: 0.6176 - weighted_mean_dice_coef: 0.5229 - val_loss: 0.4645 - val_categorical_accuracy: 0.8281 - val_mean_dice_coef: 0.6277 - val_weighted_mean_dice_coef: 0.5353 - lr: 0.0010
# Epoch 63/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4765 - categorical_accuracy: 0.8276 - mean_dice_coef: 0.6180 - weighted_mean_dice_coef: 0.5235
# Epoch 63: val_loss did not improve from 0.45794
# 183/183 [==============================] - 38s 205ms/step - loss: 0.4765 - categorical_accuracy: 0.8276 - mean_dice_coef: 0.6180 - weighted_mean_dice_coef: 0.5235 - val_loss: 0.4630 - val_categorical_accuracy: 0.8322 - val_mean_dice_coef: 0.6298 - val_weighted_mean_dice_coef: 0.5368 - lr: 0.0010
# Epoch 64/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4765 - categorical_accuracy: 0.8279 - mean_dice_coef: 0.6181 - weighted_mean_dice_coef: 0.5235
# Epoch 64: val_loss improved from 0.45794 to 0.45736, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 39s 211ms/step - loss: 0.4765 - categorical_accuracy: 0.8279 - mean_dice_coef: 0.6181 - weighted_mean_dice_coef: 0.5235 - val_loss: 0.4574 - val_categorical_accuracy: 0.8341 - val_mean_dice_coef: 0.6342 - val_weighted_mean_dice_coef: 0.5426 - lr: 0.0010
# Epoch 65/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4760 - categorical_accuracy: 0.8278 - mean_dice_coef: 0.6184 - weighted_mean_dice_coef: 0.5240
# Epoch 65: val_loss did not improve from 0.45736
# 183/183 [==============================] - 39s 212ms/step - loss: 0.4760 - categorical_accuracy: 0.8278 - mean_dice_coef: 0.6184 - weighted_mean_dice_coef: 0.5240 - val_loss: 0.4660 - val_categorical_accuracy: 0.8307 - val_mean_dice_coef: 0.6273 - val_weighted_mean_dice_coef: 0.5338 - lr: 0.0010
# Epoch 66/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4759 - categorical_accuracy: 0.8280 - mean_dice_coef: 0.6185 - weighted_mean_dice_coef: 0.5241
# Epoch 66: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 208ms/step - loss: 0.4759 - categorical_accuracy: 0.8280 - mean_dice_coef: 0.6185 - weighted_mean_dice_coef: 0.5241 - val_loss: 0.4584 - val_categorical_accuracy: 0.8388 - val_mean_dice_coef: 0.6345 - val_weighted_mean_dice_coef: 0.5415 - lr: 0.0010
# Epoch 67/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4759 - categorical_accuracy: 0.8280 - mean_dice_coef: 0.6186 - weighted_mean_dice_coef: 0.5241
# Epoch 67: val_loss did not improve from 0.45736
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4759 - categorical_accuracy: 0.8280 - mean_dice_coef: 0.6186 - weighted_mean_dice_coef: 0.5241 - val_loss: 0.4577 - val_categorical_accuracy: 0.8394 - val_mean_dice_coef: 0.6349 - val_weighted_mean_dice_coef: 0.5422 - lr: 0.0010
# Epoch 68/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4758 - categorical_accuracy: 0.8283 - mean_dice_coef: 0.6187 - weighted_mean_dice_coef: 0.5242
# Epoch 68: val_loss did not improve from 0.45736
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4758 - categorical_accuracy: 0.8283 - mean_dice_coef: 0.6187 - weighted_mean_dice_coef: 0.5242 - val_loss: 0.4688 - val_categorical_accuracy: 0.8250 - val_mean_dice_coef: 0.6239 - val_weighted_mean_dice_coef: 0.5310 - lr: 0.0010
# Epoch 69/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4757 - categorical_accuracy: 0.8282 - mean_dice_coef: 0.6188 - weighted_mean_dice_coef: 0.5243
# Epoch 69: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4757 - categorical_accuracy: 0.8282 - mean_dice_coef: 0.6188 - weighted_mean_dice_coef: 0.5243 - val_loss: 0.4621 - val_categorical_accuracy: 0.8307 - val_mean_dice_coef: 0.6302 - val_weighted_mean_dice_coef: 0.5378 - lr: 0.0010
# Epoch 70/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4747 - categorical_accuracy: 0.8284 - mean_dice_coef: 0.6195 - weighted_mean_dice_coef: 0.5253
# Epoch 70: val_loss did not improve from 0.45736
# 183/183 [==============================] - 40s 220ms/step - loss: 0.4747 - categorical_accuracy: 0.8284 - mean_dice_coef: 0.6195 - weighted_mean_dice_coef: 0.5253 - val_loss: 0.4607 - val_categorical_accuracy: 0.8349 - val_mean_dice_coef: 0.6322 - val_weighted_mean_dice_coef: 0.5392 - lr: 0.0010
# Epoch 71/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4753 - categorical_accuracy: 0.8284 - mean_dice_coef: 0.6191 - weighted_mean_dice_coef: 0.5247
# Epoch 71: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 208ms/step - loss: 0.4753 - categorical_accuracy: 0.8284 - mean_dice_coef: 0.6191 - weighted_mean_dice_coef: 0.5247 - val_loss: 0.4591 - val_categorical_accuracy: 0.8288 - val_mean_dice_coef: 0.6319 - val_weighted_mean_dice_coef: 0.5408 - lr: 0.0010
# Epoch 72/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4747 - categorical_accuracy: 0.8286 - mean_dice_coef: 0.6196 - weighted_mean_dice_coef: 0.5254
# Epoch 72: val_loss did not improve from 0.45736
# 183/183 [==============================] - 37s 203ms/step - loss: 0.4747 - categorical_accuracy: 0.8286 - mean_dice_coef: 0.6196 - weighted_mean_dice_coef: 0.5254 - val_loss: 0.4620 - val_categorical_accuracy: 0.8275 - val_mean_dice_coef: 0.6296 - val_weighted_mean_dice_coef: 0.5379 - lr: 0.0010
# Epoch 73/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4753 - categorical_accuracy: 0.8285 - mean_dice_coef: 0.6192 - weighted_mean_dice_coef: 0.5247
# Epoch 73: val_loss did not improve from 0.45736
# 183/183 [==============================] - 42s 227ms/step - loss: 0.4753 - categorical_accuracy: 0.8285 - mean_dice_coef: 0.6192 - weighted_mean_dice_coef: 0.5247 - val_loss: 0.4583 - val_categorical_accuracy: 0.8360 - val_mean_dice_coef: 0.6340 - val_weighted_mean_dice_coef: 0.5416 - lr: 0.0010
# Epoch 74/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4744 - categorical_accuracy: 0.8286 - mean_dice_coef: 0.6198 - weighted_mean_dice_coef: 0.5256
# Epoch 74: val_loss did not improve from 0.45736
# 183/183 [==============================] - 39s 214ms/step - loss: 0.4744 - categorical_accuracy: 0.8286 - mean_dice_coef: 0.6198 - weighted_mean_dice_coef: 0.5256 - val_loss: 0.4594 - val_categorical_accuracy: 0.8284 - val_mean_dice_coef: 0.6315 - val_weighted_mean_dice_coef: 0.5404 - lr: 0.0010
# Epoch 75/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4742 - categorical_accuracy: 0.8287 - mean_dice_coef: 0.6200 - weighted_mean_dice_coef: 0.5258
# Epoch 75: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 205ms/step - loss: 0.4742 - categorical_accuracy: 0.8287 - mean_dice_coef: 0.6200 - weighted_mean_dice_coef: 0.5258 - val_loss: 0.4693 - val_categorical_accuracy: 0.8292 - val_mean_dice_coef: 0.6248 - val_weighted_mean_dice_coef: 0.5306 - lr: 0.0010
# Epoch 76/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4740 - categorical_accuracy: 0.8290 - mean_dice_coef: 0.6202 - weighted_mean_dice_coef: 0.5260
# Epoch 76: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 206ms/step - loss: 0.4740 - categorical_accuracy: 0.8290 - mean_dice_coef: 0.6202 - weighted_mean_dice_coef: 0.5260 - val_loss: 0.4620 - val_categorical_accuracy: 0.8330 - val_mean_dice_coef: 0.6308 - val_weighted_mean_dice_coef: 0.5378 - lr: 0.0010
# Epoch 77/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4744 - categorical_accuracy: 0.8289 - mean_dice_coef: 0.6199 - weighted_mean_dice_coef: 0.5256
# Epoch 77: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4744 - categorical_accuracy: 0.8289 - mean_dice_coef: 0.6199 - weighted_mean_dice_coef: 0.5256 - val_loss: 0.4598 - val_categorical_accuracy: 0.8325 - val_mean_dice_coef: 0.6322 - val_weighted_mean_dice_coef: 0.5401 - lr: 0.0010
# Epoch 78/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4741 - categorical_accuracy: 0.8289 - mean_dice_coef: 0.6201 - weighted_mean_dice_coef: 0.5259
# Epoch 78: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 206ms/step - loss: 0.4741 - categorical_accuracy: 0.8289 - mean_dice_coef: 0.6201 - weighted_mean_dice_coef: 0.5259 - val_loss: 0.4614 - val_categorical_accuracy: 0.8332 - val_mean_dice_coef: 0.6313 - val_weighted_mean_dice_coef: 0.5385 - lr: 0.0010
# Epoch 79/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4739 - categorical_accuracy: 0.8288 - mean_dice_coef: 0.6202 - weighted_mean_dice_coef: 0.5261
# Epoch 79: val_loss did not improve from 0.45736
# 183/183 [==============================] - 37s 202ms/step - loss: 0.4739 - categorical_accuracy: 0.8288 - mean_dice_coef: 0.6202 - weighted_mean_dice_coef: 0.5261 - val_loss: 0.4599 - val_categorical_accuracy: 0.8312 - val_mean_dice_coef: 0.6319 - val_weighted_mean_dice_coef: 0.5400 - lr: 0.0010
# Epoch 80/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4736 - categorical_accuracy: 0.8289 - mean_dice_coef: 0.6205 - weighted_mean_dice_coef: 0.5264
# Epoch 80: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 206ms/step - loss: 0.4736 - categorical_accuracy: 0.8289 - mean_dice_coef: 0.6205 - weighted_mean_dice_coef: 0.5264 - val_loss: 0.4574 - val_categorical_accuracy: 0.8335 - val_mean_dice_coef: 0.6342 - val_weighted_mean_dice_coef: 0.5425 - lr: 0.0010
# Epoch 81/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4735 - categorical_accuracy: 0.8292 - mean_dice_coef: 0.6206 - weighted_mean_dice_coef: 0.5265
# Epoch 81: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 207ms/step - loss: 0.4735 - categorical_accuracy: 0.8292 - mean_dice_coef: 0.6206 - weighted_mean_dice_coef: 0.5265 - val_loss: 0.4610 - val_categorical_accuracy: 0.8403 - val_mean_dice_coef: 0.6328 - val_weighted_mean_dice_coef: 0.5389 - lr: 0.0010
# Epoch 82/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4734 - categorical_accuracy: 0.8293 - mean_dice_coef: 0.6207 - weighted_mean_dice_coef: 0.5266
# Epoch 82: val_loss did not improve from 0.45736
# 183/183 [==============================] - 38s 206ms/step - loss: 0.4734 - categorical_accuracy: 0.8293 - mean_dice_coef: 0.6207 - weighted_mean_dice_coef: 0.5266 - val_loss: 0.4588 - val_categorical_accuracy: 0.8275 - val_mean_dice_coef: 0.6317 - val_weighted_mean_dice_coef: 0.5412 - lr: 0.0010
# Epoch 83/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4731 - categorical_accuracy: 0.8295 - mean_dice_coef: 0.6210 - weighted_mean_dice_coef: 0.5269
# Epoch 83: val_loss did not improve from 0.45736
# 183/183 [==============================] - 37s 204ms/step - loss: 0.4731 - categorical_accuracy: 0.8295 - mean_dice_coef: 0.6210 - weighted_mean_dice_coef: 0.5269 - val_loss: 0.4576 - val_categorical_accuracy: 0.8341 - val_mean_dice_coef: 0.6341 - val_weighted_mean_dice_coef: 0.5422 - lr: 0.0010
# Epoch 84/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4736 - categorical_accuracy: 0.8291 - mean_dice_coef: 0.6205 - weighted_mean_dice_coef: 0.5264
# Epoch 84: val_loss did not improve from 0.45736
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 183/183 [==============================] - 37s 203ms/step - loss: 0.4736 - categorical_accuracy: 0.8291 - mean_dice_coef: 0.6205 - weighted_mean_dice_coef: 0.5264 - val_loss: 0.4594 - val_categorical_accuracy: 0.8380 - val_mean_dice_coef: 0.6336 - val_weighted_mean_dice_coef: 0.5404 - lr: 0.0010
# Epoch 85/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4706 - categorical_accuracy: 0.8302 - mean_dice_coef: 0.6229 - weighted_mean_dice_coef: 0.5294
# Epoch 85: val_loss did not improve from 0.45736
# 183/183 [==============================] - 37s 204ms/step - loss: 0.4706 - categorical_accuracy: 0.8302 - mean_dice_coef: 0.6229 - weighted_mean_dice_coef: 0.5294 - val_loss: 0.4574 - val_categorical_accuracy: 0.8327 - val_mean_dice_coef: 0.6338 - val_weighted_mean_dice_coef: 0.5425 - lr: 5.0000e-04
# Epoch 86/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4698 - categorical_accuracy: 0.8305 - mean_dice_coef: 0.6236 - weighted_mean_dice_coef: 0.5302
# Epoch 86: val_loss improved from 0.45736 to 0.45322, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 38s 204ms/step - loss: 0.4698 - categorical_accuracy: 0.8305 - mean_dice_coef: 0.6236 - weighted_mean_dice_coef: 0.5302 - val_loss: 0.4532 - val_categorical_accuracy: 0.8356 - val_mean_dice_coef: 0.6376 - val_weighted_mean_dice_coef: 0.5467 - lr: 5.0000e-04
# Epoch 87/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4695 - categorical_accuracy: 0.8307 - mean_dice_coef: 0.6238 - weighted_mean_dice_coef: 0.5305
# Epoch 87: val_loss did not improve from 0.45322
# 183/183 [==============================] - 38s 204ms/step - loss: 0.4695 - categorical_accuracy: 0.8307 - mean_dice_coef: 0.6238 - weighted_mean_dice_coef: 0.5305 - val_loss: 0.4538 - val_categorical_accuracy: 0.8368 - val_mean_dice_coef: 0.6375 - val_weighted_mean_dice_coef: 0.5460 - lr: 5.0000e-04
# Epoch 88/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4692 - categorical_accuracy: 0.8308 - mean_dice_coef: 0.6240 - weighted_mean_dice_coef: 0.5308
# Epoch 88: val_loss did not improve from 0.45322
# 183/183 [==============================] - 37s 204ms/step - loss: 0.4692 - categorical_accuracy: 0.8308 - mean_dice_coef: 0.6240 - weighted_mean_dice_coef: 0.5308 - val_loss: 0.4552 - val_categorical_accuracy: 0.8363 - val_mean_dice_coef: 0.6364 - val_weighted_mean_dice_coef: 0.5447 - lr: 5.0000e-04
# Epoch 89/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4690 - categorical_accuracy: 0.8309 - mean_dice_coef: 0.6242 - weighted_mean_dice_coef: 0.5310
# Epoch 89: val_loss did not improve from 0.45322
# 183/183 [==============================] - 39s 212ms/step - loss: 0.4690 - categorical_accuracy: 0.8309 - mean_dice_coef: 0.6242 - weighted_mean_dice_coef: 0.5310 - val_loss: 0.4533 - val_categorical_accuracy: 0.8373 - val_mean_dice_coef: 0.6380 - val_weighted_mean_dice_coef: 0.5466 - lr: 5.0000e-04
# Epoch 90/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4686 - categorical_accuracy: 0.8312 - mean_dice_coef: 0.6246 - weighted_mean_dice_coef: 0.5314
# Epoch 90: val_loss did not improve from 0.45322
# 183/183 [==============================] - 39s 213ms/step - loss: 0.4686 - categorical_accuracy: 0.8312 - mean_dice_coef: 0.6246 - weighted_mean_dice_coef: 0.5314 - val_loss: 0.4543 - val_categorical_accuracy: 0.8316 - val_mean_dice_coef: 0.6359 - val_weighted_mean_dice_coef: 0.5456 - lr: 5.0000e-04
# Epoch 91/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4689 - categorical_accuracy: 0.8310 - mean_dice_coef: 0.6243 - weighted_mean_dice_coef: 0.5312
# Epoch 91: val_loss did not improve from 0.45322
# ...
# Epoch 171/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4601 - categorical_accuracy: 0.8342 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399
# Epoch 171: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 216ms/step - loss: 0.4601 - categorical_accuracy: 0.8342 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399 - val_loss: 0.4493 - val_categorical_accuracy: 0.8393 - val_mean_dice_coef: 0.6414 - val_weighted_mean_dice_coef: 0.5505 - lr: 2.5000e-04
# Epoch 172/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4606 - categorical_accuracy: 0.8341 - mean_dice_coef: 0.6310 - weighted_mean_dice_coef: 0.5394
# Epoch 172: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 215ms/step - loss: 0.4606 - categorical_accuracy: 0.8341 - mean_dice_coef: 0.6310 - weighted_mean_dice_coef: 0.5394 - val_loss: 0.4482 - val_categorical_accuracy: 0.8378 - val_mean_dice_coef: 0.6417 - val_weighted_mean_dice_coef: 0.5517 - lr: 2.5000e-04
# Epoch 173/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4608 - categorical_accuracy: 0.8341 - mean_dice_coef: 0.6308 - weighted_mean_dice_coef: 0.5392
# Epoch 173: val_loss did not improve from 0.44773
# 183/183 [==============================] - 41s 222ms/step - loss: 0.4608 - categorical_accuracy: 0.8341 - mean_dice_coef: 0.6308 - weighted_mean_dice_coef: 0.5392 - val_loss: 0.4487 - val_categorical_accuracy: 0.8388 - val_mean_dice_coef: 0.6416 - val_weighted_mean_dice_coef: 0.5512 - lr: 2.5000e-04
# Epoch 174/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4601 - categorical_accuracy: 0.8344 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399
# Epoch 174: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 218ms/step - loss: 0.4601 - categorical_accuracy: 0.8344 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399 - val_loss: 0.4494 - val_categorical_accuracy: 0.8374 - val_mean_dice_coef: 0.6409 - val_weighted_mean_dice_coef: 0.5505 - lr: 2.5000e-04
# Epoch 175/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4604 - categorical_accuracy: 0.8340 - mean_dice_coef: 0.6311 - weighted_mean_dice_coef: 0.5396
# Epoch 175: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 215ms/step - loss: 0.4604 - categorical_accuracy: 0.8340 - mean_dice_coef: 0.6311 - weighted_mean_dice_coef: 0.5396 - val_loss: 0.4488 - val_categorical_accuracy: 0.8388 - val_mean_dice_coef: 0.6415 - val_weighted_mean_dice_coef: 0.5511 - lr: 2.5000e-04
# Epoch 176/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4601 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399
# Epoch 176: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 215ms/step - loss: 0.4601 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399 - val_loss: 0.4502 - val_categorical_accuracy: 0.8378 - val_mean_dice_coef: 0.6404 - val_weighted_mean_dice_coef: 0.5497 - lr: 2.5000e-04
# Epoch 177/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4602 - categorical_accuracy: 0.8342 - mean_dice_coef: 0.6312 - weighted_mean_dice_coef: 0.5398
# Epoch 177: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 220ms/step - loss: 0.4602 - categorical_accuracy: 0.8342 - mean_dice_coef: 0.6312 - weighted_mean_dice_coef: 0.5398 - val_loss: 0.4493 - val_categorical_accuracy: 0.8379 - val_mean_dice_coef: 0.6410 - val_weighted_mean_dice_coef: 0.5506 - lr: 2.5000e-04
# Epoch 178/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4602 - categorical_accuracy: 0.8342 - mean_dice_coef: 0.6312 - weighted_mean_dice_coef: 0.5398
# Epoch 178: val_loss did not improve from 0.44773
# 183/183 [==============================] - 39s 213ms/step - loss: 0.4602 - categorical_accuracy: 0.8342 - mean_dice_coef: 0.6312 - weighted_mean_dice_coef: 0.5398 - val_loss: 0.4485 - val_categorical_accuracy: 0.8405 - val_mean_dice_coef: 0.6421 - val_weighted_mean_dice_coef: 0.5513 - lr: 2.5000e-04
# Epoch 179/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4600 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6314 - weighted_mean_dice_coef: 0.5400
# Epoch 179: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 217ms/step - loss: 0.4600 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6314 - weighted_mean_dice_coef: 0.5400 - val_loss: 0.4479 - val_categorical_accuracy: 0.8414 - val_mean_dice_coef: 0.6428 - val_weighted_mean_dice_coef: 0.5520 - lr: 2.5000e-04
# Epoch 180/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4602 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5398
# Epoch 180: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 219ms/step - loss: 0.4602 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5398 - val_loss: 0.4485 - val_categorical_accuracy: 0.8389 - val_mean_dice_coef: 0.6419 - val_weighted_mean_dice_coef: 0.5514 - lr: 2.5000e-04
# Epoch 181/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4601 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399
# Epoch 181: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 216ms/step - loss: 0.4601 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6313 - weighted_mean_dice_coef: 0.5399 - val_loss: 0.4486 - val_categorical_accuracy: 0.8392 - val_mean_dice_coef: 0.6418 - val_weighted_mean_dice_coef: 0.5513 - lr: 2.5000e-04
# Epoch 182/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4598 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6315 - weighted_mean_dice_coef: 0.5402
# Epoch 182: val_loss did not improve from 0.44773
# 183/183 [==============================] - 41s 224ms/step - loss: 0.4598 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6315 - weighted_mean_dice_coef: 0.5402 - val_loss: 0.4479 - val_categorical_accuracy: 0.8391 - val_mean_dice_coef: 0.6422 - val_weighted_mean_dice_coef: 0.5520 - lr: 2.5000e-04
# Epoch 183/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4601 - categorical_accuracy: 0.8344 - mean_dice_coef: 0.6314 - weighted_mean_dice_coef: 0.5400
# Epoch 183: val_loss did not improve from 0.44773
# 183/183 [==============================] - 41s 222ms/step - loss: 0.4601 - categorical_accuracy: 0.8344 - mean_dice_coef: 0.6314 - weighted_mean_dice_coef: 0.5400 - val_loss: 0.4481 - val_categorical_accuracy: 0.8371 - val_mean_dice_coef: 0.6416 - val_weighted_mean_dice_coef: 0.5518 - lr: 2.5000e-04
# Epoch 184/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4599 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6315 - weighted_mean_dice_coef: 0.5401
# Epoch 184: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 219ms/step - loss: 0.4599 - categorical_accuracy: 0.8343 - mean_dice_coef: 0.6315 - weighted_mean_dice_coef: 0.5401 - val_loss: 0.4483 - val_categorical_accuracy: 0.8394 - val_mean_dice_coef: 0.6419 - val_weighted_mean_dice_coef: 0.5516 - lr: 2.5000e-04
# Epoch 185/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4600 - categorical_accuracy: 0.8344 - mean_dice_coef: 0.6314 - weighted_mean_dice_coef: 0.5400
# Epoch 185: val_loss did not improve from 0.44773
#
# Epoch 185: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 183/183 [==============================] - 41s 221ms/step - loss: 0.4600 - categorical_accuracy: 0.8344 - mean_dice_coef: 0.6314 - weighted_mean_dice_coef: 0.5400 - val_loss: 0.4492 - val_categorical_accuracy: 0.8379 - val_mean_dice_coef: 0.6410 - val_weighted_mean_dice_coef: 0.5507 - lr: 2.5000e-04
# Epoch 186/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4592 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6321 - weighted_mean_dice_coef: 0.5408
# Epoch 186: val_loss did not improve from 0.44773
# 183/183 [==============================] - 40s 219ms/step - loss: 0.4592 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6321 - weighted_mean_dice_coef: 0.5408 - val_loss: 0.4481 - val_categorical_accuracy: 0.8359 - val_mean_dice_coef: 0.6413 - val_weighted_mean_dice_coef: 0.5517 - lr: 1.2500e-04
# Epoch 187/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4591 - categorical_accuracy: 0.8346 - mean_dice_coef: 0.6321 - weighted_mean_dice_coef: 0.5409
# Epoch 187: val_loss improved from 0.44773 to 0.44697, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 40s 216ms/step - loss: 0.4591 - categorical_accuracy: 0.8346 - mean_dice_coef: 0.6321 - weighted_mean_dice_coef: 0.5409 - val_loss: 0.4470 - val_categorical_accuracy: 0.8398 - val_mean_dice_coef: 0.6431 - val_weighted_mean_dice_coef: 0.5529 - lr: 1.2500e-04
# Epoch 188/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4588 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6324 - weighted_mean_dice_coef: 0.5412
# Epoch 188: val_loss improved from 0.44697 to 0.44662, saving model to ./weights/eddyRESnet.h5
# 183/183 [==============================] - 40s 217ms/step - loss: 0.4588 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6324 - weighted_mean_dice_coef: 0.5412 - val_loss: 0.4466 - val_categorical_accuracy: 0.8399 - val_mean_dice_coef: 0.6434 - val_weighted_mean_dice_coef: 0.5533 - lr: 1.2500e-04
# Epoch 189/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4589 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6323 - weighted_mean_dice_coef: 0.5411
# Epoch 189: val_loss did not improve from 0.44662
# 183/183 [==============================] - 40s 219ms/step - loss: 0.4589 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6323 - weighted_mean_dice_coef: 0.5411 - val_loss: 0.4473 - val_categorical_accuracy: 0.8415 - val_mean_dice_coef: 0.6432 - val_weighted_mean_dice_coef: 0.5526 - lr: 1.2500e-04
# Epoch 190/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4590 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6322 - weighted_mean_dice_coef: 0.5410
# Epoch 190: val_loss did not improve from 0.44662
# 183/183 [==============================] - 39s 213ms/step - loss: 0.4590 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6322 - weighted_mean_dice_coef: 0.5410 - val_loss: 0.4473 - val_categorical_accuracy: 0.8392 - val_mean_dice_coef: 0.6427 - val_weighted_mean_dice_coef: 0.5526 - lr: 1.2500e-04
# Epoch 191/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4586 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5414
# Epoch 191: val_loss did not improve from 0.44662
# 183/183 [==============================] - 40s 216ms/step - loss: 0.4586 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5414 - val_loss: 0.4476 - val_categorical_accuracy: 0.8384 - val_mean_dice_coef: 0.6423 - val_weighted_mean_dice_coef: 0.5523 - lr: 1.2500e-04
# Epoch 192/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4589 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6323 - weighted_mean_dice_coef: 0.5411
# Epoch 192: val_loss did not improve from 0.44662
# 183/183 [==============================] - 40s 218ms/step - loss: 0.4589 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6323 - weighted_mean_dice_coef: 0.5411 - val_loss: 0.4476 - val_categorical_accuracy: 0.8385 - val_mean_dice_coef: 0.6424 - val_weighted_mean_dice_coef: 0.5523 - lr: 1.2500e-04
# Epoch 193/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4586 - categorical_accuracy: 0.8346 - mean_dice_coef: 0.6325 - weighted_mean_dice_coef: 0.5414
# Epoch 193: val_loss did not improve from 0.44662
# 183/183 [==============================] - 39s 214ms/step - loss: 0.4586 - categorical_accuracy: 0.8346 - mean_dice_coef: 0.6325 - weighted_mean_dice_coef: 0.5414 - val_loss: 0.4479 - val_categorical_accuracy: 0.8398 - val_mean_dice_coef: 0.6423 - val_weighted_mean_dice_coef: 0.5520 - lr: 1.2500e-04
# Epoch 194/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4585 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5415
# Epoch 194: val_loss did not improve from 0.44662
# 183/183 [==============================] - 40s 215ms/step - loss: 0.4585 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5415 - val_loss: 0.4474 - val_categorical_accuracy: 0.8379 - val_mean_dice_coef: 0.6423 - val_weighted_mean_dice_coef: 0.5525 - lr: 1.2500e-04
# Epoch 195/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4588 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6323 - weighted_mean_dice_coef: 0.5412
# Epoch 195: val_loss did not improve from 0.44662
# 183/183 [==============================] - 41s 221ms/step - loss: 0.4588 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6323 - weighted_mean_dice_coef: 0.5412 - val_loss: 0.4481 - val_categorical_accuracy: 0.8394 - val_mean_dice_coef: 0.6422 - val_weighted_mean_dice_coef: 0.5518 - lr: 1.2500e-04
# Epoch 196/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4584 - categorical_accuracy: 0.8348 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5416
# Epoch 196: val_loss did not improve from 0.44662
# 183/183 [==============================] - 39s 213ms/step - loss: 0.4584 - categorical_accuracy: 0.8348 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5416 - val_loss: 0.4469 - val_categorical_accuracy: 0.8399 - val_mean_dice_coef: 0.6432 - val_weighted_mean_dice_coef: 0.5530 - lr: 1.2500e-04
# Epoch 197/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4586 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5415
# Epoch 197: val_loss did not improve from 0.44662
# 183/183 [==============================] - 40s 217ms/step - loss: 0.4586 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6326 - weighted_mean_dice_coef: 0.5415 - val_loss: 0.4474 - val_categorical_accuracy: 0.8403 - val_mean_dice_coef: 0.6429 - val_weighted_mean_dice_coef: 0.5524 - lr: 1.2500e-04
# Epoch 198/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4582 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6328 - weighted_mean_dice_coef: 0.5418
# Epoch 198: val_loss did not improve from 0.44662
# 183/183 [==============================] - 40s 216ms/step - loss: 0.4582 - categorical_accuracy: 0.8347 - mean_dice_coef: 0.6328 - weighted_mean_dice_coef: 0.5418 - val_loss: 0.4477 - val_categorical_accuracy: 0.8406 - val_mean_dice_coef: 0.6427 - val_weighted_mean_dice_coef: 0.5522 - lr: 1.2500e-04
# Epoch 199/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4583 - categorical_accuracy: 0.8348 - mean_dice_coef: 0.6327 - weighted_mean_dice_coef: 0.5417
# Epoch 199: val_loss did not improve from 0.44662
# 183/183 [==============================] - 39s 214ms/step - loss: 0.4583 - categorical_accuracy: 0.8348 - mean_dice_coef: 0.6327 - weighted_mean_dice_coef: 0.5417 - val_loss: 0.4484 - val_categorical_accuracy: 0.8393 - val_mean_dice_coef: 0.6420 - val_weighted_mean_dice_coef: 0.5515 - lr: 1.2500e-04
# Epoch 200/200
# 183/183 [==============================] - ETA: 0s - loss: 0.4583 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6328 - weighted_mean_dice_coef: 0.5417
# Epoch 200: val_loss did not improve from 0.44662
# 183/183 [==============================] - 39s 215ms/step - loss: 0.4583 - categorical_accuracy: 0.8349 - mean_dice_coef: 0.6328 - weighted_mean_dice_coef: 0.5417 - val_loss: 0.4482 - val_categorical_accuracy: 0.8368 - val_mean_dice_coef: 0.6415 - val_weighted_mean_dice_coef: 0.5517 - lr: 1.2500e-04

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(eddynet.history.history['loss'])
plt.semilogy(eddynet.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss', 'val_loss'], loc='upper right');

# %% [markdown]
# ## Performance on train dataset
# just to be sure...

# %%
randindex=np.random.randint(0,len(SSH_train))
predictedSEGM=eddynet.predict(np.reshape(SSH_train[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,6:-6]

plt.figure(figsize=(20, 10))
plt.subplot(131)
plt.imshow(SSH_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ADT');

plt.subplot(132)
plt.imshow(predictedSEGMimage, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('Eddynet Segmentation');

plt.subplot(133)
plt.imshow(Seg_train[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');
# Out:
# 1/1 [==============================] - 1s 630ms/step

# %% [markdown]
# ## Performance on test dataset (2009 data)

# %%
randindex=np.random.randint(0,len(SSH_test))
predictedSEGM=eddynet.predict(np.reshape(SSH_test[randindex,:,:],(1,height,width,1)))
predictedSEGMimage = np.reshape(predictedSEGM.argmax(2),(height,width))
predictedSEGMimage=predictedSEGMimage[::-1,6:-6]

plt.figure(figsize=(20, 10))

plt.subplot(221)
plt.imshow(predictedSEGMimage, cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('EddyResNet Segmentation');

plt.subplot(222)
plt.imshow(Seg_test[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ground truth Segmentation');

plt.subplot(223)
plt.imshow(SSH_test[randindex,::-1,6:-6,0], cmap='viridis')
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
#plt.clim(-0.25,0.25)
plt.axis('off')
plt.title('ADT');

plt.subplot(224)
plt.imshow(np.where(predictedSEGMimage == Seg_test[randindex,::-1,6:-6,0], 0, 1))
plt.colorbar(extend='both', fraction=0.042, pad=0.04)
plt.axis('off')
plt.title('Errors');
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# Seems working nicely, but there are some false eddy detections that need to be dealt with.
#
# On my new paper I show that combining EddyResNet with ideas from level set segmentation leads to better results, I'll post the code upon acceptance of the paper

# %% [markdown]
# ## metrics on test dataset

# %%
Seg_test_categor = utils.to_categorical(np.reshape(Seg_test[:,:,:,0],(365,80*192)),5)
Seg_test_categor.shape
# Out:
# (365, 15360, 5)

# %%
eddynet.evaluate(SSH_test,Seg_test_categor)
# Out:
# 12/12 [==============================] - 1s 79ms/step - loss: 0.4427 - categorical_accuracy: 0.8371 - mean_dice_coef: 0.6441 - weighted_mean_dice_coef: 0.5552
# [0.4426587224006653, 0.8371205925941467, 0.64413982629776, 0.5551841855049133]

# %%
#### if you wanna use some animations ;) 


#imageList=[]
#for i in range(1200,1400):
#    imageList.append(SSH_train[i,:,:,0])
  

#print('drawing the animation...')
#from matplotlib import animation, rc
#from IPython.display import HTML

#def getImageFromList(x):
#    return imageList[x]

#fig = plt.figure(figsize=(10, 10))
#ims = []
#for i in range(len(imageList)):
#    im = plt.imshow(getImageFromList(i), animated=True, cmap='viridis')
#    ims.append([im])
#plt.axis('off')

#ani = animation.ArtistAnimation(fig, ims, interval=50, blit=False, repeat=False)
#plt.close()

#HTML(ani.to_jshtml())

# %% [markdown]
# # Data for statistics

# %%
predictedSEGM_train = eddynet.predict(np.reshape(SSH_train,(-1,height,width,1)))
predictedSEGMimage_train = np.reshape(predictedSEGM_train.argmax(2),(-1,height,width))
predictedSEGMimage_train = predictedSEGMimage_train[:,::-1,6:-6]
    
predictedSEGM_test = eddynet.predict(np.reshape(SSH_test,(-1,height,width,1)))
predictedSEGMimage_test = np.reshape(predictedSEGM_test.argmax(2),(-1,height,width))
predictedSEGMimage_test = predictedSEGMimage_test[:,::-1,6:-6]

eddy_detected = np.concatenate((predictedSEGMimage_train, predictedSEGMimage_test), axis=0)
eddy_detected = eddy_detected.astype(np.int8)
np.save('../Data/eddy_detected_res.npy',eddy_detected)
# Out:
# 229/229 [==============================] - 13s 54ms/step
# 12/12 [==============================] - 1s 57ms/step
